# %%
import os
import numpy as np
import pydicom

import pandas as pd
import sys
sys.path.append('/mnt/fast-disk1/mjc/utils_codes/read_weasis_raw_v0.96/')

import weasis_raw_data_api as wr
sys.path.append('/mnt/fast-disk1/mjc/utils_codes/')
from utils_test import *
from utils_metrics_3d import *

D_dir2header_df = {}
def get_dicom_header_df(image_dir , labels = []):
    global D_dir2header_df
    if image_dir in D_dir2header_df:
        return D_dir2header_df[image_dir]

    # image_dir = row['Image File Path']


    labels = ['ImageName','InstanceNumber',
            'BitsAllocated', 'BitsStored', 'Columns', 'HighBit', 
            'ImageOrientationPatient_0', 'ImageOrientationPatient_1', 'ImageOrientationPatient_2',
            'ImageOrientationPatient_3', 'ImageOrientationPatient_4', 'ImageOrientationPatient_5',
            'ImagePositionPatient_0', 'ImagePositionPatient_1', 'ImagePositionPatient_2',
            'Modality', 'PatientID', 'PhotometricInterpretation', 'PixelRepresentation',
            'PixelSpacing_0', 'PixelSpacing_1', 'RescaleIntercept', 'RescaleSlope', 'Rows', 'SOPInstanceUID',
            'SamplesPerPixel', 'SeriesInstanceUID', 'StudyID', 'StudyInstanceUID', 
            'WindowCenter', 'WindowWidth', 
        ] if not labels else labels

    data = {l: [] for l in labels}
    
    ctList = os.listdir(image_dir)
    ctList.sort()

    for image in ctList:
        if '.dcm' not in image:
            continue
        if os.path.getsize(os.path.join(image_dir, image)) < 5*1024:
            print('%s size < 5kb skiped!'%os.path.join(image_dir, image) )
            continue
        data["ImageName"].append(image)

        ds = pydicom.dcmread(os.path.join(image_dir, image))
        for metadata in ds.dir():
            if metadata not in data and metadata not in ['ImageOrientationPatient','ImagePositionPatient','PixelSpacing']:
                continue
            if metadata != "PixelData":
                metadata_values = getattr(ds, metadata)
                if type(metadata_values) == pydicom.multival.MultiValue and metadata not in ["WindowCenter", "WindowWidth"]:
                    for i, v in enumerate(metadata_values):
                        data[f"{metadata}_{i}"].append(v)  
                else:

                    if type(metadata_values) == pydicom.multival.MultiValue and metadata in ["WindowCenter", "WindowWidth"]:
                        data[metadata].append(metadata_values[0])
                    else:
                        
                        if metadata in ['ImageOrientationPatient','ImagePositionPatient','PixelSpacing']:
                            print( 'error of loading key: {}'.format(metadata) )                    
                        else:
                            data[metadata].append(metadata_values)

    df_image = pd.DataFrame(data).set_index("InstanceNumber")
    D_dir2header_df[image_dir] = df_image
    return df_image

# %%
def pd_str_replace(df , col, ori, new):
    if isinstance(col , str):
        try:
            df[col] = df[col].str.replace(ori,new, case = False) 
        except:
            pass
            
    elif isinstance(col, list):
        for one in col:
            pd_str_replace(df , one, ori, new)
    else:
        raise('col instance should be str or list')


def str_Xdrive2mnt(df_all):
    pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], "X:" , "/mnt/Y-drive")
    pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], r"\\" , "/")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrials/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrialDone/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrials", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")

    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw/PDS_AUTO_RECIST_Modified_By_Yen",
    "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw/PDS_AUTO_RECIST_Modified_By_Yen")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw/PDS_AUTO_RECIST", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw/PDS_AUTO_RECIST_RAW")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToMatlab", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")
    
def get_onect_from_list(df_list , ct):
    for i, df in enumerate(df_list):
        try:
            df_ct = df[ (df["Image File Path"]==ct) & (df['Location'].isin(['liver'])) ]
        except KeyError:
            df_ct = df[ (df["Image File Path"]==ct)]
        if df_ct.shape[0]:
            return df_ct , i
    print("warning! no CT was found")
    return None ,None

def raws2mask(raws , D_z_index, mask_vol = None):

    for raw in raws:

        radiologist_raw = wr.read(raw)
        slice_list = radiologist_raw.get_instance_number_array()
        if mask_vol is None:
            mask_vol = initialize_mask_vol(radiologist_raw , D_z_index)
        for j, one in enumerate(slice_list):
            mask = radiologist_raw.get_mask_image(j)
            mask_vol[D_z_index[one]] += mask
    return mask_vol

# %%
folder = '/mnt/fast-data/mjc/AutoRECIST/Inputs/'



df_CTs = pd.read_excel(folder+'AutoRECIST_List_LesionSize_20220602_JM_SingleCTSeries.xlsx')
str_Xdrive2mnt(df_CTs)


df_Yen = pd.read_excel(folder+'PDS_AUTO_RECIST CIA-LAB Testing Dataset Gold Standard_Yen_2022-06-13.xlsx')
str_Xdrive2mnt(df_Yen)

AI_raw_list = ['ScaleNAS9SliceToRaw_Test353.csv',]
df_AIs = []
for one in AI_raw_list:
    df = pd.read_csv(one)
    str_Xdrive2mnt(df)
    df_AIs.append(df)




Metrics_vol = []
metrics_save_path = 'Metrics_%s_vs_Yen353pts.csv'%'ScaleNAS9Slices'
CTs = df_CTs["Image File Path"].values.tolist()

for ct in CTs:
    df_image = get_dicom_header_df( ct )
    instanceNumber_list = df_image.index.to_list()
    D_z_index = instanceNumber2Matrix_z_index(instanceNumber_list)


    df_ct_Yen = df_Yen[df_Yen["Image File Path"]==ct]
    df_ct_AI , dataset_id = get_onect_from_list(df_AIs , ct)
    # break
    if (df_ct_AI is None):
        if df_ct_Yen.shape[0]:
            fn = df_ct_Yen.shape[0]
            print('{} has {} FNs!'.format(ct , fn))   
        continue

    if not df_ct_Yen.shape[0]:
        fp = df_ct_AI.shape[0]
        print( '{} has {} FPs'.format(ct , fp)  )
        continue
    else:
        print(ct)

    raws = df_ct_AI["Contour File Path"].values.tolist()
    vol_pred = raws2mask(raws , D_z_index, mask_vol = None)
    connectivity = 2
    from skimage import measure
    labels_pred=measure.label(vol_pred,connectivity=connectivity)
    l_pred,c_pred = np.unique(labels_pred , return_counts=True)
    ix2 = l_pred>0
    l_pred = l_pred[ix2] #background pixels are labeled as 0, so we exclude them
    c_pred = c_pred[ix2]
    if len(l_pred)!= len(raws):
        print("warning! raws overlaped on {}".format(ct))


    for _ , row in df_ct_Yen.iterrows():

        Yen_raw = wr.read(row['Contour File Path'])
        gt_vol = initialize_mask_vol(Yen_raw , D_z_index)

        slice_list = Yen_raw.get_instance_number_array()
        for j, one in enumerate(slice_list):
            mask = Yen_raw.get_mask_image(j)
            gt_vol[D_z_index[one]] = mask
        
        hit = vols_seg_results(gt_vol , vol_pred, CTname=row['Contour File Path'], gt_keep_largest=1)
        Metrics_vol.extend(hit)

        _n = len(Metrics_vol)
        if _n%100==0 or _n in [1,2,5,10,30,50]:
            df_metrics = pd.DataFrame(Metrics_vol, 
                                    columns = ['file_name','igt','merge','#gt','#pred',
                                                'iou_score', 'dice_score', 'over_seg' , 'under_seg',
                                                'area_gt','area_pred','intersection','union']) 
            df_metrics.to_csv(metrics_save_path)
# Out:
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0002/D2019_01_02/E1326/CT/S0007_3337
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0003/D2019_10_07/E2122/CT/S0002_2131
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0004/D2019_03_04/E9409/CT/S0016_5317
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0006/D2018_12_11/E8314/CT/S0002_5268
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0008/D2019_12_19/E2450/CT/S0002_7253
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0009/D2020_01_22/E0578/CT/S0018_3927
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0019/D2020_01_07/E8279/CT/S0005_2496
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0020/D2019_01_09/E2250/CT/S0005_1575
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0024/D2018_11_26/E0507/CT/S0006_5482
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0026/D2019_04_12/E3925/CT/S0006_9366
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0028/D2019_07_12/E6851/CT/S0006_8606
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0033/D2018_10_24/E0816/CT/S0002_0822
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0036/D2018_11_30/E2803/CT/S0003_5983
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0038/D2018_11_08/E1856/CT/S0004_9015
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0040/D2018_12_25/E0028/CT/S0004_3920
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0045/D2018_12_31/E4873/CT/S0004_3712
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0050/D2019_01_04/E4478/CT/S0002_6859
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0051/D2019_01_25/E4701/CT/S0002_5897
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0055/D2019_02_25/E8293/CT/S0005_8934
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0056/D2019_03_19/E2806/CT/S0002_8158
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0060/D2019_05_28/E4296/CT/S0002_5183
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0068/D2019_12_05/E7533/CT/S0003_7277
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0070/D2020_03_10/E1191/CT/S0006_1494
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0072/D2020_05_06/E8731/CT/S0002_4371
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0086/D2020_07_18/E4710/CT/S0004_8400
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0089/D2019_10_22/E2646/CT/S0003_6412
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0090/D2019_12_04/E4704/CT/S0002_8241
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0091/D2020_07_21/E8492/CT/S0003_1824
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0092/D2019_04_02/E1327/CT/S0007_1538
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0094/D2019_02_18/E2895/CT/S0602_8602
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0104/D2019_02_12/E3272/CT/S0004_4674
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0109/D2019_12_17/E3845/CT/S0005_1061
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0121/D2019_08_26/E8599/CT/S0003_8756
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0131/D2019_01_04/E1058/CT/S0002_8806
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0136/D2019_06_05/E6581/CT/S0002_0029
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0137/D2019_08_07/E8485/CT/S0002_0959
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0140/D2019_02_21/E1740/CT/S0003_5046
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0146/D2019_07_09/E8702/CT/S0007_7117
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0150/D2019_12_13/E6241/CT/S0005_2496
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0153/D2019_12_10/E3951/CT/S0003_3965
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0174/D2019_01_18/E3953/CT/S0003_9603
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0180/D2020_01_03/E9828/CT/S0006_8376
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0187/D2017_04_26/E1167/CT/S0002_5612
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0192/D2019_02_21/E6430/CT/S0003_0478
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0194/D2019_02_11/E3611/CT/S0002_7005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0195/D2019_04_08/E6219/CT/S0003_8373
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0197/D2019_04_12/E2953/CT/S0002_6892
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0208/D2019_06_26/E9298/CT/S0003_9073
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0212/D2019_09_12/E9134/CT/S0003_8663
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0215/D2019_10_28/E4799/CT/S0003_6381
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0222/D2019_10_16/E8403/CT/S0007_0427
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0223/D2019_12_11/E9784/CT/S0010_2646
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0225/D2019_10_31/E0067/CT/S0007_0410
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0226/D2019_11_13/E2102/CT/S0003_1093
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0227/D2019_07_22/E2270/CT/S0004_4084
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0229/D2019_12_06/E9735/CT/S0007_0451
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0232/D2020_01_22/E4306/CT/S0007_5599
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0234/D2019_12_17/E0362/CT/S0007_3717
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0243/D2019_03_28/E9456/CT/S0006_3673
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0245/D2019_09_27/E0255/CT/S0006_3194
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0246/D2019_06_19/E0384/CT/S0006_1940
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0247/D2019_10_16/E7032/CT/S0016_8197
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0249/D2019_11_25/E7414/CT/S0008_4556
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0251/D2019_05_13/E1478/CT/S0007_9648
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0255/D2019_02_15/E3928/CT/S0005_7647
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0260/D2016_12_13/E6584/CT/S0003_0478
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0263/D2019_02_05/E7272/CT/S0002_2601
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0268/D2019_02_20/E4650/CT/S0006_6006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0277/D2019_05_21/E8774/CT/S0002_4796
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0289/D2019_09_23/E4372/CT/S0002_8538
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0294/D2020_01_30/E8610/CT/S0002_5763
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0296/D2019_06_03/E3751/CT/S0002_1364
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJC/D2004_02_27/E20040227/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJD/D2004_02_07/E20040207/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJG/D2004_02_02/E20040202/CT/S0013
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJL/D2004_02_24/E20040224/CT/S3464
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJM/D2004_01_31/E20040131/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJN/D2004_02_03/E20040203/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJO/D2004_02_19/E20040219/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJP/D2004_02_26/E20040226/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJQ/D2004_04_27/E20040427/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJR/D2004_02_11/E20040211/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJT/D2004_02_27/E20040227/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJV/D2004_04_25/E9999/CT/S0004_4585
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJW/D2004_02_25/E9999/CT/S0004_1569
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJY/D2004_02_26/E20040226/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJZ/D2004_03_02/E20040302/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKB/D2004_02_24/E20040224/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKD/D2004_02_04/E20040204/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKG/D2004_04_19/E20040419/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKI/D2004_02_23/E20040223/CT/S2051
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKJ/D2004_02_08/E20040208/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKL/D2004_02_10/E9999/CT/S5141_1574
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKO/D2004_02_11/E20040211/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKP/D2004_02_25/E20040225/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKS/D2004_02_21/E20040221/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKX/D2004_04_28/E20040428/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILA/D2004_02_26/E20040226/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILC/D2004_02_23/E20040223/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILD/D2004_02_24/E20040224/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILE/D2004_02_21/E20040221/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILF/D2004_01_27/E20040127/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILG/D2004_02_19/E20040219/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILJ/D2004_02_29/E20040229/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILK/D2004_02_24/E20040224/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILL/D2004_02_23/E20040223/CT/S2965
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILM/D2004_02_05/E20040205/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILN/D2004_02_28/E20040228/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILP/D2004_02_11/E20040211/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILQ/D2004_02_24/E20040224/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILS/D2004_02_28/E20040228/CT/S4884
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAILY/D2004_02_03/E20040203/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMC/D2004_02_28/E20040228/CT/S2607
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMF/D2004_02_26/E20040226/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMI/D2004_02_18/E20040218/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIML/D2004_02_26/E20040226/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMQ/D2004_03_02/E20040302/CT/S9708
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMS/D2004_02_29/E20040229/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMU/D2004_03_02/E20040302/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIMW/D2004_02_28/E20040228/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINA/D2004_04_21/E20040421/CT/S7100
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINB/D2004_02_22/E20040222/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINC/D2004_02_27/E20040227/CT/S3498
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIND/D2004_06_21/E20040621/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINF/D2004_01_31/E20040131/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAING/D2004_02_26/E20040226/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINH/D2004_02_24/E20040224/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINI/D2004_02_06/E20040206/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINJ/D2004_03_02/E20040302/CT/S0012
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINN/D2004_04_27/E20040427/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINP/D2004_06_02/E20040602/CT/S4095
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINS/D2004_01_15/E20040115/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINT/D2004_02_22/E20040222/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINV/D2004_02_04/E20040204/CT/S0123
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAINY/D2004_02_23/E20040223/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOC/D2004_02_28/E20040228/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOE/D2004_03_08/E20040308/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOG/D2004_02_28/E20040228/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOI/D2004_02_13/E20040213/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOJ/D2004_02_15/E20040215/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOK/D2004_02_04/E20040204/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOO/D2004_01_18/E20040118/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOR/D2004_02_27/E20040227/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOS/D2004_01_26/E20040126/CT/S7861
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOT/D2004_02_27/E20040227/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOU/D2004_02_23/E20040223/CT/S6065
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOW/D2004_02_27/E20040227/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOX/D2004_04_24/E20040424/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOY/D2004_02_24/E20040224/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIOZ/D2004_02_26/E20040226/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPA/D2004_02_24/E20040224/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPB/D2004_02_28/E20040228/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPC/D2004_03_08/E20040308/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPD/D2004_02_24/E20040224/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPH/D2004_02_28/E20040228/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPL/D2004_02_27/E20040227/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPO/D2004_02_05/E20040205/CT/S3337
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPP/D2004_04_27/E20040427/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPQ/D2004_02_25/E20040225/CT/S0461
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPS/D2004_02_27/E20040227/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPU/D2004_02_28/E20040228/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPV/D2004_02_23/E20040223/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPW/D2004_02_06/E20040206/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIPZ/D2004_03_02/E20040302/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQA/D2004_03_02/E20040302/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQD/D2004_02_29/E20040229/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQE/D2004_02_24/E20040224/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQG/D2004_02_28/E20040228/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQJ/D2004_02_19/E20040219/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQL/D2004_03_08/E20040308/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQM/D2004_02_18/E20040218/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQN/D2004_02_03/E20040203/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQO/D2004_02_23/E20040223/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQP/D2004_02_26/E20040226/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQQ/D2004_02_28/E20040228/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQU/D2004_02_14/E20040214/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQW/D2004_02_24/E20040224/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQX/D2004_02_15/E20040215/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIQZ/D2004_02_27/E20040227/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRB/D2004_01_29/E20040129/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRC/D2004_02_28/E20040228/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRD/D2004_02_24/E20040224/CT/S0311
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRF/D2004_03_02/E20040302/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRG/D2004_02_19/E20040219/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRJ/D2004_02_23/E20040223/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRK/D2004_02_28/E20040228/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRL/D2004_02_24/E20040224/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRP/D2004_02_13/E20040213/CT/S0503
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRS/D2004_02_25/E20040225/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRU/D2004_02_29/E20040229/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRW/D2004_02_28/E9999/CT/S5141_2841
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIRX/D2004_02_17/E20040217/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISA/D2004_02_04/E20040204/CT/S3994
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISB/D2004_02_24/E20040224/CT/S2408
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISC/D2004_02_11/E20040211/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISE/D2004_02_21/E20040221/CT/S2628
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISH/D2004_04_22/E20040422/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISI/D2004_02_01/E20040201/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISJ/D2004_03_01/E20040301/CT/S1896
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISK/D2004_02_18/E20040218/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISM/D2004_02_15/E20040215/CT/S1232
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISN/D2004_02_25/E20040225/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISO/D2004_02_25/E20040225/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISP/D2004_02_25/E20040225/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISQ/D2004_01_27/E20040127/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIST/D2004_02_27/E20040227/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISU/D2004_02_06/E20040206/CT/S0103
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISV/D2004_02_29/E20040229/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISW/D2004_02_27/E20040227/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAISY/D2004_02_26/E20040226/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITD/D2004_04_25/E20040425/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITE/D2004_02_26/E20040226/CT/S0008
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITF/D2004_03_01/E20040301/CT/S0004
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITG/D2004_02_25/E20040225/CT/S1359
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITK/D2004_02_27/E20040227/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITL/D2004_02_26/E20040226/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITN/D2004_02_11/E20040211/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITP/D2004_02_04/E20040204/CT/S0005
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITQ/D2004_02_22/E20040222/CT/S0003
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITR/D2004_02_06/E20040206/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITS/D2004_02_25/E20040225/CT/S0002
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITU/D2004_02_26/E20040226/CT/S6470
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITV/D2004_02_21/E20040221/CT/S0773
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITW/D2004_02_12/E20040212/CT/S0006
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAITX/D2004_04_27/E20040427/CT/S0007
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET2910/D2015_02_06/E8602/CT/S0005_3151
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET2911/D2015_02_13/E2523/CT/S0004_1732
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET2914/D2015_03_16/E8300/CT/S0002_0406
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET2915/D2015_03_19/E4011/CT/S0002_6559
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET2917/D2015_04_02/E6773/CT/S0009_6114

# %%
df_metrics = pd.DataFrame(Metrics_vol, 
                        columns = ['file_name','igt','merge','#gt','#pred',
                                    'iou_score', 'dice_score', 'over_seg' , 'under_seg',
                                    'area_gt','area_pred','intersection','union']) 
df_metrics.to_csv(metrics_save_path)

# %%
pd.options.display.float_format = "{:.3f}".format
df_metrics = pd.DataFrame(Metrics_vol, 
                          columns = ['file_name','igt','merge','#gt','#pred',
                                     'iou_score', 'dice_score', 'over_seg' , 'under_seg',
                                     'area_gt','area_pred','intersection','union']) 
df_metrics.describe([.05, .25, .5, .75, .95])

# %%
df_metrics[df_metrics.dice_score>0.25].describe([.05, .25, .5, .75, .95])

# %%
dfinnermerge = pd.merge(df_metrics,df_Yen,how='inner',left_on='file_name' , right_on='Contour File Path')
for col in dfinnermerge.columns.tolist():
    print(col , len(set(dfinnermerge[col].tolist() )) )



pts = dfinnermerge["Image File Path"].values.tolist()
FPs = []
for onept in list(set(pts)):
    df_onept = dfinnermerge[dfinnermerge["Image File Path"]==onept]
    assert( min(df_onept["#pred"]) == max(df_onept["#pred"]))
    fp = max(df_onept["#pred"])
    FPs.append(fp)
print("="*80)
print( "In total, {} CT series; {} AI detections ".format( len(FPs) , sum(FPs) ) )

dices = dfinnermerge.dice_score.tolist()

for th in [0, 0.1, 0.2, 0.25, 0.5]:
    TP = [p>th for p in dices ]
    assert( len(TP) == len(dices))
    fprate = ( sum(FPs) - sum(TP) ) / len(FPs)
    print(f"sensitivity is {sum(TP)/len(dices):.3f}({sum(TP)}/{len(dices)}) FP-rate is {fprate:.1f} per CT-serie at threshold {th}")

# %%
df_metrics

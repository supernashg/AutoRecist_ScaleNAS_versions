# %%
def check_src_file_exists(masks_w_ap , masks_dir):
    N=0
    for line in masks_w_ap:
        id = line[0]
        src = os.path.join(masks_dir+id , 'mask.npy')
        if not os.path.exists(src):
            print(id,'not exists')
        else:
            N+=1
    print('{} files exist'.format(N))

# %%
from shutil import copyfile,copytree
import os
import glob

evo_sample_path = "../eval_results/seg_superscalenet_lesion_*"
masks_dir = "../output/Lesion/superscalenet_seg/Lesion_Q5_9Slices_scalenet_seg_test/data_patch_test_"

txt_files = glob.glob(evo_sample_path)
txt_files.sort()

def getid(s, l='_f' , r= '.txt'):
    ix1 = s.rfind(l)
    ix2 = s.rfind(r)
    return s[ix1+1:ix2]

masks_w_ap = []
for txt in txt_files:
    with open(txt,'r') as f:
        lines = f.readlines()  
        for lines_ind in range(0, len(lines)):
            line = lines[lines_ind]
            _line = line.split()
            if len(_line) == 15:
                # seed 266555 Params(M) 16.91 FLOPs(G) 229.07  AP 0.7646
                seed = _line[-7]
                id = getid(txt)+'_'+seed
                params = float(_line[-5])
                flops = float(_line[-3])
                ap = float(_line[-1])
                masks_w_ap.append([id, params, flops, ap])
            else:
                print(f"line should be 15 but now is {len(_line)}\n")

# %%
check_src_file_exists(masks_w_ap , masks_dir)
# Out:
# 1019 files exist

# %%
masks_w_ap.sort(key=lambda x: -x[3])
masks_w_ap = masks_w_ap[:1000]
with open('../evo_files/lesion_evo_file.txt' , 'w') as ff:
    for line in masks_w_ap:
        ss = "".join(str(x)+' ' for x in line)
        ff.write(ss+'\n')

# %%
for line in masks_w_ap:
    id = line[0]
    src = os.path.join(masks_dir+id , 'mask.npy')
    dst = '../evo_files/masks/'+id+'.npy'
    if os.path.exists(dst):
        print(id,'skip')
        continue
    else:
        print(id,'copying')
    copyfile(src, dst)
# Out:
# f0.8_d34_602867 copying
# f0.5_d45_897537 copying
# f0.5_d34_91023 copying
# f0.8_d45_393260 copying
# f0.65_d45_73574 copying
# f0.65_d45_109031 copying
# f0.8_d45_465866 copying
# f0.8_d45_122107 copying
# f0.8_d34_110914 copying
# f0.5_d34_855575 copying
# f0.5_d45_576513 copying
# f0.8_d45_925481 copying
# f0.5_d34_297580 copying
# f0.35_d45_184598 copying
# f0.5_d45_402697 copying
# f0.65_d45_645085 copying
# f0.5_d45_69001 copying
# f0.65_d45_557594 copying
# f0.65_d45_392859 copying
# f0.8_d45_878475 copying
# f0.65_d34_156923 copying
# f0.65_d34_313815 copying
# f0.65_d45_930493 copying
# f0.5_d34_440313 copying
# f0.65_d45_933003 copying
# f0.65_d45_370478 copying
# f0.65_d45_460991 copying
# f0.8_d45_233302 copying
# f0.5_d34_383162 copying
# f0.8_d34_163220 copying
# f0.5_d45_177283 copying
# f0.35_d45_171900 copying
# f0.65_d45_706503 copying
# f0.5_d45_362263 copying
# f0.8_d45_919843 copying
# f0.65_d45_395080 copying
# f0.65_d45_524162 copying
# f0.65_d45_423696 copying
# f0.8_d34_353958 copying
# f0.8_d34_110844 copying
# f0.35_d34_883419 copying
# f0.8_d45_376807 copying
# f0.65_d34_212675 copying
# f0.5_d45_451608 copying
# f0.5_d45_827848 copying
# f0.65_d45_682059 copying
# f0.8_d34_708244 copying
# f0.8_d34_989691 copying
# f0.65_d45_329712 copying
# f0.8_d45_317861 copying
# f0.35_d45_834839 copying
# f0.5_d45_949575 copying
# f0.5_d34_291044 copying
# f0.65_d34_689835 copying
# f0.65_d34_66346 copying
# f0.5_d34_251915 copying
# f0.65_d34_890405 copying
# f0.8_d34_470616 copying
# f0.8_d34_353837 copying
# f0.5_d45_369440 copying
# f0.5_d45_390000 copying
# f0.5_d45_784653 copying
# f0.65_d45_683710 copying
# f0.65_d45_821051 copying
# f0.35_d45_662116 copying
# f0.35_d45_667355 copying
# f0.5_d34_994155 copying
# f0.65_d45_280731 copying
# f0.8_d45_359018 copying
# f0.35_d34_615241 copying
# f0.8_d45_737927 copying
# f0.65_d45_429807 copying
# f0.5_d45_556333 copying
# f0.35_d34_379440 copying
# f0.65_d45_451213 copying
# f0.5_d45_787222 copying
# f0.8_d34_13668 copying
# f0.8_d45_272679 copying
# f0.5_d34_540562 copying
# f0.5_d45_678219 copying
# f0.65_d34_746233 copying
# f0.5_d45_557811 copying
# f0.35_d34_874155 copying
# f0.65_d34_890524 copying
# f0.65_d45_50583 copying
# f0.8_d34_970928 copying
# f0.5_d45_302780 copying
# f0.65_d34_212962 copying
# f0.8_d45_933732 copying
# f0.65_d34_324094 copying
# f0.65_d45_231800 copying
# f0.8_d34_182309 copying
# f0.8_d45_953671 copying
# f0.35_d34_344814 copying
# f0.35_d45_717531 copying
# f0.8_d34_420970 copying
# f0.8_d45_615156 copying
# f0.8_d45_782052 copying
# f0.5_d34_893478 copying
# f0.8_d34_314718 copying
# f0.5_d45_837040 copying
# f0.65_d34_244601 copying
# f0.8_d34_833186 copying
# f0.5_d45_600387 copying
# f0.65_d45_979197 copying
# f0.35_d34_211572 copying
# f0.8_d34_706989 copying
# f0.8_d45_41373 copying
# f0.65_d45_943476 copying
# f0.8_d34_878125 copying
# f0.5_d45_700562 copying
# f0.8_d34_115953 copying
# f0.35_d45_205735 copying
# f0.65_d45_807778 copying
# f0.65_d34_359402 copying
# f0.65_d23_478748 copying
# f0.8_d23_216566 copying
# f0.8_d34_381616 copying
# f0.8_d34_596193 copying
# f0.8_d45_171170 copying
# f0.2_d45_71843 copying
# f0.5_d45_825928 copying
# f0.5_d45_134829 copying
# f0.65_d45_236328 copying
# f0.8_d34_130044 copying
# f0.8_d45_668920 copying
# f0.35_d45_178770 copying
# f0.35_d45_343585 copying
# f0.65_d34_231126 copying
# f0.8_d34_206187 copying
# f0.8_d34_233069 copying
# f0.5_d45_510788 copying
# f0.5_d45_464554 copying
# f0.65_d34_874097 copying
# f0.8_d45_543931 copying
# f0.8_d45_136355 copying
# f0.8_d45_333387 copying
# f0.5_d34_397102 copying
# f0.5_d34_979904 copying
# f0.65_d34_548245 copying
# f0.65_d45_638347 copying
# f0.8_d34_564406 copying
# f0.8_d45_288722 copying
# f0.8_d45_614159 copying
# f0.65_d34_100127 copying
# f0.65_d45_556261 copying
# f0.2_d45_979040 copying
# f0.5_d34_156906 copying
# f0.65_d34_39351 copying
# f0.65_d45_246746 copying
# f0.35_d45_62768 copying
# f0.65_d45_398757 copying
# f0.65_d45_985461 copying
# f0.8_d34_297674 copying
# f0.5_d34_852821 copying
# f0.5_d45_364711 copying
# f0.5_d45_704607 copying
# f0.5_d45_616757 copying
# f0.35_d34_8748 copying
# f0.5_d45_999252 copying
# f0.65_d34_309427 copying
# f0.8_d45_162280 copying
# f0.2_d45_454198 copying
# f0.5_d34_949389 copying
# f0.65_d34_193773 copying
# f0.65_d34_553388 copying
# f0.65_d45_750145 copying
# f0.8_d34_973973 copying
# f0.35_d34_484542 copying
# f0.5_d45_992880 copying
# f0.65_d34_626208 copying
# f0.65_d45_983843 copying
# f0.8_d45_91540 copying
# f0.8_d45_794090 copying
# f0.5_d34_916861 copying
# f0.5_d45_483472 copying
# f0.5_d45_879125 copying
# f0.65_d45_279396 copying
# f0.5_d34_625595 copying
# f0.5_d45_299012 copying
# f0.65_d34_363664 copying
# f0.8_d45_674219 copying
# f0.2_d34_102805 copying
# f0.8_d34_587950 copying
# f0.35_d45_409768 copying
# f0.5_d45_915208 copying
# f0.5_d45_704749 copying
# f0.35_d45_312685 copying
# f0.5_d34_781781 copying
# f0.5_d34_565567 copying
# f0.35_d45_584473 copying
# f0.5_d45_900576 copying
# f0.65_d45_569712 copying
# f0.8_d34_204540 copying
# f0.8_d34_321160 copying
# f0.8_d45_413989 copying
# f0.8_d45_813335 copying
# f0.5_d34_520560 copying
# f0.5_d45_133084 copying
# f0.65_d34_132545 copying
# f0.8_d34_955257 copying
# f0.8_d34_546402 copying
# f0.5_d45_512234 copying
# f0.65_d34_629040 copying
# f0.65_d34_931073 copying
# f0.65_d34_494389 copying
# f0.5_d34_477950 copying
# f0.5_d45_678160 copying
# f0.5_d45_990212 copying
# f0.65_d34_451367 copying
# f0.65_d34_822261 copying
# f0.8_d45_92916 copying
# f0.5_d34_772270 copying
# f0.8_d34_55628 copying
# f0.65_d45_603126 copying
# f0.8_d34_92097 copying
# f0.5_d45_816844 copying
# f0.65_d23_563250 copying
# f0.65_d34_408134 copying
# f0.35_d45_61796 copying
# f0.65_d34_657336 copying
# f0.65_d34_879866 copying
# f0.8_d34_554651 copying
# f0.8_d45_573305 copying
# f0.65_d34_646142 copying
# f0.65_d34_873680 copying
# f0.65_d45_893836 copying
# f0.8_d45_430325 copying
# f0.2_d34_34063 copying
# f0.35_d45_530864 copying
# f0.65_d45_946695 copying
# f0.8_d34_724445 copying
# f0.35_d45_872746 copying
# f0.35_d45_247799 copying
# f0.35_d45_334643 copying
# f0.65_d34_483841 copying
# f0.65_d34_283460 copying
# f0.8_d34_291520 copying
# f0.8_d45_929270 copying
# f0.5_d34_858273 copying
# f0.65_d34_330679 copying
# f0.65_d34_282008 copying
# f0.65_d45_846469 copying
# f0.8_d34_819048 copying
# f0.35_d45_864321 copying
# f0.35_d45_190317 copying
# f0.65_d45_631977 copying
# f0.35_d45_755655 copying
# f0.5_d34_190277 copying
# f0.8_d45_249320 copying
# f0.35_d34_988044 copying
# f0.2_d34_208867 copying
# f0.35_d34_807318 copying
# f0.35_d45_554546 copying
# f0.5_d23_688982 copying
# f0.5_d45_438931 copying
# f0.8_d45_907188 copying
# f0.65_d45_932036 copying
# f0.8_d34_819255 copying
# f0.35_d45_92083 copying
# f0.35_d45_556938 copying
# f0.5_d45_194816 copying
# f0.65_d45_192457 copying
# f0.8_d45_170093 copying
# f0.8_d45_233943 copying
# f0.35_d45_946480 copying
# f0.35_d34_841554 copying
# f0.35_d45_487707 copying
# f0.35_d45_598211 copying
# f0.65_d34_992567 copying
# f0.65_d34_290013 copying
# f0.8_d34_595493 copying
# f0.65_d34_420877 copying
# f0.8_d45_423591 copying
# f0.8_d45_679815 copying
# f0.8_d45_116439 copying
# f0.2_d34_543039 copying
# f0.5_d45_488130 copying
# f0.5_d45_633335 copying
# f0.65_d34_229859 copying
# f0.65_d45_336981 copying
# f0.8_d34_600447 copying
# f0.2_d45_333791 copying
# f0.65_d34_935697 copying
# f0.8_d23_293308 copying
# f0.2_d45_205553 copying
# f0.65_d45_607042 copying
# f0.8_d45_724493 copying
# f0.35_d34_197360 copying
# f0.65_d34_562664 copying
# f0.65_d34_862836 copying
# f0.65_d45_893785 copying
# f0.35_d34_826702 copying
# f0.35_d45_486795 copying
# f0.35_d45_245001 copying
# f0.35_d45_151884 copying
# f0.65_d23_551913 copying
# f0.8_d45_398578 copying
# f0.8_d45_448384 copying
# f0.5_d34_473476 copying
# f0.5_d34_984726 copying
# f0.65_d45_703670 copying
# f0.65_d45_157536 copying
# f0.8_d34_241023 copying
# f0.8_d34_181254 copying
# f0.2_d34_728599 copying
# f0.5_d34_559669 copying
# f0.5_d45_459779 copying
# f0.65_d34_470351 copying
# f0.8_d45_305593 copying
# f0.8_d45_589870 copying
# f0.8_d45_939536 copying
# f0.5_d34_595878 copying
# f0.5_d45_123823 copying
# f0.2_d45_771042 copying
# f0.35_d34_340659 copying
# f0.65_d34_469454 copying
# f0.65_d34_418919 copying
# f0.8_d34_175279 copying
# f0.35_d45_681710 copying
# f0.8_d23_393886 copying
# f0.8_d23_21262 copying
# f0.8_d34_310959 copying
# f0.65_d45_797284 copying
# f0.8_d23_995819 copying
# f0.8_d34_708591 copying
# f0.35_d34_22318 copying
# f0.35_d45_274281 copying
# f0.65_d34_173452 copying
# f0.2_d45_75692 copying
# f0.35_d45_890112 copying
# f0.8_d45_634424 copying
# f0.2_d45_1177 copying
# f0.65_d23_868763 copying
# f0.2_d45_319811 copying
# f0.35_d45_126191 copying
# f0.5_d45_346465 copying
# f0.5_d45_667575 copying
# f0.65_d45_666021 copying
# f0.65_d45_511544 copying
# f0.8_d34_936475 copying
# f0.8_d45_457257 copying
# f0.2_d45_32226 copying
# f0.65_d45_750225 copying
# f0.8_d45_970801 copying
# f0.35_d23_433915 copying
# f0.5_d34_500652 copying
# f0.65_d34_324368 copying
# f0.65_d45_23634 copying
# f0.5_d34_802536 copying
# f0.5_d34_902487 copying
# f0.5_d34_390723 copying
# f0.65_d34_401852 copying
# f0.65_d45_102192 copying
# f0.35_d45_285019 copying
# f0.35_d45_764869 copying
# f0.5_d34_399091 copying
# f0.5_d45_93248 copying
# f0.65_d34_531564 copying
# f0.2_d34_850792 copying
# f0.5_d34_183556 copying
# f0.5_d45_900330 copying
# f0.65_d23_766307 copying
# f0.8_d34_197820 copying
# f0.8_d45_876889 copying
# f0.35_d34_420731 copying
# f0.35_d45_926049 copying
# f0.5_d45_499302 copying
# f0.5_d45_545372 copying
# f0.2_d45_881396 copying
# f0.5_d45_527274 copying
# f0.65_d34_291056 copying
# f0.2_d34_281830 copying
# f0.35_d45_943114 copying
# f0.65_d34_79301 copying
# f0.65_d34_233865 copying
# f0.2_d45_856522 copying
# f0.5_d34_18372 copying
# f0.8_d34_437329 copying
# f0.8_d45_372909 copying
# f0.8_d45_822940 copying
# f0.65_d34_317728 copying
# f0.8_d23_658167 copying
# f0.8_d45_130879 copying
# f0.35_d23_195017 copying
# f0.35_d34_424391 copying
# f0.5_d45_668486 copying
# f0.65_d45_166764 copying
# f0.8_d45_415190 copying
# f0.5_d45_26171 copying
# f0.35_d34_299414 copying
# f0.35_d45_172641 copying
# f0.65_d34_198089 copying
# f0.8_d34_460101 copying
# f0.2_d45_774513 copying
# f0.35_d45_186648 copying
# f0.5_d34_600279 copying
# f0.5_d34_9015 copying
# f0.8_d34_716276 copying
# f0.8_d45_123414 copying
# f0.65_d34_501150 copying
# f0.8_d34_843465 copying
# f0.2_d45_423967 copying
# f0.65_d45_121696 copying
# f0.35_d34_284840 copying
# f0.35_d34_952264 copying
# f0.35_d45_631965 copying
# f0.5_d34_936185 copying
# f0.5_d45_24403 copying
# f0.65_d34_321097 copying
# f0.8_d34_517758 copying
# f0.8_d34_746935 copying
# f0.8_d34_662756 copying
# f0.8_d45_6546 copying
# f0.35_d45_938169 copying
# f0.35_d45_446524 copying
# f0.5_d45_617899 copying
# f0.8_d34_783243 copying
# f0.2_d45_175246 copying
# f0.5_d45_246578 copying
# f0.65_d23_809878 copying
# f0.65_d34_202992 copying
# f0.65_d45_877208 copying
# f0.8_d34_641107 copying
# f0.2_d45_578613 copying
# f0.35_d34_673090 copying
# f0.35_d45_377099 copying
# f0.5_d34_686086 copying
# f0.65_d45_123829 copying
# f0.65_d45_583757 copying
# f0.8_d23_635042 copying
# f0.8_d34_332460 copying
# f0.8_d34_391450 copying
# f0.35_d34_264892 copying
# f0.5_d34_719566 copying
# f0.8_d45_184124 copying
# f0.2_d34_888184 copying
# f0.35_d23_339669 copying
# f0.35_d45_229672 copying
# f0.5_d34_759801 copying
# f0.5_d34_868761 copying
# f0.5_d45_459625 copying
# f0.8_d23_359896 copying
# f0.35_d34_834284 copying
# f0.5_d23_648780 copying
# f0.5_d34_357760 copying
# f0.2_d45_326102 copying
# f0.35_d23_696328 copying
# f0.5_d34_751853 copying
# f0.65_d45_327826 copying
# f0.2_d45_252157 copying
# f0.2_d45_83874 copying
# f0.5_d23_418872 copying
# f0.65_d34_798987 copying
# f0.8_d34_941463 copying
# f0.2_d45_915072 copying
# f0.35_d45_762190 copying
# f0.35_d45_497408 copying
# f0.8_d34_62940 copying
# f0.8_d34_256907 copying
# f0.8_d34_333682 copying
# f0.2_d34_166402 copying
# f0.8_d45_620520 copying
# f0.2_d45_817556 copying
# f0.8_d45_55898 copying
# f0.2_d34_456912 copying
# f0.35_d34_321116 copying
# f0.5_d34_70535 copying
# f0.65_d23_784885 copying
# f0.65_d45_200682 copying
# f0.2_d45_983531 copying
# f0.35_d45_805471 copying
# f0.5_d34_352096 copying
# f0.35_d23_840981 copying
# f0.35_d34_473058 copying
# f0.65_d23_2203 copying
# f0.65_d45_907608 copying
# f0.65_d45_948241 copying
# f0.65_d45_876318 copying
# f0.2_d45_413275 copying
# f0.35_d34_560141 copying
# f0.5_d23_917704 copying
# f0.5_d34_202516 copying
# f0.2_d34_236720 copying
# f0.5_d45_894131 copying
# f0.8_d23_839648 copying
# f0.35_d34_540445 copying
# f0.35_d34_72926 copying
# f0.35_d34_927153 copying
# f0.5_d34_164676 copying
# f0.65_d23_643708 copying
# f0.65_d23_306491 copying
# f0.35_d34_909698 copying
# f0.35_d34_271501 copying
# f0.35_d45_808701 copying
# f0.5_d45_665239 copying
# f0.8_d34_613727 copying
# f0.8_d45_50209 copying
# f0.35_d34_31522 copying
# f0.8_d23_646085 copying
# f0.2_d45_733934 copying
# f0.8_d34_354782 copying
# f0.2_d34_476642 copying
# f0.35_d45_243146 copying
# f0.8_d45_812082 copying
# f0.35_d45_259559 copying
# f0.5_d34_835826 copying
# f0.5_d34_767185 copying
# f0.8_d23_79697 copying
# f0.5_d23_357125 copying
# f0.5_d34_810288 copying
# f0.35_d34_621548 copying
# f0.35_d45_274956 copying
# f0.5_d34_178947 copying
# f0.35_d34_401918 copying
# f0.35_d45_441259 copying
# f0.8_d23_962721 copying
# f0.8_d34_405405 copying
# f0.35_d34_409951 copying
# f0.35_d34_121986 copying
# f0.35_d34_429688 copying
# f0.65_d23_17801 copying
# f0.8_d23_467491 copying
# f0.5_d34_372433 copying
# f0.65_d23_215956 copying
# f0.2_d45_616272 copying
# f0.35_d45_758809 copying
# f0.65_d23_67066 copying
# f0.8_d23_897580 copying
# f0.8_d45_593053 copying
# f0.2_d34_623486 copying
# f0.5_d45_821202 copying
# f0.65_d45_61838 copying
# f0.8_d23_558526 copying
# f0.2_d34_219163 copying
# f0.35_d34_359257 copying
# f0.65_d45_444395 copying
# f0.8_d45_684266 copying
# f0.2_d45_83867 copying
# f0.2_d45_827980 copying
# f0.2_d45_842473 copying
# f0.5_d23_391613 copying
# f0.65_d23_416990 copying
# f0.8_d23_932190 copying
# f0.2_d23_364781 copying
# f0.2_d45_511884 copying
# f0.2_d45_215495 copying
# f0.35_d34_936993 copying
# f0.5_d34_456638 copying
# f0.2_d34_512583 copying
# f0.65_d23_336534 copying
# f0.8_d45_99627 copying
# f0.2_d45_434784 copying
# f0.35_d34_538378 copying
# f0.8_d23_984698 copying
# f0.35_d23_415767 copying
# f0.35_d34_847358 copying
# f0.65_d23_979048 copying
# f0.8_d23_55240 copying
# f0.2_d45_881216 copying
# f0.8_d23_419742 copying
# f0.35_d34_353800 copying
# f0.65_d23_705067 copying
# f0.65_d34_268762 copying
# f0.35_d34_336307 copying
# f0.5_d23_610874 copying
# f0.5_d34_290828 copying
# f0.65_d45_472773 copying
# f0.2_d45_925281 copying
# f0.35_d45_856636 copying
# f0.5_d23_994964 copying
# f0.5_d23_746361 copying
# f0.2_d45_555615 copying
# f0.35_d45_507458 copying
# f0.5_d34_314573 copying
# f0.65_d23_176727 copying
# f0.65_d23_801773 copying
# f0.2_d34_681802 copying
# f0.2_d45_163729 copying
# f0.35_d34_313038 copying
# f0.35_d45_256234 copying
# f0.35_d45_130816 copying
# f0.35_d45_115294 copying
# f0.35_d34_148162 copying
# f0.65_d34_177651 copying
# f0.35_d23_49547 copying
# f0.65_d23_487087 copying
# f0.65_d34_137052 copying
# f0.8_d34_676812 copying
# f0.2_d34_419269 copying
# f0.35_d34_687017 copying
# f0.2_d45_619989 copying
# f0.8_d23_934322 copying
# f0.8_d34_680653 copying
# f0.35_d34_934884 copying
# f0.35_d34_294818 copying
# f0.65_d23_104191 copying
# f0.65_d23_560456 copying
# f0.65_d34_703979 copying
# f0.2_d34_190136 copying
# f0.2_d45_495920 copying
# f0.35_d34_918241 copying
# f0.65_d23_241591 copying
# f0.2_d23_441231 copying
# f0.2_d34_902585 copying
# f0.2_d45_468576 copying
# f0.8_d23_297962 copying
# f0.2_d34_995308 copying
# f0.2_d45_686354 copying
# f0.5_d34_426273 copying
# f0.8_d23_154478 copying
# f0.8_d45_915527 copying
# f0.2_d34_194133 copying
# f0.2_d45_745128 copying
# f0.2_d45_678601 copying
# f0.35_d34_278407 copying
# f0.5_d34_513711 copying
# f0.2_d45_737431 copying
# f0.35_d23_152965 copying
# f0.35_d34_600126 copying
# f0.35_d34_714081 copying
# f0.65_d23_928299 copying
# f0.65_d23_530191 copying
# f0.2_d45_157752 copying
# f0.5_d23_915936 copying
# f0.8_d23_598153 copying
# f0.2_d45_728166 copying
# f0.2_d34_767400 copying
# f0.2_d45_791581 copying
# f0.2_d45_934338 copying
# f0.35_d45_762326 copying
# f0.35_d45_466243 copying
# f0.65_d23_399318 copying
# f0.65_d23_393349 copying
# f0.2_d45_779161 copying
# f0.2_d45_79028 copying
# f0.35_d23_250730 copying
# f0.65_d23_516791 copying
# f0.2_d34_35892 copying
# f0.35_d34_709827 copying
# f0.5_d23_288691 copying
# f0.5_d34_110712 copying
# f0.5_d34_202210 copying
# f0.8_d23_796505 copying
# f0.2_d34_716125 copying
# f0.35_d45_731884 copying
# f0.5_d23_544638 copying
# f0.65_d23_169224 copying
# f0.2_d34_824860 copying
# f0.2_d45_445582 copying
# f0.35_d34_915454 copying
# f0.5_d34_504104 copying
# f0.2_d34_877323 copying
# f0.35_d45_575330 copying
# f0.5_d23_88002 copying
# f0.5_d45_877065 copying
# f0.65_d34_533288 copying
# f0.8_d23_230972 copying
# f0.2_d34_942948 copying
# f0.35_d45_494987 copying
# f0.8_d23_771646 copying
# f0.35_d23_850738 copying
# f0.35_d34_45424 copying
# f0.5_d34_245228 copying
# f0.5_d34_513751 copying
# f0.8_d23_366961 copying
# f0.8_d23_552336 copying
# f0.2_d23_630630 copying
# f0.35_d23_737778 copying
# f0.5_d23_528949 copying
# f0.8_d45_796106 copying
# f0.35_d34_683743 copying
# f0.35_d45_48367 copying
# f0.65_d23_131345 copying
# f0.35_d34_768094 copying
# f0.8_d23_203781 copying
# f0.2_d34_44889 copying
# f0.35_d34_153253 copying
# f0.8_d23_448414 copying
# f0.2_d45_502012 copying
# f0.35_d34_342348 copying
# f0.2_d34_570116 copying
# f0.5_d23_605244 copying
# f0.8_d23_357831 copying
# f0.8_d23_256746 copying
# f0.2_d34_910466 copying
# f0.8_d23_798452 copying
# f0.2_d45_477739 copying
# f0.65_d23_545334 copying
# f0.8_d23_709720 copying
# f0.2_d34_94831 copying
# f0.2_d45_599978 copying
# f0.2_d45_591573 copying
# f0.5_d45_593708 copying
# f0.5_d45_792211 copying
# f0.65_d23_253317 copying
# f0.2_d34_427510 copying
# f0.35_d34_855597 copying
# f0.35_d45_796710 copying
# f0.5_d23_193386 copying
# f0.5_d23_401233 copying
# f0.65_d34_981583 copying
# f0.8_d23_656062 copying
# f0.2_d34_565027 copying
# f0.35_d23_200156 copying
# f0.5_d34_491635 copying
# f0.65_d23_511693 copying
# f0.65_d23_141348 copying
# f0.8_d23_939743 copying
# f0.8_d23_48966 copying
# f0.2_d45_357946 copying
# f0.35_d34_482489 copying
# f0.65_d23_888555 copying
# f0.65_d23_365848 copying
# f0.5_d23_122692 copying
# f0.5_d34_827559 copying
# f0.5_d45_418083 copying
# f0.35_d34_625163 copying
# f0.35_d34_215856 copying
# f0.5_d23_770719 copying
# f0.8_d23_881846 copying
# f0.2_d45_971323 copying
# f0.2_d45_345318 copying
# f0.5_d23_597549 copying
# f0.8_d23_372529 copying
# f0.2_d34_439717 copying
# f0.2_d34_89854 copying
# f0.2_d34_327268 copying
# f0.8_d23_349786 copying
# f0.2_d45_130218 copying
# f0.35_d23_620524 copying
# f0.65_d23_89135 copying
# f0.2_d34_990021 copying
# f0.35_d23_61354 copying
# f0.5_d34_494240 copying
# f0.65_d23_329593 copying
# f0.65_d34_529992 copying
# f0.2_d34_480759 copying
# f0.65_d23_90722 copying
# f0.8_d23_588017 copying
# f0.2_d34_754846 copying
# f0.35_d34_390162 copying
# f0.5_d23_735887 copying
# f0.5_d23_655326 copying
# f0.65_d23_220719 copying
# f0.8_d23_545216 copying
# f0.8_d23_123534 copying
# f0.5_d23_282744 copying
# f0.5_d45_536466 copying
# f0.35_d23_662087 copying
# f0.2_d23_217453 copying
# f0.2_d23_422170 copying
# f0.8_d23_663369 copying
# f0.2_d45_296719 copying
# f0.8_d23_135045 copying
# f0.2_d34_362454 copying
# f0.2_d34_301776 copying
# f0.65_d45_169593 copying
# f0.8_d23_970626 copying
# f0.35_d23_751320 copying
# f0.2_d34_137875 copying
# f0.35_d23_406854 copying
# f0.35_d23_169243 copying
# f0.65_d23_765961 copying
# f0.2_d34_809847 copying
# f0.2_d34_434498 copying
# f0.35_d34_806495 copying
# f0.5_d23_53800 copying
# f0.2_d34_419672 copying
# f0.65_d23_113758 copying
# f0.65_d23_886333 copying
# f0.65_d23_803807 copying
# f0.65_d23_866823 copying
# f0.8_d23_928105 copying
# f0.5_d23_438772 copying
# f0.5_d34_948081 copying
# f0.65_d23_146121 copying
# f0.2_d34_923840 copying
# f0.35_d23_757383 copying
# f0.2_d34_539272 copying
# f0.35_d23_71505 copying
# f0.35_d34_350774 copying
# f0.5_d23_656932 copying
# f0.5_d23_452321 copying
# f0.2_d23_734815 copying
# f0.5_d23_883274 copying
# f0.5_d23_589473 copying
# f0.2_d34_11331 copying
# f0.5_d23_750613 copying
# f0.65_d23_460291 copying
# f0.2_d34_936113 copying
# f0.35_d23_488783 copying
# f0.8_d23_301473 copying
# f0.8_d23_667291 copying
# f0.2_d45_427030 copying
# f0.5_d23_772773 copying
# f0.8_d23_840702 copying
# f0.2_d23_917115 copying
# f0.2_d34_614632 copying
# f0.2_d34_555585 copying
# f0.5_d23_121968 copying
# f0.2_d34_354280 copying
# f0.2_d45_65740 copying
# f0.2_d34_130895 copying
# f0.35_d34_243451 copying
# f0.5_d23_683196 copying
# f0.5_d23_144083 copying
# f0.65_d23_621695 copying
# f0.8_d23_941420 copying
# f0.35_d23_915196 copying
# f0.2_d23_35732 copying
# f0.2_d45_24829 copying
# f0.35_d23_694397 copying
# f0.5_d23_565909 copying
# f0.65_d23_737540 copying
# f0.65_d23_623532 copying
# f0.5_d23_446158 copying
# f0.2_d45_661334 copying
# f0.35_d23_602688 copying
# f0.35_d45_785760 copying
# f0.8_d23_549258 copying
# f0.8_d23_275114 copying
# f0.2_d34_654836 copying
# f0.2_d34_2840 copying
# f0.2_d34_260971 copying
# f0.2_d45_793353 copying
# f0.2_d45_465934 copying
# f0.5_d23_619828 copying
# f0.5_d23_315224 copying
# f0.65_d23_970273 copying
# f0.8_d23_46951 copying
# f0.2_d45_734827 copying
# f0.2_d45_795691 copying
# f0.35_d23_733073 copying
# f0.35_d23_787296 copying
# f0.65_d23_958265 copying
# f0.8_d23_337490 copying
# f0.2_d34_573784 copying
# f0.2_d34_523084 copying
# f0.8_d23_476141 copying
# f0.8_d23_533862 copying
# f0.2_d23_552569 copying
# f0.8_d23_649749 copying
# f0.8_d23_349554 copying
# f0.5_d23_133713 copying
# f0.5_d23_586915 copying
# f0.2_d23_604526 copying
# f0.35_d23_320797 copying
# f0.5_d23_448144 copying
# f0.5_d23_713003 copying
# f0.2_d23_696748 copying
# f0.8_d23_370062 copying
# f0.2_d23_382589 copying
# f0.8_d23_385753 copying
# f0.2_d34_300287 copying
# f0.65_d23_981899 copying
# f0.2_d34_938661 copying
# f0.35_d23_725634 copying
# f0.5_d23_279564 copying
# f0.5_d23_424947 copying
# f0.35_d23_618709 copying
# f0.35_d23_190248 copying
# f0.35_d23_546911 copying
# f0.5_d23_741348 copying
# f0.65_d23_468578 copying
# f0.8_d23_128445 copying
# f0.8_d23_532640 copying
# f0.2_d34_799886 copying
# f0.2_d45_932245 copying
# f0.35_d23_172384 copying
# f0.2_d34_64604 copying
# f0.65_d23_737407 copying
# f0.8_d23_322944 copying
# f0.2_d23_83876 copying
# f0.2_d23_41101 copying
# f0.5_d23_406160 copying
# f0.8_d23_196525 copying
# f0.35_d23_193739 copying
# f0.8_d23_668873 copying
# f0.8_d23_526000 copying
# f0.5_d23_278502 copying
# f0.2_d23_287727 copying
# f0.5_d23_162673 copying
# f0.65_d23_764252 copying
# f0.35_d23_998862 copying
# f0.35_d23_139950 copying
# f0.5_d23_219130 copying
# f0.8_d23_755923 copying
# f0.8_d23_483675 copying
# f0.2_d34_848579 copying
# f0.65_d23_946738 copying
# f0.2_d23_101781 copying
# f0.2_d34_774770 copying
# f0.5_d23_982372 copying
# f0.2_d34_989108 copying
# f0.5_d23_648671 copying
# f0.2_d23_767367 copying
# f0.2_d34_163738 copying
# f0.35_d23_317067 copying
# f0.8_d23_990888 copying
# f0.65_d23_467977 copying
# f0.5_d23_492387 copying
# f0.2_d23_172242 copying
# f0.65_d23_53164 copying
# f0.2_d23_134692 copying
# f0.8_d23_566091 copying
# f0.5_d23_22446 copying
# f0.8_d23_560977 copying
# f0.2_d23_204966 copying
# f0.65_d23_940297 copying
# f0.35_d23_167812 copying
# f0.5_d23_111112 copying
# f0.65_d23_824796 copying
# f0.2_d23_976406 copying
# f0.8_d23_362342 copying
# f0.35_d23_732936 copying
# f0.5_d23_403752 copying
# f0.2_d23_3273 copying
# f0.35_d23_922946 copying
# f0.2_d23_417260 copying
# f0.65_d23_946927 copying
# f0.35_d23_941617 copying
# f0.8_d23_247442 copying
# f0.8_d23_322549 copying
# f0.35_d23_323664 copying
# f0.35_d23_750611 copying
# f0.2_d23_803733 copying
# f0.5_d23_29825 copying
# f0.2_d34_167931 copying
# f0.65_d23_760298 copying
# f0.8_d23_128830 copying
# f0.35_d23_728248 copying
# f0.35_d23_886516 copying
# f0.5_d23_392944 copying
# f0.2_d23_412964 copying
# f0.35_d23_234893 copying
# f0.35_d23_536320 copying
# f0.65_d23_757914 copying
# f0.35_d23_523346 copying
# f0.35_d23_197063 copying
# f0.8_d23_242835 copying
# f0.8_d23_742587 copying
# f0.2_d23_408371 copying
# f0.8_d23_812169 copying
# f0.2_d23_123349 copying
# f0.2_d23_676104 copying
# f0.35_d23_671092 copying
# f0.35_d23_80952 copying
# f0.65_d23_504607 copying
# f0.2_d23_858659 copying
# f0.35_d23_645450 copying
# f0.35_d23_569284 copying
# f0.5_d23_660959 copying
# f0.5_d23_74347 copying
# f0.65_d23_323423 copying
# f0.35_d23_2462 copying
# f0.5_d23_806137 copying
# f0.2_d23_711578 copying
# f0.35_d23_679271 copying
# f0.35_d23_855708 copying
# f0.2_d23_911892 copying
# f0.2_d23_433994 copying
# f0.35_d23_449070 copying
# f0.2_d23_792673 copying
# f0.2_d23_555847 copying
# f0.2_d23_161769 copying
# f0.2_d23_246951 copying
# f0.2_d23_856159 copying
# f0.35_d23_490891 copying
# f0.5_d23_311954 copying
# f0.5_d23_524351 copying
# f0.2_d23_734253 copying
# f0.8_d23_145291 copying
# f0.2_d23_883183 copying
# f0.5_d23_151382 copying
# f0.35_d23_757324 copying
# f0.2_d23_224393 copying
# f0.35_d23_119420 copying
# f0.5_d23_440182 copying
# f0.8_d23_592123 copying
# f0.2_d23_186349 copying
# f0.2_d23_279589 copying
# f0.2_d23_986410 copying
# f0.35_d23_731009 copying
# f0.35_d23_477711 copying
# f0.2_d23_5363 copying
# f0.35_d23_528244 copying
# f0.2_d23_394332 copying
# f0.5_d23_771900 copying
# f0.2_d23_328989 copying
# f0.5_d23_739642 copying
# f0.2_d23_904621 copying
# f0.2_d23_374099 copying
# f0.2_d23_233917 copying
# f0.2_d23_679519 copying
# f0.65_d23_945342 copying
# f0.35_d23_462235 copying
# f0.35_d23_260624 copying
# f0.2_d23_871590 copying
# f0.2_d23_760827 copying

# %%
masks_w_ap

# %%
masks_w_ap.sort(key=lambda x: -x[3])

# %%
masks_w_ap

# %%
import pandas as pd
df_metrics = pd.DataFrame(masks_w_ap, 
                          columns = ['Name_id','Params','FLOPs','AP']) 
df_metrics.describe([.05, .25, .5, .75, .95])

# %%
df_sort = df_metrics.sort_values(by=['AP'] , ascending=False )

# %%
df_sort.tail(50)

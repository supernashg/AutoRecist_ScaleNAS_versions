# %%
import os
import numpy as np
import pydicom

import pandas as pd
import sys
sys.path.append('/mnt/fast-disk1/mjc/utils_codes/read_weasis_raw_v0.96/')

import weasis_raw_data_api as wr
sys.path.append('/mnt/fast-disk1/mjc/utils_codes/')
from utils_test import *
from utils_metrics_3d import *

D_dir2header_df = {}
def get_dicom_header_df(image_dir , labels = []):
    global D_dir2header_df
    if image_dir in D_dir2header_df:
        return D_dir2header_df[image_dir]

    # image_dir = row['Image File Path']


    labels = ['ImageName','InstanceNumber',
            'BitsAllocated', 'BitsStored', 'Columns', 'HighBit', 
            'ImageOrientationPatient_0', 'ImageOrientationPatient_1', 'ImageOrientationPatient_2',
            'ImageOrientationPatient_3', 'ImageOrientationPatient_4', 'ImageOrientationPatient_5',
            'ImagePositionPatient_0', 'ImagePositionPatient_1', 'ImagePositionPatient_2',
            'Modality', 'PatientID', 'PhotometricInterpretation', 'PixelRepresentation',
            'PixelSpacing_0', 'PixelSpacing_1', 'RescaleIntercept', 'RescaleSlope', 'Rows', 'SOPInstanceUID',
            'SamplesPerPixel', 'SeriesInstanceUID', 'StudyID', 'StudyInstanceUID', 
            'WindowCenter', 'WindowWidth', 
        ] if not labels else labels

    data = {l: [] for l in labels}
    
    ctList = os.listdir(image_dir)
    ctList.sort()

    for image in ctList:
        if '.dcm' not in image:
            continue
        if os.path.getsize(os.path.join(image_dir, image)) < 5*1024:
            print('%s size < 5kb skiped!'%os.path.join(image_dir, image) )
            continue
        data["ImageName"].append(image)

        ds = pydicom.dcmread(os.path.join(image_dir, image))
        for metadata in ds.dir():
            if metadata not in data and metadata not in ['ImageOrientationPatient','ImagePositionPatient','PixelSpacing']:
                continue
            if metadata != "PixelData":
                metadata_values = getattr(ds, metadata)
                if type(metadata_values) == pydicom.multival.MultiValue and metadata not in ["WindowCenter", "WindowWidth"]:
                    for i, v in enumerate(metadata_values):
                        data[f"{metadata}_{i}"].append(v)  
                else:

                    if type(metadata_values) == pydicom.multival.MultiValue and metadata in ["WindowCenter", "WindowWidth"]:
                        data[metadata].append(metadata_values[0])
                    else:
                        
                        if metadata in ['ImageOrientationPatient','ImagePositionPatient','PixelSpacing']:
                            print( 'error of loading key: {}'.format(metadata) )                    
                        else:
                            data[metadata].append(metadata_values)

    df_image = pd.DataFrame(data).set_index("InstanceNumber")
    D_dir2header_df[image_dir] = df_image
    return df_image

# %%
def pd_str_replace(df , col, ori, new):
    if isinstance(col , str):
        try:
            df[col] = df[col].str.replace(ori,new, case = False) 
        except:
            pass
            
    elif isinstance(col, list):
        for one in col:
            pd_str_replace(df , one, ori, new)
    else:
        raise('col instance should be str or list')


def str_Xdrive2mnt(df_all):
    pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], "X:" , "/mnt/Y-drive")
    pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], r"\\" , "/")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrials/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrialDone/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
    pd_str_replace(df_all, ['Image File Path'], "/mnt/Y-drive/ClinicalTrials", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")

    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw/PDS_AUTO_RECIST_Modified_By_Yen",
    "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw/PDS_AUTO_RECIST_Modified_By_Yen")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw/PDS_AUTO_RECIST", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw/PDS_AUTO_RECIST_RAW")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToRaw", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")
    pd_str_replace(df_all, ['Contour File Path'], "/mnt/Y-drive/ConvWeasisToMatlab", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")
    
def get_onect_from_list(df_list , ct):
    for i, df in enumerate(df_list):
        try:
            df_ct = df[ (df["Image File Path"]==ct) & (df['Location'].isin(['liver'])) ]
        except KeyError:
            df_ct = df[ (df["Image File Path"]==ct)]
        if df_ct.shape[0]:
            return df_ct , i
    print("warning! no CT was found")
    return None ,None

def raws2mask(raws , D_z_index, mask_vol = None):

    for raw in raws:

        radiologist_raw = wr.read(raw)
        slice_list = radiologist_raw.get_instance_number_array()
        if mask_vol is None:
            mask_vol = initialize_mask_vol(radiologist_raw , D_z_index)
        for j, one in enumerate(slice_list):
            mask = radiologist_raw.get_mask_image(j)
            mask_vol[D_z_index[one]] += mask
    return mask_vol

# %%
folder = '/mnt/fast-data/mjc/AutoRECIST/Inputs/'



df_CTs = pd.read_excel(folder+'AutoRECIST_List_LesionSize_20220602_JM_SingleCTSeries.xlsx')
str_Xdrive2mnt(df_CTs)


df_Yen = pd.read_excel(folder+'PDS_AUTO_RECIST CIA-LAB Testing Dataset Gold Standard_Yen_2022-06-13.xlsx')
str_Xdrive2mnt(df_Yen)

AI_raw_list = ['ScaleNAS9SliceToRaw_Test353.csv',]
df_AIs = []
for one in AI_raw_list:
    df = pd.read_csv(one)
    str_Xdrive2mnt(df)
    df_AIs.append(df)




Metrics_vol = []
metrics_save_path = 'Metrics_%s_vs_Yen353pts.csv'%'ScaleNAS9Slices'
CTs = df_CTs["Image File Path"].values.tolist()
import time
for ct in CTs:
    t = time.time()
    df_image = get_dicom_header_df( ct )
    instanceNumber_list = df_image.index.to_list()
    D_z_index = instanceNumber2Matrix_z_index(instanceNumber_list)


    df_ct_Yen = df_Yen[df_Yen["Image File Path"]==ct]
    df_ct_AI , dataset_id = get_onect_from_list(df_AIs , ct)
    # break
    if (df_ct_AI is None):
        if df_ct_Yen.shape[0]:
            fn = df_ct_Yen.shape[0]
            print('{} has {} FNs!'.format(ct , fn))   
        continue

    if not df_ct_Yen.shape[0]:
        fp = df_ct_AI.shape[0]
        print( '{} has {} FPs'.format(ct , fp)  )
        continue
    else:
        print(ct)

    raws = df_ct_AI["Contour File Path"].values.tolist()
    
    elapsed = time.time() - t
    print('raws time cost is {} sec'.format(elapsed) )
    
    vol_pred = raws2mask(raws , D_z_index, mask_vol = None)
    elapsed = time.time() - t
    print('vol_pred time cost is {} sec'.format(elapsed) )
    connectivity = 2
    from skimage import measure
    labels_pred=measure.label(vol_pred,connectivity=connectivity)
    l_pred,c_pred = np.unique(labels_pred , return_counts=True)
    ix2 = l_pred>0
    l_pred = l_pred[ix2] #background pixels are labeled as 0, so we exclude them
    c_pred = c_pred[ix2]
    if len(l_pred)!= len(raws):
        print("warning! raws overlaped on {}".format(ct))
    elapsed = time.time() - t
    print('c_pred time cost is {} sec'.format(elapsed) )

    for _ , row in df_ct_Yen.iterrows():
        t = time.time()
        Yen_raw = wr.read(row['Contour File Path'])
        gt_vol = initialize_mask_vol(Yen_raw , D_z_index)
        

        slice_list = Yen_raw.get_instance_number_array()
        for j, one in enumerate(slice_list):
            mask = Yen_raw.get_mask_image(j)
            gt_vol[D_z_index[one]] = mask
        elapsed = time.time() - t
        print('gt_vol time cost is {} sec'.format(elapsed) )
        hit = vols_seg_results(gt_vol , vol_pred, CTname=row['Contour File Path'], gt_keep_largest=1)
        Metrics_vol.extend(hit)
        elapsed = time.time() - t
        print('vols_seg_results time cost is {} sec'.format(elapsed) )

#         _n = len(Metrics_vol)
#         if _n%100==0 or _n in [1,2,5,10,30,50]:
#             df_metrics = pd.DataFrame(Metrics_vol, 
#                                     columns = ['file_name','igt','merge','#gt','#pred',
#                                                 'iou_score', 'dice_score', 'over_seg' , 'under_seg',
#                                                 'area_gt','area_pred','intersection','union']) 
#             df_metrics.to_csv(metrics_save_path)
# Out:
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0002/D2019_01_02/E1326/CT/S0007_3337
# raws time cost is 0.3735804557800293 sec
# vol_pred time cost is 0.3861560821533203 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0002/D2019_01_02/E1326/CT/S0007_3337
# c_pred time cost is 1.8347127437591553 sec
# gt_vol time cost is 0.0034494400024414062 sec
# vols_seg_results time cost is 7.1484456062316895 sec
# gt_vol time cost is 0.0024390220642089844 sec
# vols_seg_results time cost is 7.035311222076416 sec
# gt_vol time cost is 0.005133867263793945 sec
# vols_seg_results time cost is 7.253568649291992 sec
# gt_vol time cost is 0.002465963363647461 sec
# vols_seg_results time cost is 7.195111513137817 sec
# gt_vol time cost is 0.005255460739135742 sec
# vols_seg_results time cost is 7.104291200637817 sec
# gt_vol time cost is 0.0031404495239257812 sec
# vols_seg_results time cost is 7.166154384613037 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0003/D2019_10_07/E2122/CT/S0002_2131
# raws time cost is 0.40085792541503906 sec
# vol_pred time cost is 0.4109377861022949 sec
# c_pred time cost is 1.6876606941223145 sec
# gt_vol time cost is 0.0019884109497070312 sec
# vols_seg_results time cost is 5.6568989753723145 sec
# gt_vol time cost is 0.0016858577728271484 sec
# vols_seg_results time cost is 5.641864061355591 sec
# gt_vol time cost is 0.005751371383666992 sec
# vols_seg_results time cost is 5.702888011932373 sec
# gt_vol time cost is 0.0038022994995117188 sec
# vols_seg_results time cost is 5.651336193084717 sec
# gt_vol time cost is 0.005272388458251953 sec
# vols_seg_results time cost is 5.658361911773682 sec
# gt_vol time cost is 0.0019659996032714844 sec
# vols_seg_results time cost is 5.544666290283203 sec
# gt_vol time cost is 0.0056972503662109375 sec
# vols_seg_results time cost is 5.702205419540405 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0004/D2019_03_04/E9409/CT/S0016_5317
# raws time cost is 0.2105543613433838 sec
# vol_pred time cost is 0.22696352005004883 sec
# c_pred time cost is 0.8825480937957764 sec
# gt_vol time cost is 0.00744938850402832 sec
# vols_seg_results time cost is 2.4106953144073486 sec
# gt_vol time cost is 0.009149312973022461 sec
# vols_seg_results time cost is 2.415060043334961 sec
# gt_vol time cost is 0.0028076171875 sec
# vols_seg_results time cost is 2.4437685012817383 sec
# gt_vol time cost is 0.0034346580505371094 sec
# vols_seg_results time cost is 2.378816843032837 sec
# gt_vol time cost is 0.0030112266540527344 sec
# vols_seg_results time cost is 2.3940324783325195 sec
# gt_vol time cost is 0.004078388214111328 sec
# vols_seg_results time cost is 2.4524354934692383 sec
# gt_vol time cost is 0.0038843154907226562 sec
# vols_seg_results time cost is 2.38657808303833 sec
# gt_vol time cost is 0.0030210018157958984 sec
# vols_seg_results time cost is 2.4035825729370117 sec
# gt_vol time cost is 0.0035974979400634766 sec
# vols_seg_results time cost is 2.4679505825042725 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0006/D2018_12_11/E8314/CT/S0002_5268
# raws time cost is 0.5064034461975098 sec
# vol_pred time cost is 0.5315132141113281 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0006/D2018_12_11/E8314/CT/S0002_5268
# c_pred time cost is 2.155409812927246 sec
# gt_vol time cost is 0.010115861892700195 sec
# vols_seg_results time cost is 18.829993724822998 sec
# gt_vol time cost is 0.0044367313385009766 sec
# vols_seg_results time cost is 18.504299879074097 sec
# gt_vol time cost is 0.0051424503326416016 sec
# vols_seg_results time cost is 18.41442036628723 sec
# gt_vol time cost is 0.0025048255920410156 sec
# vols_seg_results time cost is 18.548625946044922 sec
# gt_vol time cost is 0.0029129981994628906 sec
# vols_seg_results time cost is 18.901688814163208 sec
# gt_vol time cost is 0.002426624298095703 sec
# vols_seg_results time cost is 18.52996277809143 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0008/D2019_12_19/E2450/CT/S0002_7253
# raws time cost is 0.4950113296508789 sec
# vol_pred time cost is 0.5154299736022949 sec
# c_pred time cost is 2.2829360961914062 sec
# gt_vol time cost is 0.0021903514862060547 sec
# vols_seg_results time cost is 7.203500032424927 sec
# gt_vol time cost is 0.0021033287048339844 sec
# vols_seg_results time cost is 7.2304394245147705 sec
# gt_vol time cost is 0.0025932788848876953 sec
# vols_seg_results time cost is 7.251920938491821 sec
# gt_vol time cost is 0.007018566131591797 sec
# vols_seg_results time cost is 7.31697940826416 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0009/D2020_01_22/E0578/CT/S0018_3927
# raws time cost is 0.9660561084747314 sec
# vol_pred time cost is 0.9728372097015381 sec
# c_pred time cost is 4.125774145126343 sec
# gt_vol time cost is 0.0029380321502685547 sec
# vols_seg_results time cost is 10.014668941497803 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0019/D2020_01_07/E8279/CT/S0005_2496
# raws time cost is 0.8954451084136963 sec
# vol_pred time cost is 0.9437761306762695 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0019/D2020_01_07/E8279/CT/S0005_2496
# c_pred time cost is 4.173695087432861 sec
# gt_vol time cost is 0.005656242370605469 sec
# vols_seg_results time cost is 39.283883810043335 sec
# gt_vol time cost is 0.003134489059448242 sec
# vols_seg_results time cost is 39.35824251174927 sec
# gt_vol time cost is 0.003197193145751953 sec
# vols_seg_results time cost is 37.899128913879395 sec
# gt_vol time cost is 0.003646373748779297 sec
# vols_seg_results time cost is 38.551337003707886 sec
# gt_vol time cost is 0.00402522087097168 sec
# vols_seg_results time cost is 38.07399868965149 sec
# gt_vol time cost is 0.004121541976928711 sec
# vols_seg_results time cost is 37.23751664161682 sec
# gt_vol time cost is 0.004393100738525391 sec
# vols_seg_results time cost is 39.122666358947754 sec
# gt_vol time cost is 0.007095813751220703 sec
# vols_seg_results time cost is 37.219398498535156 sec
# gt_vol time cost is 0.004251718521118164 sec
# vols_seg_results time cost is 37.027584075927734 sec
# gt_vol time cost is 0.0037381649017333984 sec
# vols_seg_results time cost is 39.37990689277649 sec
# gt_vol time cost is 0.012759685516357422 sec
# vols_seg_results time cost is 38.51710224151611 sec
# gt_vol time cost is 0.006232261657714844 sec
# vols_seg_results time cost is 37.247350215911865 sec
# gt_vol time cost is 0.0029757022857666016 sec
# vols_seg_results time cost is 40.39338803291321 sec
# gt_vol time cost is 0.003396272659301758 sec
# vols_seg_results time cost is 38.51409935951233 sec
# gt_vol time cost is 0.008181571960449219 sec
# vols_seg_results time cost is 39.05109405517578 sec
# gt_vol time cost is 0.0032570362091064453 sec
# vols_seg_results time cost is 43.665313482284546 sec
# gt_vol time cost is 0.003905773162841797 sec
# vols_seg_results time cost is 45.76451015472412 sec
# gt_vol time cost is 0.004282236099243164 sec
# vols_seg_results time cost is 44.999746322631836 sec
# gt_vol time cost is 0.014857769012451172 sec
# vols_seg_results time cost is 45.60268020629883 sec
# gt_vol time cost is 0.005751609802246094 sec
# vols_seg_results time cost is 46.39942026138306 sec
# gt_vol time cost is 0.00400996208190918 sec
# vols_seg_results time cost is 45.95413684844971 sec
# gt_vol time cost is 0.005318880081176758 sec
# vols_seg_results time cost is 45.36748218536377 sec
# gt_vol time cost is 0.002649068832397461 sec
# vols_seg_results time cost is 44.965412855148315 sec
# gt_vol time cost is 0.0029375553131103516 sec
# vols_seg_results time cost is 44.7003653049469 sec
# gt_vol time cost is 0.003175020217895508 sec
# vols_seg_results time cost is 46.61606001853943 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0020/D2019_01_09/E2250/CT/S0005_1575
# raws time cost is 0.6888482570648193 sec
# vol_pred time cost is 0.7328948974609375 sec
# c_pred time cost is 2.9747090339660645 sec
# gt_vol time cost is 0.005891323089599609 sec
# vols_seg_results time cost is 19.6090247631073 sec
# gt_vol time cost is 0.007176876068115234 sec
# vols_seg_results time cost is 19.921507835388184 sec
# gt_vol time cost is 0.004026889801025391 sec
# vols_seg_results time cost is 20.223628520965576 sec
# gt_vol time cost is 0.0028617382049560547 sec
# vols_seg_results time cost is 19.200708389282227 sec
# gt_vol time cost is 0.0043027400970458984 sec
# vols_seg_results time cost is 19.835174322128296 sec
# gt_vol time cost is 0.0038576126098632812 sec
# vols_seg_results time cost is 19.403026342391968 sec
# gt_vol time cost is 0.013644933700561523 sec
# vols_seg_results time cost is 19.65104913711548 sec
# gt_vol time cost is 0.003454923629760742 sec
# vols_seg_results time cost is 20.033101797103882 sec
# gt_vol time cost is 0.003398418426513672 sec
# vols_seg_results time cost is 20.17870020866394 sec
# gt_vol time cost is 0.00337982177734375 sec
# vols_seg_results time cost is 19.28462314605713 sec
# gt_vol time cost is 0.003737211227416992 sec
# vols_seg_results time cost is 19.153436183929443 sec
# gt_vol time cost is 0.0036468505859375 sec
# vols_seg_results time cost is 19.898125648498535 sec
# gt_vol time cost is 0.003034830093383789 sec
# vols_seg_results time cost is 19.58906865119934 sec
# gt_vol time cost is 0.0028274059295654297 sec
# vols_seg_results time cost is 18.847706079483032 sec
# gt_vol time cost is 0.007942914962768555 sec
# vols_seg_results time cost is 20.01276659965515 sec
# gt_vol time cost is 0.003782987594604492 sec
# vols_seg_results time cost is 19.170826196670532 sec
# gt_vol time cost is 0.004445791244506836 sec
# vols_seg_results time cost is 20.200201749801636 sec
# gt_vol time cost is 0.002628803253173828 sec
# vols_seg_results time cost is 19.31742238998413 sec
# gt_vol time cost is 0.0024423599243164062 sec
# vols_seg_results time cost is 19.432782888412476 sec
# gt_vol time cost is 0.0037479400634765625 sec
# vols_seg_results time cost is 19.27608370780945 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0024/D2018_11_26/E0507/CT/S0006_5482
# raws time cost is 0.384260892868042 sec
# vol_pred time cost is 0.3883528709411621 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0024/D2018_11_26/E0507/CT/S0006_5482
# c_pred time cost is 1.689159870147705 sec
# gt_vol time cost is 0.006203413009643555 sec
# vols_seg_results time cost is 4.800635814666748 sec
# gt_vol time cost is 0.0023005008697509766 sec
# vols_seg_results time cost is 4.84234881401062 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0026/D2019_04_12/E3925/CT/S0006_9366
# raws time cost is 0.4352085590362549 sec
# vol_pred time cost is 0.4441344738006592 sec
# c_pred time cost is 1.8126060962677002 sec
# gt_vol time cost is 0.006241321563720703 sec
# vols_seg_results time cost is 4.809981346130371 sec
# gt_vol time cost is 0.005660295486450195 sec
# vols_seg_results time cost is 4.940033674240112 sec
# gt_vol time cost is 0.016240835189819336 sec
# vols_seg_results time cost is 4.994350910186768 sec
# gt_vol time cost is 0.009409904479980469 sec
# vols_seg_results time cost is 5.075756788253784 sec
# gt_vol time cost is 0.01271510124206543 sec
# vols_seg_results time cost is 4.961155652999878 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0028/D2019_07_12/E6851/CT/S0006_8606
# raws time cost is 0.41268157958984375 sec
# vol_pred time cost is 0.44948863983154297 sec
# c_pred time cost is 1.7650971412658691 sec
# gt_vol time cost is 0.011615753173828125 sec
# vols_seg_results time cost is 9.09643268585205 sec
# gt_vol time cost is 0.00580906867980957 sec
# vols_seg_results time cost is 9.3807692527771 sec
# gt_vol time cost is 0.0031003952026367188 sec
# vols_seg_results time cost is 9.506067037582397 sec
# gt_vol time cost is 0.0055577754974365234 sec
# vols_seg_results time cost is 9.188162565231323 sec
# gt_vol time cost is 0.003185272216796875 sec
# vols_seg_results time cost is 8.955209970474243 sec
# gt_vol time cost is 0.004429817199707031 sec
# vols_seg_results time cost is 9.006875991821289 sec
# gt_vol time cost is 0.006409645080566406 sec
# vols_seg_results time cost is 9.167800426483154 sec
# gt_vol time cost is 0.0030128955841064453 sec
# vols_seg_results time cost is 9.233880996704102 sec
# gt_vol time cost is 0.005597591400146484 sec
# vols_seg_results time cost is 9.006173133850098 sec
# gt_vol time cost is 0.0028328895568847656 sec
# vols_seg_results time cost is 9.194779396057129 sec
# gt_vol time cost is 0.013247013092041016 sec
# vols_seg_results time cost is 9.230653047561646 sec
# gt_vol time cost is 0.0018682479858398438 sec
# vols_seg_results time cost is 8.801268577575684 sec
# gt_vol time cost is 0.005548715591430664 sec
# vols_seg_results time cost is 8.802608013153076 sec
# gt_vol time cost is 0.0024514198303222656 sec
# vols_seg_results time cost is 9.009147644042969 sec
# gt_vol time cost is 0.010912656784057617 sec
# vols_seg_results time cost is 9.042043209075928 sec
# gt_vol time cost is 0.0027022361755371094 sec
# vols_seg_results time cost is 8.992255449295044 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0033/D2018_10_24/E0816/CT/S0002_0822
# raws time cost is 0.381014347076416 sec
# vol_pred time cost is 0.38763904571533203 sec
# c_pred time cost is 1.839688777923584 sec
# gt_vol time cost is 0.008342742919921875 sec
# vols_seg_results time cost is 4.877685785293579 sec
# gt_vol time cost is 0.0064373016357421875 sec
# vols_seg_results time cost is 4.9154908657073975 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0036/D2018_11_30/E2803/CT/S0003_5983
# raws time cost is 2.380592107772827 sec
# vol_pred time cost is 2.3987858295440674 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0036/D2018_11_30/E2803/CT/S0003_5983
# c_pred time cost is 10.685641288757324 sec
# gt_vol time cost is 0.008788347244262695 sec
# vols_seg_results time cost is 33.41360592842102 sec
# gt_vol time cost is 0.005647182464599609 sec
# vols_seg_results time cost is 35.338080644607544 sec
# gt_vol time cost is 0.004968166351318359 sec
# vols_seg_results time cost is 33.99683666229248 sec
# gt_vol time cost is 0.005068540573120117 sec
# vols_seg_results time cost is 35.25360441207886 sec
# gt_vol time cost is 0.0035440921783447266 sec
# vols_seg_results time cost is 33.10990810394287 sec
# gt_vol time cost is 0.0042307376861572266 sec
# vols_seg_results time cost is 35.702622413635254 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0038/D2018_11_08/E1856/CT/S0004_9015
# raws time cost is 0.4633312225341797 sec
# vol_pred time cost is 0.48204898834228516 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0038/D2018_11_08/E1856/CT/S0004_9015
# c_pred time cost is 1.7519629001617432 sec
# gt_vol time cost is 0.00957942008972168 sec
# vols_seg_results time cost is 7.636877775192261 sec
# gt_vol time cost is 0.010390520095825195 sec
# vols_seg_results time cost is 7.473731994628906 sec
# gt_vol time cost is 0.004968166351318359 sec
# vols_seg_results time cost is 7.660507440567017 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0040/D2018_12_25/E0028/CT/S0004_3920
# raws time cost is 0.7651760578155518 sec
# vol_pred time cost is 0.8275110721588135 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0040/D2018_12_25/E0028/CT/S0004_3920
# c_pred time cost is 3.4813640117645264 sec
# gt_vol time cost is 0.002516031265258789 sec
# vols_seg_results time cost is 51.25016403198242 sec
# gt_vol time cost is 0.012065649032592773 sec
# vols_seg_results time cost is 50.47357106208801 sec
# gt_vol time cost is 0.004082202911376953 sec
# vols_seg_results time cost is 48.1613986492157 sec
# gt_vol time cost is 0.003929853439331055 sec
# vols_seg_results time cost is 50.82785415649414 sec
# gt_vol time cost is 0.00974273681640625 sec
# vols_seg_results time cost is 52.0832884311676 sec
# gt_vol time cost is 0.004913330078125 sec
# vols_seg_results time cost is 52.798951864242554 sec
# gt_vol time cost is 0.0031671524047851562 sec
# vols_seg_results time cost is 53.246291637420654 sec
# gt_vol time cost is 0.0045452117919921875 sec
# vols_seg_results time cost is 44.583059310913086 sec
# gt_vol time cost is 0.0047075748443603516 sec
# vols_seg_results time cost is 42.32960319519043 sec
# gt_vol time cost is 0.0052433013916015625 sec
# vols_seg_results time cost is 43.190507888793945 sec
# gt_vol time cost is 0.004742860794067383 sec
# vols_seg_results time cost is 43.94835543632507 sec
# gt_vol time cost is 0.0034401416778564453 sec
# vols_seg_results time cost is 42.58093309402466 sec
# gt_vol time cost is 0.006827831268310547 sec
# vols_seg_results time cost is 42.26578187942505 sec
# gt_vol time cost is 0.0029108524322509766 sec
# vols_seg_results time cost is 42.50256824493408 sec
# gt_vol time cost is 0.0029158592224121094 sec
# vols_seg_results time cost is 42.68832278251648 sec
# gt_vol time cost is 0.002858400344848633 sec
# vols_seg_results time cost is 43.19970726966858 sec
# gt_vol time cost is 0.0019936561584472656 sec
# vols_seg_results time cost is 42.58996033668518 sec
# gt_vol time cost is 0.00796651840209961 sec
# vols_seg_results time cost is 42.69351029396057 sec
# gt_vol time cost is 0.008481979370117188 sec
# vols_seg_results time cost is 43.7182183265686 sec
# gt_vol time cost is 0.005195140838623047 sec
# vols_seg_results time cost is 43.52757239341736 sec
# gt_vol time cost is 0.0027687549591064453 sec
# vols_seg_results time cost is 42.45909404754639 sec
# gt_vol time cost is 0.0052683353424072266 sec
# vols_seg_results time cost is 42.36038303375244 sec
# gt_vol time cost is 0.005382061004638672 sec
# vols_seg_results time cost is 42.95855236053467 sec
# gt_vol time cost is 0.004474639892578125 sec
# vols_seg_results time cost is 42.8167245388031 sec
# gt_vol time cost is 0.003501415252685547 sec
# vols_seg_results time cost is 44.17298340797424 sec
# gt_vol time cost is 0.005769968032836914 sec
# vols_seg_results time cost is 44.43827986717224 sec
# gt_vol time cost is 0.004438161849975586 sec
# vols_seg_results time cost is 42.53761053085327 sec
# gt_vol time cost is 0.0030641555786132812 sec
# vols_seg_results time cost is 41.77438569068909 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0045/D2018_12_31/E4873/CT/S0004_3712
# raws time cost is 0.506723165512085 sec
# vol_pred time cost is 0.5392630100250244 sec
# c_pred time cost is 1.9352502822875977 sec
# gt_vol time cost is 0.014113903045654297 sec
# vols_seg_results time cost is 4.094915151596069 sec
# gt_vol time cost is 0.0033588409423828125 sec
# vols_seg_results time cost is 4.028012037277222 sec
# gt_vol time cost is 0.009229421615600586 sec
# vols_seg_results time cost is 4.0785276889801025 sec
# gt_vol time cost is 0.002351045608520508 sec
# vols_seg_results time cost is 4.042078733444214 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0050/D2019_01_04/E4478/CT/S0002_6859
# raws time cost is 0.6091232299804688 sec
# vol_pred time cost is 0.6302275657653809 sec
# c_pred time cost is 2.391411781311035 sec
# gt_vol time cost is 0.0073473453521728516 sec
# vols_seg_results time cost is 6.519778728485107 sec
# gt_vol time cost is 0.007567167282104492 sec
# vols_seg_results time cost is 6.501149415969849 sec
# gt_vol time cost is 0.013558626174926758 sec
# vols_seg_results time cost is 6.650497674942017 sec
# gt_vol time cost is 0.011016607284545898 sec
# vols_seg_results time cost is 6.554518461227417 sec
# gt_vol time cost is 0.007412910461425781 sec
# vols_seg_results time cost is 6.624806642532349 sec
# gt_vol time cost is 0.006902933120727539 sec
# vols_seg_results time cost is 7.003479242324829 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0051/D2019_01_25/E4701/CT/S0002_5897
# raws time cost is 0.6765530109405518 sec
# vol_pred time cost is 0.6931920051574707 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0051/D2019_01_25/E4701/CT/S0002_5897
# c_pred time cost is 2.9737701416015625 sec
# gt_vol time cost is 0.003618955612182617 sec
# vols_seg_results time cost is 19.541608810424805 sec
# gt_vol time cost is 0.010637998580932617 sec
# vols_seg_results time cost is 22.140883922576904 sec
# gt_vol time cost is 0.0023145675659179688 sec
# vols_seg_results time cost is 19.55179238319397 sec
# gt_vol time cost is 0.008810281753540039 sec
# vols_seg_results time cost is 21.131004095077515 sec
# gt_vol time cost is 0.003086566925048828 sec
# vols_seg_results time cost is 19.782022714614868 sec
# gt_vol time cost is 0.01064300537109375 sec
# vols_seg_results time cost is 22.3538818359375 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0055/D2019_02_25/E8293/CT/S0005_8934
# raws time cost is 0.22386479377746582 sec
# vol_pred time cost is 0.2395472526550293 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0055/D2019_02_25/E8293/CT/S0005_8934
# c_pred time cost is 0.9431285858154297 sec
# gt_vol time cost is 0.010506153106689453 sec
# vols_seg_results time cost is 2.3755807876586914 sec
# gt_vol time cost is 0.002580404281616211 sec
# vols_seg_results time cost is 2.3045225143432617 sec
# gt_vol time cost is 0.01024174690246582 sec
# vols_seg_results time cost is 2.357656955718994 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0056/D2019_03_19/E2806/CT/S0002_8158
# raws time cost is 0.2820770740509033 sec
# vol_pred time cost is 0.2954254150390625 sec
# c_pred time cost is 1.1214556694030762 sec
# gt_vol time cost is 0.00655055046081543 sec
# vols_seg_results time cost is 3.7207748889923096 sec
# gt_vol time cost is 0.0042667388916015625 sec
# vols_seg_results time cost is 3.581406831741333 sec
# gt_vol time cost is 0.015935420989990234 sec
# vols_seg_results time cost is 3.772871732711792 sec
# gt_vol time cost is 0.00480341911315918 sec
# vols_seg_results time cost is 3.6772818565368652 sec
# gt_vol time cost is 0.012051820755004883 sec
# vols_seg_results time cost is 3.6896255016326904 sec
# gt_vol time cost is 0.003197908401489258 sec
# vols_seg_results time cost is 3.614331007003784 sec
# gt_vol time cost is 0.010092735290527344 sec
# vols_seg_results time cost is 3.6379141807556152 sec
# gt_vol time cost is 0.002527475357055664 sec
# vols_seg_results time cost is 3.637221574783325 sec
# gt_vol time cost is 0.010468244552612305 sec
# vols_seg_results time cost is 3.6544606685638428 sec
# gt_vol time cost is 0.0013892650604248047 sec
# vols_seg_results time cost is 3.6572179794311523 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0060/D2019_05_28/E4296/CT/S0002_5183
# raws time cost is 0.40833187103271484 sec
# vol_pred time cost is 0.4426882266998291 sec
# c_pred time cost is 1.7425940036773682 sec
# gt_vol time cost is 0.00735926628112793 sec
# vols_seg_results time cost is 6.163048505783081 sec
# gt_vol time cost is 0.0031723976135253906 sec
# vols_seg_results time cost is 6.152207612991333 sec
# gt_vol time cost is 0.008220911026000977 sec
# vols_seg_results time cost is 6.3325018882751465 sec
# gt_vol time cost is 0.005246162414550781 sec
# vols_seg_results time cost is 6.121929407119751 sec
# gt_vol time cost is 0.008140087127685547 sec
# vols_seg_results time cost is 6.272381067276001 sec
# gt_vol time cost is 0.0037660598754882812 sec
# vols_seg_results time cost is 6.2808308601379395 sec
# gt_vol time cost is 0.00806879997253418 sec
# vols_seg_results time cost is 6.365593433380127 sec
# gt_vol time cost is 0.0046770572662353516 sec
# vols_seg_results time cost is 6.338581323623657 sec
# gt_vol time cost is 0.007462024688720703 sec
# vols_seg_results time cost is 6.236704587936401 sec
# gt_vol time cost is 0.003990888595581055 sec
# vols_seg_results time cost is 6.123785972595215 sec
# gt_vol time cost is 0.008421182632446289 sec
# vols_seg_results time cost is 6.264728546142578 sec
# gt_vol time cost is 0.0037376880645751953 sec
# vols_seg_results time cost is 6.171664476394653 sec
# gt_vol time cost is 0.009729862213134766 sec
# vols_seg_results time cost is 6.183626174926758 sec
# gt_vol time cost is 0.002966165542602539 sec
# vols_seg_results time cost is 6.344609022140503 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0068/D2019_12_05/E7533/CT/S0003_7277
# raws time cost is 0.6664431095123291 sec
# vol_pred time cost is 0.6885886192321777 sec
# c_pred time cost is 2.482975482940674 sec
# gt_vol time cost is 0.00803828239440918 sec
# vols_seg_results time cost is 6.316877126693726 sec
# gt_vol time cost is 0.0042819976806640625 sec
# vols_seg_results time cost is 6.1966211795806885 sec
# gt_vol time cost is 0.007860422134399414 sec
# vols_seg_results time cost is 6.500779151916504 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0070/D2020_03_10/E1191/CT/S0006_1494
# raws time cost is 0.34442925453186035 sec
# vol_pred time cost is 0.34833335876464844 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0070/D2020_03_10/E1191/CT/S0006_1494
# c_pred time cost is 1.634176254272461 sec
# gt_vol time cost is 0.006715297698974609 sec
# vols_seg_results time cost is 4.660185813903809 sec
# gt_vol time cost is 0.006659030914306641 sec
# vols_seg_results time cost is 4.674468755722046 sec
# gt_vol time cost is 0.005936384201049805 sec
# vols_seg_results time cost is 4.558668613433838 sec
# gt_vol time cost is 0.007451772689819336 sec
# vols_seg_results time cost is 4.816951036453247 sec
# gt_vol time cost is 0.0067958831787109375 sec
# vols_seg_results time cost is 4.809158802032471 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0072/D2020_05_06/E8731/CT/S0002_4371
# raws time cost is 0.4738640785217285 sec
# vol_pred time cost is 0.5050365924835205 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0072/D2020_05_06/E8731/CT/S0002_4371
# c_pred time cost is 1.8627052307128906 sec
# gt_vol time cost is 0.009169340133666992 sec
# vols_seg_results time cost is 8.585241556167603 sec
# gt_vol time cost is 0.002575397491455078 sec
# vols_seg_results time cost is 8.688671588897705 sec
# gt_vol time cost is 0.009861946105957031 sec
# vols_seg_results time cost is 8.792608261108398 sec
# gt_vol time cost is 0.0067596435546875 sec
# vols_seg_results time cost is 8.842380285263062 sec
# gt_vol time cost is 0.007739067077636719 sec
# vols_seg_results time cost is 8.887848615646362 sec
# gt_vol time cost is 0.011318206787109375 sec
# vols_seg_results time cost is 8.851909399032593 sec
# gt_vol time cost is 0.007691383361816406 sec
# vols_seg_results time cost is 8.786471366882324 sec
# gt_vol time cost is 0.0073163509368896484 sec
# vols_seg_results time cost is 8.711984634399414 sec
# gt_vol time cost is 0.006760120391845703 sec
# vols_seg_results time cost is 8.914481163024902 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0086/D2020_07_18/E4710/CT/S0004_8400
# raws time cost is 0.42302799224853516 sec
# vol_pred time cost is 0.4754602909088135 sec
# c_pred time cost is 2.1512396335601807 sec
# gt_vol time cost is 0.006754875183105469 sec
# vols_seg_results time cost is 4.499662637710571 sec
# gt_vol time cost is 0.0033364295959472656 sec
# vols_seg_results time cost is 4.559441089630127 sec
# gt_vol time cost is 0.007658720016479492 sec
# vols_seg_results time cost is 4.564857721328735 sec
# gt_vol time cost is 0.002604961395263672 sec
# vols_seg_results time cost is 4.595484733581543 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0089/D2019_10_22/E2646/CT/S0003_6412
# raws time cost is 0.39710021018981934 sec
# vol_pred time cost is 0.4373013973236084 sec
# c_pred time cost is 1.8182525634765625 sec
# gt_vol time cost is 0.020537137985229492 sec
# vols_seg_results time cost is 8.650509595870972 sec
# gt_vol time cost is 0.008510589599609375 sec
# vols_seg_results time cost is 8.498884916305542 sec
# gt_vol time cost is 0.006548643112182617 sec
# vols_seg_results time cost is 8.719317436218262 sec
# gt_vol time cost is 0.006587982177734375 sec
# vols_seg_results time cost is 8.831254959106445 sec
# gt_vol time cost is 0.014522075653076172 sec
# vols_seg_results time cost is 8.43002438545227 sec
# gt_vol time cost is 0.007587909698486328 sec
# vols_seg_results time cost is 8.663774013519287 sec
# gt_vol time cost is 0.0069239139556884766 sec
# vols_seg_results time cost is 8.544064283370972 sec
# gt_vol time cost is 0.0076885223388671875 sec
# vols_seg_results time cost is 8.553268909454346 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0090/D2019_12_04/E4704/CT/S0002_8241
# raws time cost is 0.370441198348999 sec
# vol_pred time cost is 0.39728784561157227 sec
# c_pred time cost is 1.7295255661010742 sec
# gt_vol time cost is 0.0063321590423583984 sec
# vols_seg_results time cost is 4.071450710296631 sec
# gt_vol time cost is 0.034538984298706055 sec
# vols_seg_results time cost is 4.354553937911987 sec
# gt_vol time cost is 0.005125999450683594 sec
# vols_seg_results time cost is 3.9683609008789062 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0091/D2020_07_21/E8492/CT/S0003_1824
# raws time cost is 0.2259199619293213 sec
# vol_pred time cost is 0.24404025077819824 sec
# c_pred time cost is 1.0803158283233643 sec
# gt_vol time cost is 0.007713794708251953 sec
# vols_seg_results time cost is 2.2874364852905273 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0092/D2019_04_02/E1327/CT/S0007_1538
# raws time cost is 0.30260372161865234 sec
# vol_pred time cost is 0.33678174018859863 sec
# c_pred time cost is 1.508228063583374 sec
# gt_vol time cost is 0.0049436092376708984 sec
# vols_seg_results time cost is 7.887532472610474 sec
# gt_vol time cost is 0.0059642791748046875 sec
# vols_seg_results time cost is 7.928506135940552 sec
# gt_vol time cost is 0.004560232162475586 sec
# vols_seg_results time cost is 7.734658718109131 sec
# gt_vol time cost is 0.005484580993652344 sec
# vols_seg_results time cost is 8.109204769134521 sec
# gt_vol time cost is 0.009630680084228516 sec
# vols_seg_results time cost is 8.122576475143433 sec
# gt_vol time cost is 0.006620645523071289 sec
# vols_seg_results time cost is 8.102999448776245 sec
# gt_vol time cost is 0.01486659049987793 sec
# vols_seg_results time cost is 8.073105812072754 sec
# gt_vol time cost is 0.0058231353759765625 sec
# vols_seg_results time cost is 8.15839171409607 sec
# gt_vol time cost is 0.003729581832885742 sec
# vols_seg_results time cost is 8.332512140274048 sec
# gt_vol time cost is 0.005801200866699219 sec
# vols_seg_results time cost is 8.273200988769531 sec
# gt_vol time cost is 0.00419306755065918 sec
# vols_seg_results time cost is 8.010786056518555 sec
# gt_vol time cost is 0.006676912307739258 sec
# vols_seg_results time cost is 8.163866519927979 sec
# gt_vol time cost is 0.0027549266815185547 sec
# vols_seg_results time cost is 8.360060930252075 sec
# gt_vol time cost is 0.006180286407470703 sec
# vols_seg_results time cost is 8.491528511047363 sec
# gt_vol time cost is 0.0041964054107666016 sec
# vols_seg_results time cost is 8.218347787857056 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0094/D2019_02_18/E2895/CT/S0602_8602
# raws time cost is 0.49454164505004883 sec
# vol_pred time cost is 0.5100500583648682 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0094/D2019_02_18/E2895/CT/S0602_8602
# c_pred time cost is 2.430776357650757 sec
# gt_vol time cost is 0.009070873260498047 sec
# vols_seg_results time cost is 16.499670267105103 sec
# gt_vol time cost is 0.006292581558227539 sec
# vols_seg_results time cost is 15.052579879760742 sec
# gt_vol time cost is 0.007636308670043945 sec
# vols_seg_results time cost is 16.415308237075806 sec
# gt_vol time cost is 0.003664255142211914 sec
# vols_seg_results time cost is 14.943764925003052 sec
# gt_vol time cost is 0.011261940002441406 sec
# vols_seg_results time cost is 16.290045738220215 sec
# gt_vol time cost is 0.0035829544067382812 sec
# vols_seg_results time cost is 15.339307069778442 sec
# gt_vol time cost is 0.009798049926757812 sec
# vols_seg_results time cost is 16.521525144577026 sec
# gt_vol time cost is 0.004280567169189453 sec
# vols_seg_results time cost is 15.564236640930176 sec
# gt_vol time cost is 0.009794235229492188 sec
# vols_seg_results time cost is 17.027219533920288 sec
# gt_vol time cost is 0.0031442642211914062 sec
# vols_seg_results time cost is 15.635200023651123 sec
# gt_vol time cost is 0.00971531867980957 sec
# vols_seg_results time cost is 16.550394535064697 sec
# gt_vol time cost is 0.003487110137939453 sec
# vols_seg_results time cost is 15.911518335342407 sec
# gt_vol time cost is 0.010423898696899414 sec
# vols_seg_results time cost is 16.496692419052124 sec
# gt_vol time cost is 0.007971048355102539 sec
# vols_seg_results time cost is 15.448881149291992 sec
# gt_vol time cost is 0.008951425552368164 sec
# vols_seg_results time cost is 16.318583965301514 sec
# gt_vol time cost is 0.0049631595611572266 sec
# vols_seg_results time cost is 14.900676012039185 sec
# gt_vol time cost is 0.010110855102539062 sec
# vols_seg_results time cost is 16.678401231765747 sec
# gt_vol time cost is 0.0036287307739257812 sec
# vols_seg_results time cost is 16.12427020072937 sec
# gt_vol time cost is 0.009253501892089844 sec
# vols_seg_results time cost is 16.879765510559082 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0104/D2019_02_12/E3272/CT/S0004_4674
# raws time cost is 1.020569086074829 sec
# vol_pred time cost is 1.0297272205352783 sec
# c_pred time cost is 4.589950084686279 sec
# gt_vol time cost is 0.0038475990295410156 sec
# vols_seg_results time cost is 14.51735782623291 sec
# gt_vol time cost is 0.005379438400268555 sec
# vols_seg_results time cost is 14.565831422805786 sec
# gt_vol time cost is 0.002776622772216797 sec
# vols_seg_results time cost is 16.422684907913208 sec
# gt_vol time cost is 0.0041501522064208984 sec
# vols_seg_results time cost is 15.556368827819824 sec
# gt_vol time cost is 0.0034444332122802734 sec
# vols_seg_results time cost is 16.22845220565796 sec
# gt_vol time cost is 0.006128549575805664 sec
# vols_seg_results time cost is 16.264160633087158 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0109/D2019_12_17/E3845/CT/S0005_1061
# raws time cost is 0.34119248390197754 sec
# vol_pred time cost is 0.3655576705932617 sec
# c_pred time cost is 1.335296630859375 sec
# gt_vol time cost is 0.0049190521240234375 sec
# vols_seg_results time cost is 2.891326427459717 sec
# gt_vol time cost is 0.0020799636840820312 sec
# vols_seg_results time cost is 2.8275656700134277 sec
# gt_vol time cost is 0.010851860046386719 sec
# vols_seg_results time cost is 2.822526693344116 sec
# gt_vol time cost is 0.0015583038330078125 sec
# vols_seg_results time cost is 2.7326176166534424 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0121/D2019_08_26/E8599/CT/S0003_8756
# raws time cost is 0.32928943634033203 sec
# vol_pred time cost is 0.34830379486083984 sec
# c_pred time cost is 1.5040340423583984 sec
# gt_vol time cost is 0.0071222782135009766 sec
# vols_seg_results time cost is 6.2781291007995605 sec
# gt_vol time cost is 0.007039070129394531 sec
# vols_seg_results time cost is 6.239806175231934 sec
# gt_vol time cost is 0.005176067352294922 sec
# vols_seg_results time cost is 6.300011873245239 sec
# gt_vol time cost is 0.005196571350097656 sec
# vols_seg_results time cost is 6.2635414600372314 sec
# gt_vol time cost is 0.0060198307037353516 sec
# vols_seg_results time cost is 6.245058536529541 sec
# gt_vol time cost is 0.005360126495361328 sec
# vols_seg_results time cost is 6.338205814361572 sec
# gt_vol time cost is 0.008173465728759766 sec
# vols_seg_results time cost is 6.48057222366333 sec
# gt_vol time cost is 0.0056955814361572266 sec
# vols_seg_results time cost is 6.378909587860107 sec
# gt_vol time cost is 0.0073130130767822266 sec
# vols_seg_results time cost is 6.127893924713135 sec
# gt_vol time cost is 0.005419492721557617 sec
# vols_seg_results time cost is 6.30356240272522 sec
# gt_vol time cost is 0.007896661758422852 sec
# vols_seg_results time cost is 6.152552127838135 sec
# gt_vol time cost is 0.010926485061645508 sec
# vols_seg_results time cost is 6.418705701828003 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0131/D2019_01_04/E1058/CT/S0002_8806
# raws time cost is 0.3668701648712158 sec
# vol_pred time cost is 0.37501001358032227 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0131/D2019_01_04/E1058/CT/S0002_8806
# c_pred time cost is 1.6277961730957031 sec
# gt_vol time cost is 0.00480198860168457 sec
# vols_seg_results time cost is 4.826597690582275 sec
# gt_vol time cost is 0.0018155574798583984 sec
# vols_seg_results time cost is 4.837263584136963 sec
# gt_vol time cost is 0.0046405792236328125 sec
# vols_seg_results time cost is 4.843695163726807 sec
# gt_vol time cost is 0.0017733573913574219 sec
# vols_seg_results time cost is 4.898862838745117 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0136/D2019_06_05/E6581/CT/S0002_0029
# raws time cost is 0.4525320529937744 sec
# vol_pred time cost is 0.454761266708374 sec
# c_pred time cost is 1.786428689956665 sec
# gt_vol time cost is 0.006287574768066406 sec
# vols_seg_results time cost is 3.2810451984405518 sec
# gt_vol time cost is 0.005183219909667969 sec
# vols_seg_results time cost is 3.2016398906707764 sec
# gt_vol time cost is 0.0017275810241699219 sec
# vols_seg_results time cost is 3.2441694736480713 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0137/D2019_08_07/E8485/CT/S0002_0959
# raws time cost is 0.5330336093902588 sec
# vol_pred time cost is 0.5459349155426025 sec
# c_pred time cost is 1.8548455238342285 sec
# gt_vol time cost is 0.008710622787475586 sec
# vols_seg_results time cost is 3.256615400314331 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0140/D2019_02_21/E1740/CT/S0003_5046
# raws time cost is 0.2776625156402588 sec
# vol_pred time cost is 0.29253625869750977 sec
# c_pred time cost is 1.2018096446990967 sec
# gt_vol time cost is 0.005110740661621094 sec
# vols_seg_results time cost is 2.315831184387207 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0146/D2019_07_09/E8702/CT/S0007_7117
# raws time cost is 0.20633745193481445 sec
# vol_pred time cost is 0.2110593318939209 sec
# c_pred time cost is 0.8454270362854004 sec
# gt_vol time cost is 0.0019562244415283203 sec
# vols_seg_results time cost is 1.6276345252990723 sec
# gt_vol time cost is 0.004745960235595703 sec
# vols_seg_results time cost is 1.5498995780944824 sec
# gt_vol time cost is 0.004565715789794922 sec
# vols_seg_results time cost is 1.60251784324646 sec
# gt_vol time cost is 0.003025531768798828 sec
# vols_seg_results time cost is 1.6961357593536377 sec
# gt_vol time cost is 0.004012107849121094 sec
# vols_seg_results time cost is 1.6677756309509277 sec
# gt_vol time cost is 0.0033349990844726562 sec
# vols_seg_results time cost is 1.6193385124206543 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0150/D2019_12_13/E6241/CT/S0005_2496
# raws time cost is 0.7538902759552002 sec
# vol_pred time cost is 0.7675573825836182 sec
# c_pred time cost is 3.60638165473938 sec
# gt_vol time cost is 0.01063394546508789 sec
# vols_seg_results time cost is 13.745908737182617 sec
# gt_vol time cost is 0.010015010833740234 sec
# vols_seg_results time cost is 13.645750045776367 sec
# gt_vol time cost is 0.006543636322021484 sec
# vols_seg_results time cost is 13.661145687103271 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0153/D2019_12_10/E3951/CT/S0003_3965
# raws time cost is 0.4348912239074707 sec
# vol_pred time cost is 0.44118261337280273 sec
# c_pred time cost is 1.9858672618865967 sec
# gt_vol time cost is 0.008141756057739258 sec
# vols_seg_results time cost is 4.623531341552734 sec
# gt_vol time cost is 0.005465030670166016 sec
# vols_seg_results time cost is 4.8772172927856445 sec
# gt_vol time cost is 0.008085966110229492 sec
# vols_seg_results time cost is 5.054439544677734 sec
# gt_vol time cost is 0.0029523372650146484 sec
# vols_seg_results time cost is 4.861929655075073 sec
# gt_vol time cost is 0.00769352912902832 sec
# vols_seg_results time cost is 5.12411904335022 sec
# gt_vol time cost is 0.0025701522827148438 sec
# vols_seg_results time cost is 5.068319320678711 sec
# gt_vol time cost is 0.008402109146118164 sec
# vols_seg_results time cost is 5.069993257522583 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0174/D2019_01_18/E3953/CT/S0003_9603
# raws time cost is 0.25903940200805664 sec
# vol_pred time cost is 0.26782655715942383 sec
# c_pred time cost is 1.1448626518249512 sec
# gt_vol time cost is 0.005650758743286133 sec
# vols_seg_results time cost is 2.337857246398926 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0180/D2020_01_03/E9828/CT/S0006_8376
# raws time cost is 0.33623218536376953 sec
# vol_pred time cost is 0.33786964416503906 sec
# c_pred time cost is 1.4776122570037842 sec
# gt_vol time cost is 0.005686759948730469 sec
# vols_seg_results time cost is 2.816598892211914 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0187/D2017_04_26/E1167/CT/S0002_5612
# raws time cost is 0.4649200439453125 sec
# vol_pred time cost is 0.48174619674682617 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0187/D2017_04_26/E1167/CT/S0002_5612
# c_pred time cost is 1.7933859825134277 sec
# gt_vol time cost is 0.006114482879638672 sec
# vols_seg_results time cost is 24.817240715026855 sec
# gt_vol time cost is 0.008933067321777344 sec
# vols_seg_results time cost is 25.82206916809082 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0192/D2019_02_21/E6430/CT/S0003_0478
# raws time cost is 0.4429440498352051 sec
# vol_pred time cost is 0.45572829246520996 sec
# c_pred time cost is 1.8524439334869385 sec
# gt_vol time cost is 0.006067752838134766 sec
# vols_seg_results time cost is 3.2332916259765625 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0194/D2019_02_11/E3611/CT/S0002_7005
# raws time cost is 0.8028438091278076 sec
# vol_pred time cost is 0.8115212917327881 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0194/D2019_02_11/E3611/CT/S0002_7005
# c_pred time cost is 3.834120988845825 sec
# gt_vol time cost is 0.012395858764648438 sec
# vols_seg_results time cost is 17.303816318511963 sec
# gt_vol time cost is 0.003461599349975586 sec
# vols_seg_results time cost is 17.205593585968018 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0195/D2019_04_08/E6219/CT/S0003_8373
# raws time cost is 0.2660386562347412 sec
# vol_pred time cost is 0.2810025215148926 sec
# c_pred time cost is 1.2019009590148926 sec
# gt_vol time cost is 0.012609004974365234 sec
# vols_seg_results time cost is 2.8816535472869873 sec
# gt_vol time cost is 0.0054852962493896484 sec
# vols_seg_results time cost is 2.692037343978882 sec
# gt_vol time cost is 0.014638185501098633 sec
# vols_seg_results time cost is 2.852210283279419 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0197/D2019_04_12/E2953/CT/S0002_6892
# raws time cost is 0.4332444667816162 sec
# vol_pred time cost is 0.4398672580718994 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0197/D2019_04_12/E2953/CT/S0002_6892
# c_pred time cost is 1.6311452388763428 sec
# gt_vol time cost is 0.005769968032836914 sec
# vols_seg_results time cost is 4.065239191055298 sec
# gt_vol time cost is 0.004379749298095703 sec
# vols_seg_results time cost is 4.1112895011901855 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0208/D2019_06_26/E9298/CT/S0003_9073
# raws time cost is 0.36609911918640137 sec
# vol_pred time cost is 0.38054752349853516 sec
# c_pred time cost is 1.5589232444763184 sec
# gt_vol time cost is 0.005530357360839844 sec
# vols_seg_results time cost is 4.3312602043151855 sec
# gt_vol time cost is 0.006322383880615234 sec
# vols_seg_results time cost is 4.305314302444458 sec
# gt_vol time cost is 0.005596637725830078 sec
# vols_seg_results time cost is 4.261728048324585 sec
# gt_vol time cost is 0.0066835880279541016 sec
# vols_seg_results time cost is 4.178065299987793 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0212/D2019_09_12/E9134/CT/S0003_8663
# raws time cost is 0.38814210891723633 sec
# vol_pred time cost is 0.41222548484802246 sec
# c_pred time cost is 1.6946098804473877 sec
# gt_vol time cost is 0.004593849182128906 sec
# vols_seg_results time cost is 3.095449447631836 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0215/D2019_10_28/E4799/CT/S0003_6381
# raws time cost is 0.3629038333892822 sec
# vol_pred time cost is 0.36834239959716797 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0215/D2019_10_28/E4799/CT/S0003_6381
# c_pred time cost is 1.6094977855682373 sec
# gt_vol time cost is 0.005697965621948242 sec
# vols_seg_results time cost is 5.274848222732544 sec
# gt_vol time cost is 0.003343343734741211 sec
# vols_seg_results time cost is 5.088070869445801 sec
# gt_vol time cost is 0.006669521331787109 sec
# vols_seg_results time cost is 5.337985992431641 sec
# gt_vol time cost is 0.002682209014892578 sec
# vols_seg_results time cost is 5.219617128372192 sec
# gt_vol time cost is 0.006180524826049805 sec
# vols_seg_results time cost is 5.268556118011475 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0222/D2019_10_16/E8403/CT/S0007_0427
# raws time cost is 0.3800654411315918 sec
# vol_pred time cost is 0.3838005065917969 sec
# c_pred time cost is 1.7732059955596924 sec
# gt_vol time cost is 0.004609823226928711 sec
# vols_seg_results time cost is 3.9895849227905273 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0223/D2019_12_11/E9784/CT/S0010_2646
# raws time cost is 0.6504945755004883 sec
# vol_pred time cost is 0.674447774887085 sec
# c_pred time cost is 3.184393882751465 sec
# gt_vol time cost is 0.006387233734130859 sec
# vols_seg_results time cost is 8.597395896911621 sec
# gt_vol time cost is 0.0024259090423583984 sec
# vols_seg_results time cost is 9.053536891937256 sec
# gt_vol time cost is 0.0025129318237304688 sec
# vols_seg_results time cost is 9.58098316192627 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0225/D2019_10_31/E0067/CT/S0007_0410
# raws time cost is 0.3618755340576172 sec
# vol_pred time cost is 0.3833754062652588 sec
# c_pred time cost is 1.4853651523590088 sec
# gt_vol time cost is 0.006357431411743164 sec
# vols_seg_results time cost is 2.829559326171875 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0226/D2019_11_13/E2102/CT/S0003_1093
# raws time cost is 0.2506411075592041 sec
# vol_pred time cost is 0.25290846824645996 sec
# c_pred time cost is 1.0529191493988037 sec
# gt_vol time cost is 0.003556966781616211 sec
# vols_seg_results time cost is 2.0756962299346924 sec
# gt_vol time cost is 0.005015373229980469 sec
# vols_seg_results time cost is 1.9755334854125977 sec
# gt_vol time cost is 0.004151105880737305 sec
# vols_seg_results time cost is 2.1658732891082764 sec
# gt_vol time cost is 0.004723310470581055 sec
# vols_seg_results time cost is 2.136272430419922 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0227/D2019_07_22/E2270/CT/S0004_4084
# raws time cost is 0.5453882217407227 sec
# vol_pred time cost is 0.5644237995147705 sec
# c_pred time cost is 2.5117738246917725 sec
# gt_vol time cost is 0.003854036331176758 sec
# vols_seg_results time cost is 6.852109909057617 sec
# gt_vol time cost is 0.004019260406494141 sec
# vols_seg_results time cost is 6.878618240356445 sec
# gt_vol time cost is 0.009450674057006836 sec
# vols_seg_results time cost is 7.361616611480713 sec
# gt_vol time cost is 0.0033986568450927734 sec
# vols_seg_results time cost is 6.998049736022949 sec
# gt_vol time cost is 0.04150032997131348 sec
# vols_seg_results time cost is 7.441275596618652 sec
# gt_vol time cost is 0.0024089813232421875 sec
# vols_seg_results time cost is 6.99729323387146 sec
# gt_vol time cost is 0.007600069046020508 sec
# vols_seg_results time cost is 7.2021613121032715 sec
# gt_vol time cost is 0.005885124206542969 sec
# vols_seg_results time cost is 6.967600584030151 sec
# gt_vol time cost is 0.015617132186889648 sec
# vols_seg_results time cost is 6.987957000732422 sec
# gt_vol time cost is 0.002386808395385742 sec
# vols_seg_results time cost is 6.792558908462524 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0229/D2019_12_06/E9735/CT/S0007_0451
# raws time cost is 0.3908107280731201 sec
# vol_pred time cost is 0.39803147315979004 sec
# c_pred time cost is 1.823287010192871 sec
# gt_vol time cost is 0.006139039993286133 sec
# vols_seg_results time cost is 3.8324477672576904 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0232/D2020_01_22/E4306/CT/S0007_5599
# raws time cost is 0.3366405963897705 sec
# vol_pred time cost is 0.3467884063720703 sec
# ...
# vols_seg_results time cost is 4.026695966720581 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0277/D2019_05_21/E8774/CT/S0002_4796
# raws time cost is 0.2774958610534668 sec
# vol_pred time cost is 0.2872898578643799 sec
# c_pred time cost is 1.231234073638916 sec
# gt_vol time cost is 0.0047054290771484375 sec
# vols_seg_results time cost is 2.650050163269043 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0289/D2019_09_23/E4372/CT/S0002_8538
# raws time cost is 0.5906929969787598 sec
# vol_pred time cost is 0.5947611331939697 sec
# c_pred time cost is 2.240875720977783 sec
# gt_vol time cost is 0.0031249523162841797 sec
# vols_seg_results time cost is 5.266648530960083 sec
# gt_vol time cost is 0.003987789154052734 sec
# vols_seg_results time cost is 5.483489036560059 sec
# gt_vol time cost is 0.0018000602722167969 sec
# vols_seg_results time cost is 5.457338809967041 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0294/D2020_01_30/E8610/CT/S0002_5763
# raws time cost is 0.434459924697876 sec
# vol_pred time cost is 0.4488186836242676 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0294/D2020_01_30/E8610/CT/S0002_5763
# c_pred time cost is 1.653447151184082 sec
# gt_vol time cost is 0.0058705806732177734 sec
# vols_seg_results time cost is 4.745031833648682 sec
# gt_vol time cost is 0.006132364273071289 sec
# vols_seg_results time cost is 4.6783106327056885 sec
# gt_vol time cost is 0.006204128265380859 sec
# vols_seg_results time cost is 4.576898813247681 sec
# gt_vol time cost is 0.0050160884857177734 sec
# vols_seg_results time cost is 4.850044012069702 sec
# gt_vol time cost is 0.006463050842285156 sec
# vols_seg_results time cost is 4.9953696727752686 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/PDS_AUTO_RECIST/METNET0296/D2019_06_03/E3751/CT/S0002_1364
# raws time cost is 0.34212589263916016 sec
# vol_pred time cost is 0.34734582901000977 sec
# c_pred time cost is 1.5147526264190674 sec
# gt_vol time cost is 0.004105567932128906 sec
# vols_seg_results time cost is 3.1228034496307373 sec
# gt_vol time cost is 0.005728244781494141 sec
# vols_seg_results time cost is 3.1711764335632324 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJC/D2004_02_27/E20040227/CT/S0002
# raws time cost is 0.526740312576294 sec
# vol_pred time cost is 0.5592780113220215 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJC/D2004_02_27/E20040227/CT/S0002
# c_pred time cost is 3.1256704330444336 sec
# gt_vol time cost is 0.0046961307525634766 sec
# vols_seg_results time cost is 50.67264008522034 sec
# gt_vol time cost is 0.004812479019165039 sec
# vols_seg_results time cost is 44.80200386047363 sec
# gt_vol time cost is 0.004014253616333008 sec
# vols_seg_results time cost is 43.36243271827698 sec
# gt_vol time cost is 0.006577968597412109 sec
# vols_seg_results time cost is 42.99984407424927 sec
# gt_vol time cost is 0.0036034584045410156 sec
# vols_seg_results time cost is 42.92711567878723 sec
# gt_vol time cost is 0.003469705581665039 sec
# vols_seg_results time cost is 41.88345694541931 sec
# gt_vol time cost is 0.0030078887939453125 sec
# vols_seg_results time cost is 42.97422981262207 sec
# gt_vol time cost is 0.0036475658416748047 sec
# vols_seg_results time cost is 42.931605100631714 sec
# gt_vol time cost is 0.00255584716796875 sec
# vols_seg_results time cost is 42.77383804321289 sec
# gt_vol time cost is 0.002683401107788086 sec
# vols_seg_results time cost is 42.838367223739624 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJD/D2004_02_07/E20040207/CT/S0002
# raws time cost is 0.31310296058654785 sec
# vol_pred time cost is 0.3378121852874756 sec
# c_pred time cost is 1.4952507019042969 sec
# gt_vol time cost is 0.009580373764038086 sec
# vols_seg_results time cost is 3.1583056449890137 sec
# gt_vol time cost is 0.001585245132446289 sec
# vols_seg_results time cost is 3.095669746398926 sec
# gt_vol time cost is 0.00939035415649414 sec
# vols_seg_results time cost is 3.173783302307129 sec
# gt_vol time cost is 0.0030622482299804688 sec
# vols_seg_results time cost is 3.167658567428589 sec
# gt_vol time cost is 0.006200075149536133 sec
# vols_seg_results time cost is 3.1427555084228516 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJG/D2004_02_02/E20040202/CT/S0013
# raws time cost is 0.2584543228149414 sec
# vol_pred time cost is 0.2675185203552246 sec
# c_pred time cost is 1.2924983501434326 sec
# gt_vol time cost is 0.005197763442993164 sec
# vols_seg_results time cost is 2.927103042602539 sec
# gt_vol time cost is 0.0057752132415771484 sec
# vols_seg_results time cost is 3.0167717933654785 sec
# gt_vol time cost is 0.006609678268432617 sec
# vols_seg_results time cost is 2.93192195892334 sec
# gt_vol time cost is 0.004456758499145508 sec
# vols_seg_results time cost is 2.986295461654663 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJL/D2004_02_24/E20040224/CT/S3464
# raws time cost is 0.23341917991638184 sec
# vol_pred time cost is 0.2567934989929199 sec
# c_pred time cost is 1.1066386699676514 sec
# gt_vol time cost is 0.01238250732421875 sec
# vols_seg_results time cost is 3.5317909717559814 sec
# gt_vol time cost is 0.018011093139648438 sec
# vols_seg_results time cost is 3.5676801204681396 sec
# gt_vol time cost is 0.004292011260986328 sec
# vols_seg_results time cost is 3.541433811187744 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJM/D2004_01_31/E20040131/CT/S0003
# raws time cost is 0.3903782367706299 sec
# vol_pred time cost is 0.40329527854919434 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJM/D2004_01_31/E20040131/CT/S0003
# c_pred time cost is 1.8600053787231445 sec
# gt_vol time cost is 0.010969400405883789 sec
# vols_seg_results time cost is 6.994859218597412 sec
# gt_vol time cost is 0.0019447803497314453 sec
# vols_seg_results time cost is 6.725674629211426 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJN/D2004_02_03/E20040203/CT/S0004
# raws time cost is 0.14931821823120117 sec
# vol_pred time cost is 0.1603245735168457 sec
# c_pred time cost is 0.663193941116333 sec
# gt_vol time cost is 0.01363825798034668 sec
# vols_seg_results time cost is 1.4171373844146729 sec
# gt_vol time cost is 0.004280805587768555 sec
# vols_seg_results time cost is 1.4233622550964355 sec
# gt_vol time cost is 0.003949642181396484 sec
# vols_seg_results time cost is 1.351367712020874 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJO/D2004_02_19/E20040219/CT/S0005
# raws time cost is 0.28861284255981445 sec
# vol_pred time cost is 0.30512070655822754 sec
# c_pred time cost is 1.3996565341949463 sec
# gt_vol time cost is 0.008675336837768555 sec
# vols_seg_results time cost is 5.046304225921631 sec
# gt_vol time cost is 0.0022025108337402344 sec
# vols_seg_results time cost is 5.005237102508545 sec
# gt_vol time cost is 0.0068967342376708984 sec
# vols_seg_results time cost is 4.9382240772247314 sec
# gt_vol time cost is 0.0029327869415283203 sec
# vols_seg_results time cost is 4.949208498001099 sec
# gt_vol time cost is 0.009516239166259766 sec
# vols_seg_results time cost is 4.968462944030762 sec
# gt_vol time cost is 0.0019686222076416016 sec
# vols_seg_results time cost is 4.959198951721191 sec
# gt_vol time cost is 0.0057888031005859375 sec
# vols_seg_results time cost is 4.9865429401397705 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJP/D2004_02_26/E20040226/CT/S0002
# raws time cost is 0.35054636001586914 sec
# vol_pred time cost is 0.3607809543609619 sec
# c_pred time cost is 1.7533929347991943 sec
# gt_vol time cost is 0.005596160888671875 sec
# vols_seg_results time cost is 5.181463956832886 sec
# gt_vol time cost is 0.007386922836303711 sec
# vols_seg_results time cost is 5.310228109359741 sec
# gt_vol time cost is 0.004906892776489258 sec
# vols_seg_results time cost is 5.244278430938721 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJQ/D2004_04_27/E20040427/CT/S0007
# raws time cost is 0.2889871597290039 sec
# vol_pred time cost is 0.29586100578308105 sec
# c_pred time cost is 1.377046823501587 sec
# gt_vol time cost is 0.00680232048034668 sec
# vols_seg_results time cost is 3.6106629371643066 sec
# gt_vol time cost is 0.0018465518951416016 sec
# vols_seg_results time cost is 3.649301767349243 sec
# gt_vol time cost is 0.004515409469604492 sec
# vols_seg_results time cost is 3.7039260864257812 sec
# gt_vol time cost is 0.0018305778503417969 sec
# vols_seg_results time cost is 3.561755895614624 sec
# gt_vol time cost is 0.004521369934082031 sec
# vols_seg_results time cost is 3.6327383518218994 sec
# gt_vol time cost is 0.0022139549255371094 sec
# vols_seg_results time cost is 3.5549209117889404 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJR/D2004_02_11/E20040211/CT/S0006
# raws time cost is 0.29207921028137207 sec
# vol_pred time cost is 0.297680139541626 sec
# c_pred time cost is 1.4602489471435547 sec
# gt_vol time cost is 0.007027626037597656 sec
# vols_seg_results time cost is 2.7220468521118164 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJT/D2004_02_27/E20040227/CT/S0002
# raws time cost is 0.41492176055908203 sec
# vol_pred time cost is 0.4349021911621094 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJT/D2004_02_27/E20040227/CT/S0002
# c_pred time cost is 2.116273880004883 sec
# gt_vol time cost is 0.0062465667724609375 sec
# vols_seg_results time cost is 13.179863929748535 sec
# gt_vol time cost is 0.002568960189819336 sec
# vols_seg_results time cost is 13.311021089553833 sec
# gt_vol time cost is 0.007971048355102539 sec
# vols_seg_results time cost is 14.090203285217285 sec
# gt_vol time cost is 0.00413060188293457 sec
# vols_seg_results time cost is 14.183316469192505 sec
# gt_vol time cost is 0.008527994155883789 sec
# vols_seg_results time cost is 15.287365913391113 sec
# gt_vol time cost is 0.003030061721801758 sec
# vols_seg_results time cost is 14.113706588745117 sec
# gt_vol time cost is 0.007942914962768555 sec
# vols_seg_results time cost is 15.201014280319214 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJV/D2004_04_25/E9999/CT/S0004_4585
# raws time cost is 0.16699695587158203 sec
# vol_pred time cost is 0.17607355117797852 sec
# c_pred time cost is 0.7408547401428223 sec
# gt_vol time cost is 0.01227879524230957 sec
# vols_seg_results time cost is 1.9433066844940186 sec
# gt_vol time cost is 0.0032830238342285156 sec
# vols_seg_results time cost is 1.907027006149292 sec
# gt_vol time cost is 0.003391265869140625 sec
# vols_seg_results time cost is 1.8660588264465332 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJW/D2004_02_25/E9999/CT/S0004_1569
# raws time cost is 0.17544054985046387 sec
# vol_pred time cost is 0.18122220039367676 sec
# c_pred time cost is 0.726738691329956 sec
# gt_vol time cost is 0.002652406692504883 sec
# vols_seg_results time cost is 1.8493871688842773 sec
# gt_vol time cost is 0.003142118453979492 sec
# vols_seg_results time cost is 1.844902753829956 sec
# gt_vol time cost is 0.004045248031616211 sec
# vols_seg_results time cost is 1.9354538917541504 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJY/D2004_02_26/E20040226/CT/S0006
# raws time cost is 0.12582635879516602 sec
# vol_pred time cost is 0.14232206344604492 sec
# c_pred time cost is 0.5776000022888184 sec
# gt_vol time cost is 0.002803802490234375 sec
# vols_seg_results time cost is 1.8255376815795898 sec
# gt_vol time cost is 0.0034401416778564453 sec
# vols_seg_results time cost is 1.7962555885314941 sec
# gt_vol time cost is 0.0034182071685791016 sec
# vols_seg_results time cost is 1.8930072784423828 sec
# gt_vol time cost is 0.00436711311340332 sec
# vols_seg_results time cost is 1.7920761108398438 sec
# gt_vol time cost is 0.004656791687011719 sec
# vols_seg_results time cost is 1.7919237613677979 sec
# gt_vol time cost is 0.0021522045135498047 sec
# vols_seg_results time cost is 1.9208788871765137 sec
# gt_vol time cost is 0.003583192825317383 sec
# vols_seg_results time cost is 1.8226301670074463 sec
# gt_vol time cost is 0.0021789073944091797 sec
# vols_seg_results time cost is 1.7812490463256836 sec
# gt_vol time cost is 0.0031821727752685547 sec
# vols_seg_results time cost is 1.8294150829315186 sec
# gt_vol time cost is 0.0048410892486572266 sec
# vols_seg_results time cost is 1.8996338844299316 sec
# gt_vol time cost is 0.002110719680786133 sec
# vols_seg_results time cost is 1.7801487445831299 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJZ/D2004_03_02/E20040302/CT/S0002
# raws time cost is 0.47527503967285156 sec
# vol_pred time cost is 0.5109176635742188 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIJZ/D2004_03_02/E20040302/CT/S0002
# c_pred time cost is 2.431722402572632 sec
# gt_vol time cost is 0.005686521530151367 sec
# vols_seg_results time cost is 19.898529052734375 sec
# gt_vol time cost is 0.002544403076171875 sec
# vols_seg_results time cost is 19.47940731048584 sec
# gt_vol time cost is 0.004284381866455078 sec
# vols_seg_results time cost is 20.860015869140625 sec
# gt_vol time cost is 0.005689144134521484 sec
# vols_seg_results time cost is 21.814944744110107 sec
# gt_vol time cost is 0.012873649597167969 sec
# vols_seg_results time cost is 19.872787952423096 sec
# gt_vol time cost is 0.005563497543334961 sec
# vols_seg_results time cost is 19.148172616958618 sec
# gt_vol time cost is 0.006448984146118164 sec
# vols_seg_results time cost is 19.85748052597046 sec
# gt_vol time cost is 0.004489898681640625 sec
# vols_seg_results time cost is 19.823996782302856 sec
# gt_vol time cost is 0.00318145751953125 sec
# vols_seg_results time cost is 20.028295278549194 sec
# gt_vol time cost is 0.002946615219116211 sec
# vols_seg_results time cost is 21.61146354675293 sec
# gt_vol time cost is 0.002641916275024414 sec
# vols_seg_results time cost is 20.45738410949707 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKB/D2004_02_24/E20040224/CT/S0004
# raws time cost is 0.43488597869873047 sec
# vol_pred time cost is 0.4473118782043457 sec
# c_pred time cost is 2.2059781551361084 sec
# gt_vol time cost is 0.005985736846923828 sec
# vols_seg_results time cost is 5.010858535766602 sec
# /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKD/D2004_02_04/E20040204/CT/S0002
# raws time cost is 0.2405712604522705 sec
# vol_pred time cost is 0.25969839096069336 sec
# warning! raws overlaped on /mnt/fast-disk1/mjc/AutoRecist/Inputs/AMGEN/20020408/BAIKD/D2004_02_04/E20040204/CT/S0002
# c_pred time cost is 1.1746323108673096 sec
# gt_vol time cost is 0.0050792694091796875 sec
# vols_seg_results time cost is 11.29726791381836 sec
# gt_vol time cost is 0.0038149356842041016 sec
# vols_seg_results time cost is 11.00318431854248 sec
# gt_vol time cost is 0.015418529510498047 sec
# vols_seg_results time cost is 10.809924364089966 sec
# gt_vol time cost is 0.0033845901489257812 sec
# vols_seg_results time cost is 11.264874696731567 sec
# gt_vol time cost is 0.009736299514770508 sec
# vols_seg_results time cost is 11.463147163391113 sec
# gt_vol time cost is 0.004509925842285156 sec
# vols_seg_results time cost is 10.94100832939148 sec
# gt_vol time cost is 0.010319232940673828 sec
# vols_seg_results time cost is 10.887633562088013 sec
# gt_vol time cost is 0.004209041595458984 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-098e86f0622b> in <module>
#      79         elapsed = time.time() - t
#      80         print('gt_vol time cost is {} sec'.format(elapsed) )
# ---> 81         hit = vols_seg_results(gt_vol , vol_pred, CTname=row['Contour File Path'], gt_keep_largest=1)
#      82         Metrics_vol.extend(hit)
#      83         elapsed = time.time() - t
#
# /mnt/fast-disk1/mjc/utils_codes/utils_metrics_3d.py in vols_seg_results(vol_gt, vol_pred, CTname, gt_keep_largest, pred_keep_largest, pred_keep_best, reduceFP)
#     276         ix2 = l_pred>0
#     277         for i, p in enumerate(l_pred):
# --> 278             z = np.where(labels_pred == p)[0]
#     279             if len( set(z) )<=1:
#     280                 ix2[i]=False
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
df_metrics = pd.DataFrame(Metrics_vol, 
                        columns = ['file_name','igt','merge','#gt','#pred',
                                    'iou_score', 'dice_score', 'over_seg' , 'under_seg',
                                    'area_gt','area_pred','intersection','union']) 
df_metrics.to_csv(metrics_save_path)

# %%
pd.options.display.float_format = "{:.3f}".format
df_metrics = pd.DataFrame(Metrics_vol, 
                          columns = ['file_name','igt','merge','#gt','#pred',
                                     'iou_score', 'dice_score', 'over_seg' , 'under_seg',
                                     'area_gt','area_pred','intersection','union']) 
df_metrics.describe([.05, .25, .5, .75, .95])

# %%
df_metrics[df_metrics.dice_score>0.25].describe([.05, .25, .5, .75, .95])

# %%
dfinnermerge = pd.merge(df_metrics,df_Yen,how='inner',left_on='file_name' , right_on='Contour File Path')
for col in dfinnermerge.columns.tolist():
    print(col , len(set(dfinnermerge[col].tolist() )) )



pts = dfinnermerge["Image File Path"].values.tolist()
FPs = []
for onept in list(set(pts)):
    df_onept = dfinnermerge[dfinnermerge["Image File Path"]==onept]
    assert( min(df_onept["#pred"]) == max(df_onept["#pred"]))
    fp = max(df_onept["#pred"])
    FPs.append(fp)
print("="*80)
print( "In total, {} CT series; {} AI detections ".format( len(FPs) , sum(FPs) ) )

dices = dfinnermerge.dice_score.tolist()

for th in [0, 0.1, 0.2, 0.25, 0.5]:
    TP = [p>th for p in dices ]
    assert( len(TP) == len(dices))
    fprate = ( sum(FPs) - sum(TP) ) / len(FPs)
    print(f"sensitivity is {sum(TP)/len(dices):.3f}({sum(TP)}/{len(dices)}) FP-rate is {fprate:.1f} per CT-serie at threshold {th}")

# %%
df_metrics

# %%
CT_EXCEL_FILE = '/mnt/fast-data/mjc/AutoRECIST/Inputs/PDS_AMGEN_20020408_CIA-LAB_Image_And_Contour_2022-01-10.xlsx'
# CT_EXCEL_FILE = '/mnt/fast-data/mjc/AutoRECIST/Inputs/PDS_AUTO_RECIST CIA-LAB Image and Contour 2020-10-01.xlsx'
SAVE_PATH = '/mnt/fast-disk1/refine_gt/'

import pandas as pd
df_all = pd.read_excel(CT_EXCEL_FILE)

print(df_all)
# Out:
#      PatientID PatientName  StudyDate User ID  Tumor QA State  Tumor Label  \
# 0        BAIJC       BAIJC 2004-02-27  js5680               3            1
# 1        BAIJC       BAIJC 2004-02-27  js5680               3            2
# 2        BAIJC       BAIJC 2004-02-27  js5680               3            3
# 3        BAIJC       BAIJC 2004-02-27  js5680               3            4
# 4        BAIJC       BAIJC 2004-02-27  js5680               3            5
# ...        ...         ...        ...     ...             ...          ...
# 3243     BAIXA       BAIXA 2004-02-09  yh2588               3            2
# 3244     BAIXA       BAIXA 2004-02-09  yh2588               3            3
# 3245     BAIXA       BAIXA 2004-02-09  yh2588               3            4
# 3246     BAIXA       BAIXA 2004-02-09  yh2588               3            5
# 3247     BAIXA       BAIXA 2004-02-09  yh2588               3            6
#
#      Location      Uni      Perp           Bi    Volume    Update Date Time  \
# 0       liver  45.5731  36.56930  1666.576500  24536.30 2020-06-16 10:39:58
# 1        lung  15.5643  11.11740   173.034550   2039.34 2020-06-16 10:40:00
# 2        lung  12.8308  10.06720   129.170230   1344.73 2020-06-22 16:51:16
# 3        lung  15.1458  12.27960   185.984360   1586.98 2020-06-22 16:51:26
# 4        lung  10.7557   3.58525    38.561874    538.88 2020-06-22 16:51:38
# ...       ...      ...       ...          ...       ...                 ...
# 3243    liver  23.2746  13.19280   307.057130   7250.49 2020-07-01 12:33:51
# 3244    liver  16.8104   9.88845   166.228790   1557.17 2020-07-01 12:33:51
# 3245    liver  27.1977  17.68900   481.100100   5395.09 2020-07-09 15:44:15
# 3246    liver  17.4805  16.14270   282.182460   2574.10 2020-07-09 15:44:25
# 3247    liver  16.9263   8.95437   151.564350   1178.27 2020-07-09 15:44:43
#
#                                           Raw File Name  \
# 0     js5680_BAIJC_2004-02-27_S0002_T0000_1.3.6.1.4....
# 1     js5680_BAIJC_2004-02-27_S0003_T0000_1.3.6.1.4....
# 2     js5680_BAIJC_2004-02-27_S0002_T0001_1.3.6.1.4....
# 3     js5680_BAIJC_2004-02-27_S0002_T0002_1.3.6.1.4....
# 4     js5680_BAIJC_2004-02-27_S0002_T0003_1.3.6.1.4....
# ...                                                 ...
# 3243  yh2588_BAIXA_2004-02-09_S0002_T0001_1.3.12.2.1...
# 3244  yh2588_BAIXA_2004-02-09_S0002_T0002_1.3.12.2.1...
# 3245  yh2588_BAIXA_2004-02-09_S0002_T0003_1.3.12.2.1...
# 3246  yh2588_BAIXA_2004-02-09_S0002_T0004_1.3.12.2.1...
# 3247  yh2588_BAIXA_2004-02-09_S0002_T0005_1.3.12.2.1...
#
#                         Tumor Instance UID  \
# 0     c77ee057-1b44-46e4-a860-64a0ea2659a2
# 1     8a3aa808-3588-4a3e-a46f-258867dd9ff3
# 2     37e51f5c-8ea1-4cda-9451-9a7f39357971
# 3     a4c79b5b-020d-423e-8541-48e80e398fb5
# 4     31dd6b13-1323-4097-88df-ecba9f76abb5
# ...                                    ...
# 3243  cbc0f051-9943-47ec-a1be-c92c942e5770
# 3244  1d38835a-7651-4b76-98e4-23a5a9b31de1
# 3245  2c707ced-3805-4746-a79c-bd6bb98944bf
# 3246  bf41ffe0-7a73-43af-9070-f41a3bc8f162
# 3247  bc2881d4-2e49-4313-b5a5-9cf5dffbc4bb
#
#                                         Image File Path  \
# 0     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 1     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 2     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 4     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# ...                                                 ...
# 3243  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3244  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3245  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3246  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3247  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
#
#                                       Contour File Path
# 0     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 1     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 2     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 3     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 4     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# ...                                                 ...
# 3243  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3244  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3245  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3246  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3247  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
#
# [3248 rows x 16 columns]

# %%
df = df_all # a liver lesions case

df = df.drop_duplicates(subset=['Image File Path'], keep='first')
print(df)
# Out:
#      PatientID PatientName  StudyDate User ID  Tumor QA State  Tumor Label  \
# 0        BAIJC       BAIJC 2004-02-27  js5680               3            1
# 1        BAIJC       BAIJC 2004-02-27  js5680               3            2
# 15       BAIJD       BAIJD 2004-02-07  js5680               3            1
# 23       BAIJG       BAIJG 2004-02-02  js5680               3            1
# 24       BAIJG       BAIJG 2004-02-02  js5680               3            2
# ...        ...         ...        ...     ...             ...          ...
# 3229     BAIWV       BAIWV 2004-02-02  yh2588               3            1
# 3235     BAIWY       BAIWY 2004-02-25  yh2588               3            1
# 3236     BAIWY       BAIWY 2004-02-25  yh2588               3            2
# 3241     BAIWZ       BAIWZ 2004-02-25  yh2588               3            1
# 3242     BAIXA       BAIXA 2004-02-09  yh2588               3            1
#
#             Location       Uni      Perp           Bi     Volume  \
# 0              liver  45.57310  36.56930  1666.576500  24536.300
# 1               lung  15.56430  11.11740   173.034550   2039.340
# 15             liver  51.53200  47.67340  2456.705800  59975.700
# 23              lung   7.65169   6.42315    49.147953    317.011
# 24             liver  42.02920  35.80720  1504.948100  24998.600
# ...              ...       ...       ...          ...        ...
# 3229  mediastinum LN  15.04750  10.54690   158.704470    986.298
# 3235        pancreas  42.97980  27.04890  1162.556400  17728.500
# 3236            lung  26.79620  15.42970   413.457340   8662.140
# 3241           liver  43.39280  35.69890  1549.075100  30111.700
# 3242            lung  15.35100  12.23130   187.762700   1474.060
#
#         Update Date Time                                      Raw File Name  \
# 0    2020-06-16 10:39:58  js5680_BAIJC_2004-02-27_S0002_T0000_1.3.6.1.4....
# 1    2020-06-16 10:40:00  js5680_BAIJC_2004-02-27_S0003_T0000_1.3.6.1.4....
# 15   2020-06-16 10:40:03  js5680_BAIJD_2004-02-07_S0002_T0000_1.3.12.2.1...
# 23   2020-06-22 19:05:06  js5680_BAIJG_2004-02-02_S0005_T0000_1.3.12.2.1...
# 24   2020-06-16 10:40:08  js5680_BAIJG_2004-02-02_S0013_T0000_1.3.12.2.1...
# ...                  ...                                                ...
# 3229 2020-07-01 12:33:26  yh2588_BAIWV_2004-02-02_S0002_T0000_1.3.6.1.4....
# 3235 2020-07-09 15:38:45  yh2588_BAIWY_2004-02-25_S0007_T0000_1.3.12.2.1...
# 3236 2020-07-01 12:33:41  yh2588_BAIWY_2004-02-25_S0005_T0000_1.3.12.2.1...
# 3241 2020-07-01 12:33:48  yh2588_BAIWZ_2004-02-25_S3720_T0000_1.2.840.11...
# 3242 2020-07-01 12:33:51  yh2588_BAIXA_2004-02-09_S0002_T0000_1.3.12.2.1...
#
#                         Tumor Instance UID  \
# 0     c77ee057-1b44-46e4-a860-64a0ea2659a2
# 1     8a3aa808-3588-4a3e-a46f-258867dd9ff3
# 15    b38df58b-d2d4-43b7-84ec-e782e89e564e
# 23    6b41eb8a-a5d5-4da7-9c0b-7a4fcf9be4c2
# 24    57c7d5be-92dd-4b2c-a737-646a5c977605
# ...                                    ...
# 3229  403450e7-e09d-43e3-90e5-ddf8b459823f
# 3235  11cfd312-1b9d-43c4-a676-9833b4c10cbc
# 3236  68df5581-40a2-4b16-89a6-3783ac4e622b
# 3241  60f7a288-0b87-4360-85ee-da054386f07f
# 3242  4f771cf9-b8dd-4801-87e9-1d6aefe0cf5b
#
#                                         Image File Path  \
# 0     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 1     X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 15    X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 23    X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 24    X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# ...                                                 ...
# 3229  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3235  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3236  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3241  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
# 3242  X:\ClinicalTrials\FNIH_VOLPACK\AMGEN\20020408\...
#
#                                       Contour File Path
# 0     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 1     X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 15    X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 23    X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# 24    X:\ConvWeasisToRaw\PDS_AMGEN_20020408\js5680_B...
# ...                                                 ...
# 3229  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3235  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3236  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3241  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
# 3242  X:\ConvWeasisToRaw\PDS_AMGEN_20020408\yh2588_B...
#
# [370 rows x 16 columns]

# %%
# coding: utf-8



from __future__ import division
from __future__ import print_function

# In[110]:

import numpy as np
import pandas as pd
import pydicom
import os
import matplotlib.pyplot as plt
import collections
# from tqdm import tqdm_notebook as tqdm
from datetime import datetime

from math import ceil, floor
import cv2
import sys
# from sklearn.model_selection import ShuffleSplit

def window_image(img, window_center,window_width, intercept, slope):
    
#     window_center,window_width = 50 ,100
    img = (img*slope +intercept)
    img_min = window_center - window_width//2
    img_max = window_center + window_width//2
    img[img<img_min] = img_min
    img[img>img_max] = img_max
    return img 


def get_first_of_dicom_field_as_int(x):
    #get x[0] as in int is x is a 'pydicom.multival.MultiValue', otherwise get int(x)
    if type(x) == pydicom.multival.MultiValue:
        return int(x[0])
    else:
        return int(x)

def get_windowing(data):
    dicom_fields = [data[('0028','1050')].value, #window center
                    data[('0028','1051')].value, #window width
                    data[('0028','1052')].value, #intercept
                    data[('0028','1053')].value] #slope
    return [get_first_of_dicom_field_as_int(x) for x in dicom_fields]

def _normalize(img):
    if img.max() == img.min():
        return np.zeros(img.shape)-1
    return 2 * (img - img.min())/(img.max() - img.min()) - 1

def normalize_minmax(img):
    mi, ma = img.min(), img.max()
    if mi == ma:
        return np.zeros(img.shape)-1
    return 2*(img - mi) / (ma - mi) - 1

def getName(s):
    ix1 = s.rfind('/')
    ix2 = s.rfind('.')
    return s[ix1:ix2]


def _read(path, desired_size = (512,512)):
    """Will be used in DataGenerator"""

    try:
        data = pydicom.read_file(path)
        image = data.pixel_array
        window_center , window_width, intercept, slope = get_windowing(data)
        
        image_windowed = window_image(image, window_center, window_width, intercept, slope)
        img = normalize_minmax(image_windowed)

    except:
        img = np.zeros(desired_size[:2])-1
    
    if img.shape[:2] != desired_size[:2]:
        print("image shape is not desired size. Interpolation is done.")
        img = cv2.resize(img, desired_size[:2], interpolation=cv2.INTER_LINEAR)
    
    
    return img



import os
import numpy as np
import pydicom

D_dir2header_df = {}


def get_dicom_header_df(image_dir , labels = []):
    global D_dir2header_df
    if image_dir in D_dir2header_df:
        return D_dir2header_df[image_dir]

    # image_dir = row['Image File Path']


    labels = ['ImageName','InstanceNumber',
            'BitsAllocated', 'BitsStored', 'Columns', 'HighBit', 
            'ImageOrientationPatient_0', 'ImageOrientationPatient_1', 'ImageOrientationPatient_2',
            'ImageOrientationPatient_3', 'ImageOrientationPatient_4', 'ImageOrientationPatient_5',
            'ImagePositionPatient_0', 'ImagePositionPatient_1', 'ImagePositionPatient_2',
            'Modality', 'PatientID', 'PhotometricInterpretation', 'PixelRepresentation',
            'PixelSpacing_0', 'PixelSpacing_1', 'RescaleIntercept', 'RescaleSlope', 'Rows', 'SOPInstanceUID',
            'SamplesPerPixel', 'SeriesInstanceUID', 'StudyID', 'StudyInstanceUID', 
            'WindowCenter', 'WindowWidth', 
        ] if not labels else labels

    data = {l: [] for l in labels}
    
    ctList = os.listdir(image_dir)
    ctList.sort()

    for image in ctList:
        if '.dcm' not in image:
            continue
        if os.path.getsize(os.path.join(image_dir, image)) < 5*1024:
            print('%s size < 5kb skiped!'%os.path.join(image_dir, image) )
            continue
        data["ImageName"].append(image)

        ds = pydicom.dcmread(os.path.join(image_dir, image))
        for metadata in ds.dir():
            if metadata not in data and metadata not in ['ImageOrientationPatient','ImagePositionPatient','PixelSpacing']:
                continue
            if metadata != "PixelData":
                metadata_values = getattr(ds, metadata)
                if type(metadata_values) == pydicom.multival.MultiValue and metadata not in ["WindowCenter", "WindowWidth"]:
                    for i, v in enumerate(metadata_values):
                        data[f"{metadata}_{i}"].append(v)  
                else:
                    if type(metadata_values) == pydicom.multival.MultiValue and metadata in ["WindowCenter", "WindowWidth"]:
                        data[metadata].append(metadata_values[0])
                    else:
                        data[metadata].append(metadata_values)

    df_image = pd.DataFrame(data).set_index("InstanceNumber")
    D_dir2header_df[image_dir] = df_image
    return df_image


# In[2]:

def InstanceNumber2file_name(df_image, num):
    return df_image.loc[num,'ImageName']

def InstanceNumber2data_element(df_image, num, label):
    return df_image.loc[num , label]

    
def get_SliceThickness(df_image):
    flag = False
    L = df_image['ImagePositionPatient_2'].tolist()
    thick = list( np.diff(L) )
    res = float( max(set(thick), key=thick.count) )
    res = -res if res < 0 else res
    
    L.sort()
    thick2 = list( np.diff(L) )
    res2 = float( max(set(thick2), key=thick2.count) )
    if res2 ==0 and res==0:
        result = 0
        flag = True
        print('Warning intv is 0')
        print(df_image['ImagePositionPatient_2'])
    if res2 == res:
        result = res
    else:
        result = res
        flag = True
        print('Warning intv may wrong',res,res2)
        print(df_image['ImagePositionPatient_2'])
    
    return result 

def InstanceNumber2windows_min_max(df_image,num):
    try:     
        WL = InstanceNumber2data_element(df_image, num, 'WindowCenter')
        WW = InstanceNumber2data_element(df_image, num, 'WindowWidth')
    except:
        print("Warning! Window Center or Width is empty! Now use default values")
        WL , WW = 250 , 1500
        
    minHU = int( WL-WW/2 )
    maxHU = minHU + int(WW)
    return [minHU , maxHU]


class ASerial:
    P=-1
    D=-1
    S=-1
    name = ''
    def __init__(self, path_str):
        self.path = path_str
        self.getP()
        self.getD()
        self.getS()
        self.convert_path()
        
    def getP(self, target = 'DeepLesion_', L=6):
        ix = self.path.rfind(target) + len(target)
        ss = self.path[ix:ix+L]
        self.P = int(ss)
        
    def getD(self, target = '/D', L=6):
        ix = self.path.rfind(target) + len(target)
        ss = self.path[ix:ix+L]
        self.D = int(ss)
        
    def getS(self, target = '/S', L=6):
        ix = self.path.rfind(target) + len(target)
        ss = self.path[ix:ix+L]
        self.S = int(ss)
        
    def convert_path(self):
        self.name = '%06d_%02d_%02d'%(self.P, self.D, self.S)




import os
import cv2
import json, yaml
import numpy as np
from PIL import Image
# from collections import OrderedDict
from pycocotools import mask as cocomask
from pycocotools import coco as cocoapi



def replacer(s, newstring, index, nofail=False):
    # raise an error if index is outside of the string
    if not nofail and index not in range(len(s)):
        raise ValueError("index outside given string")

    # if not erroring, but the index is still not in the correct range..
    if index < 0:  # add it to the beginning
        return newstring + s
    if index > len(s):  # add it to the end
        return s + newstring

    # insert the new string between "slices" of the original
    return s[:index] + newstring + s[index + 1:]

def convert_file_name(name,S='/'):
    ix = name.rfind('_')
    return replacer(name,S,ix)

def file_name2id(name):
    name.replace('.png','')
    name.replace('_','')
    return int('1' + name)
    
def get_image_size( s ):
    num = list( map( int , s.split(',')))
    return num[0] , num[1]

def get_spacing( s ):
    num = list( map( float , s.split(',')))
    return num[0] , num[1] , num[2]


def get_z_position( df ):
    s = df.loc['Normalized_lesion_location']
    num = list( map( float , s.split(',')))
    return num[2]
    
def get_slice_no( df ):
    s = df.loc['Key_slice_index']
    return int(s)

def get_windows( df ):
    s = df.loc[ 'DICOM_windows']
    num = list( map( float , s.split(',')))
    return num


def get_segmentation():
    return []

def get_bbox( df ):
    s = df.loc['Bounding_boxes']
    num = list( map( float , s.split(',')))
    num[2] = num[2]-num[0]
    num[3] = num[3]-num[1]
    return num 

def get_noise( df ):
    s = df.loc['Possibly_noisy']
    num = int(s)
    return num

def get_area( df ):
    s = df.loc['Lesion_diameters_Pixel_']
    num = list( map( float , s.split(',')))
    return num[0]*num[1]
    



newcats = [{'supercategory': 'DeepLesion', 'id': 1, 'name': 'abdomen'},
           {'supercategory': 'DeepLN', 'id': 2, 'name': 'abdomen LN'},
           {'supercategory': 'DeepLesion', 'id': 3, 'name': 'adrenal'},
           {'supercategory': 'DeepLN', 'id': 4, 'name': 'axillary LN'},
           {'supercategory': 'DeepLesion', 'id': 5, 'name': 'bone'},
           {'supercategory': 'DeepLN', 'id': 6, 'name': 'inguinal LN'},
           {'supercategory': 'DeepLesion', 'id': 7, 'name': 'kidney'},
           {'supercategory': 'DeepLesion', 'id': 8, 'name': 'liver'},
           {'supercategory': 'DeepLesion', 'id': 9, 'name': 'lung'},
           {'supercategory': 'DeepLN', 'id': 10, 'name': 'mediastinum LN'},
           {'supercategory': 'DeepLN', 'id': 11, 'name': 'neck LN'},
           {'supercategory': 'DeepLesion', 'id': 12, 'name': 'ovary'},
           {'supercategory': 'DeepLesion', 'id': 13, 'name': 'pancreas'},
           {'supercategory': 'DeepLN', 'id': 14, 'name': 'pelvic LN'},
           {'supercategory': 'DeepLesion', 'id': 15, 'name': 'pelvis'},
           {'supercategory': 'DeepLesion', 'id': 16, 'name': 'pleural'},
           {'supercategory': 'DeepLN', 'id': 17, 'name': 'retroperitoneal LN'},
           {'supercategory': 'DeepLesion', 'id': 18, 'name': 'soft tissue'},
           {'supercategory': 'DeepLesion', 'id': 19, 'name': 'spleen'},
           {'supercategory': 'DeepLesion', 'id': 20, 'name': 'stomach'},
           {'supercategory': 'DeepLesion', 'id': 21, 'name': 'thyroid'} ]

def get_21_lesion_location_cls():
    D_cls = {}
    for d in newcats:
        id_ = d['id']
        name = d['name']
        D_cls[name] = id_
    return D_cls

D_cls = get_21_lesion_location_cls()

def get_category_id( location , Dict ):
    return Dict[location]


# In[4]:

def replace_png_path(s):
    cs = s.replace('AutoRecist/Inputs' , 'AutoRecist/Pngs')
    return cs


# In[5]:

import os
import cv2
import json, yaml
import numpy as np
from PIL import Image
from collections import OrderedDict
from pycocotools import mask as cocomask
from pycocotools import coco as cocoapi


class DeepLesion():
    """
        DL class to convert annotations to COCO Json format
    """
    def __init__(self, df,image_id_start=0,annotation_id_start=0, savename='a.json'):
        self.image_id_start = image_id_start
        self.annotation_id_start = annotation_id_start
        self.df = df 
        self.info = {"year" : 2021,
                     "version" : "2.0",
                     "description" : "Covert Weasis to Json format",
                     "contributor" : "HY,JM,BZ,LS,FSA",
                     "url" : "http:// /",
                     "date_created" : "20211129"
                    }
        self.licenses = [{"id": 1,
                          "name": "Attribution-NonCommercial",
                          "url": "http:// /"
                         }]

        self.categories = newcats
        
        self.images, self.annotations = self.__get_image_annotation_pairs__(self.df)
        json_data = {"info" : self.info,
                     "images" : self.images,
                     "licenses" : self.licenses,
                     "annotations" : self.annotations,
                     "categories" : self.categories}

        with open(savename, "w") as jsonfile:
            json.dump(json_data, jsonfile, sort_keys=True, indent=4)
            
    def change_df(self , df , savename = 'temp.json'):
        self.df = df 

        self.images, self.annotations = self.__get_image_annotation_pairs__(self.df)
        json_data = {"info" : self.info,
                     "images" : self.images,
                     "licenses" : self.licenses,
                     "annotations" : self.annotations,
                     "categories" : self.categories}

        with open(savename, "w") as jsonfile:
            json.dump(json_data, jsonfile, sort_keys=True, indent=4)
            print( 'Saved %s'%savename )
        
            
    def __get_image_annotation_pairs__(self,df):
        images = []
        annotations = []
        self.file_name_dict = {}
        for i , row in df.iterrows():
            try:
                print(i)
                df_image = get_dicom_header_df( row['Image File Path'] )
                png_folder = replace_png_path(row['Image File Path'] )
                
                for one in df_image.index.values.tolist():
#                     file_name = InstanceNumber2file_name(df_image, one)
#                     file_name = os.path.join( row['Image File Path'] , file_name)
                    file_name = os.path.join(png_folder, '%03d.png'%one)
                    file_name = file_name.replace('/mnt/fast-disk1/mjc/AutoRecist/','')

                    if file_name in self.file_name_dict:
                        oneimageid = self.file_name_dict[file_name]
                    else:
                        oneimage = {}
                        oneimage['file_name'] = file_name
                        self.image_id_start += 1
                        oneimageid = self.image_id_start
                        oneimage['id'] = oneimageid

                        oneimage['height'] , oneimage['width'] = int(InstanceNumber2data_element(df_image,one,'Rows')), int( InstanceNumber2data_element(df_image,one,'Columns') )

                        oneimage['slice_no'] = int(one)
                        oneimage['spacing'] = float( InstanceNumber2data_element(df_image,one,'PixelSpacing_0') )
                        oneimage['slice_intv'] = float( get_SliceThickness(df_image) )
                        oneimage['z_position'] = 0.5
                        oneimage['windows'] = InstanceNumber2windows_min_max(df_image,one)

                        images.append(oneimage)
                        self.file_name_dict[file_name] = oneimageid


            except Exception as e: print(e)
        
        return images, annotations

# %%
def pd_str_replace(df , col, ori, new):
    if isinstance(col , str):
        df[col] = df[col].str.replace(ori,new, case = False) 
    elif isinstance(col, list):
        for one in col:
            pd_str_replace(df , one, ori, new)
    else:
        raise('col instance should be str or list')

pd_str_replace(df, ['Image File Path' ], "X:" , "/mnt/X-drive")
pd_str_replace(df, ['Image File Path' ], r"\\" , "/")
pd_str_replace(df, ['Image File Path'], "/mnt/X-drive/ClinicalTrials/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
pd_str_replace(df, ['Image File Path'], "/mnt/X-drive/ClinicalTrialDone/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
pd_str_replace(df, ['Image File Path'], "/mnt/X-drive/ClinicalTrials", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")


print('Initial Image Process')
dataset = DeepLesion(df,savename='/mnt/fast-data/mjc/AutoRECIST/Annotations/inference.json')
print('Image Process is Done')
print('Total of {} slice images was Processed.'.format(len(dataset.images)))
# Out:
# /mnt/fast-data/mjc/envs/scalenas/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# Initial Image Process
# 0
# 1
# 15
# 23
# 24
# 30
# 31
# 59
# 69
# 76
# 99
# 100
# 114
# 115
# 139
# 149
# 150
# 170
# 171
# 198
# 202
# 203
# 204
# 230
# 231
# 237
# 251
# 279
# 287
# 288
# 307
# 308
# 327
# 328
# 334
# 335
# 341
# 355
# 356
# 370
# 373
# 374
# 381
# 387
# 412
# 441
# 457
# 483
# 484
# 502
# 503
# 504
# 526
# 533
# 534
# 535
# 546
# 551
# 552
# 579
# 580
# 611
# 612
# 631
# 632
# 633
# 648
# 659
# 674
# 675
# 683
# 687
# 702
# 703
# 728
# 729
# 751
# 752
# 757
# 781
# 782
# 783
# 799
# 804
# 805
# 823
# 824
# 835
# 844
# 858
# 859
# 867
# 868
# 897
# 898
# 910
# 924
# 925
# 948
# 949
# 959
# 963
# 968
# 973
# 976
# 977
# 993
# 994
# 998
# 1005
# 1010
# 1026
# 1035
# 1037
# 1054
# 1055
# 1063
# 1071
# 1074
# 1075
# 1092
# 1094
# 1100
# 1101
# 1118
# 1119
# 1142
# 1144
# 1145
# 1164
# 1165
# 1180
# 1181
# 1207
# 1213
# 1229
# 1243
# 1244
# 1258
# 1259
# 1266
# 1269
# 1281
# 1286
# 1287
# 1299
# 1307
# 1318
# 1327
# 1328
# 1331
# 1334
# 1349
# 1356
# 1357
# 1372
# 1378
# 1380
# 1381
# 1396
# 1398
# 1413
# 1420
# 1436
# 1439
# 1458
# 1461
# 1464
# 1482
# 1483
# 1493
# 1519
# 1525
# 1560
# 1563
# 1565
# 1566
# 1605
# 1609
# 1613
# 1614
# 1629
# 1634
# 1635
# 1642
# 1643
# 1646
# 1656
# 1657
# 1676
# 1692
# 1698
# 1714
# 1715
# 1742
# 1743
# 1749
# 1750
# 1766
# 1770
# 1782
# 1783
# 1784
# 1820
# 1821
# 1829
# 1838
# 1851
# 1854
# 1855
# 1869
# 1904
# 1909
# 1924
# 1925
# 1943
# 1970
# 1971
# 1995
# 1996
# 2000
# 2001
# 2014
# 2015
# 2028
# 2029
# 2037
# 2038
# 2055
# 2070
# 2071
# 2080
# 2081
# 2086
# 2089
# 2100
# 2107
# 2111
# 2128
# 2129
# 2156
# 2157
# 2163
# 2185
# 2186
# 2187
# 2214
# 2215
# 2233
# 2249
# 2260
# 2270
# 2285
# 2286
# 2295
# 2296
# 2312
# 2326
# 2345
# 2356
# 2357
# 2360
# 2368
# 2375
# 2376
# 2379
# 2380
# 2404
# 2405
# 2406
# 2437
# 2443
# 2444
# 2445
# 2471
# 2472
# 2498
# 2499
# 2500
# 2512
# 2513
# 2523
# 2528
# 2529
# 2532
# 2533
# 2534
# 2553
# 2570
# 2573
# 2601
# 2602
# 2606
# 2622
# 2623
# 2639
# 2654
# 2655
# 2673
# 2674
# 2700
# 2701
# 2702
# 2717
# 2718
# 2752
# 2755
# 2756
# 2780
# 2781
# 2785
# 2786
# 2804
# 2823
# 2854
# 2855
# 2858
# 2859
# 2865
# 2866
# 2882
# 2883
# 2895
# 2896
# 2907
# 2926
# 2931
# 2932
# 2942
# 2943
# 2959
# 2960
# 2977
# 2992
# 2993
# 2996
# 3002
# 3003
# 3010
# 3032
# 3048
# 3060
# 3073
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# Warning intv may wrong 5.0 1.0
# InstanceNumber
# 1     -1083.0
# 2     -1088.0
# 3     -1093.0
# 4     -1098.0
# 5     -1103.0
#         ...
# 153   -1554.0
# 154   -1559.0
# 155   -1564.0
# 156   -1569.0
# 157   -1574.0
# Name: ImagePositionPatient_2, Length: 157, dtype: float64
# 3086
# 3087
# 3094
# 3116
# 3117
# 3134
# 3135
# 3138
# 3141
# 3144
# 3149
# 3150
# 3157
# 3169
# 3170
# 3183
# 3187
# 3193
# 3199
# 3200
# 3202
# 3216
# 3229
# 3235
# 3236
# 3241
# 3242
# Image Process is Done
# Total of 33394 slice images was Processed.

# %%
get_ipython().system('rm ./cache/inference_gt_roidb.pkl')

# %%
get_ipython().system('rm ./cache/inference_gt_roidb.pkl')

get_ipython().magic('reload_ext autoreload')
get_ipython().magic('autoreload 2')

import warnings
warnings.filterwarnings('ignore')

import argparse
import os

import logging
import numpy as np

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
from tensorboardX import SummaryWriter

import _init_paths
import models
import dataset
from config import cfg
from config import update_config
from core.seg_function import validate_seg_wo_loss as validate
from core.oneshot_function import calib_bn_seg as calib_bn
from utils.utils import get_model_summary
from utils.utils import create_logger, FullModel

from dataset.roidb import combined_roidb_for_training
from roi_data.loader import RoiDataLoader

from PIL import Image
import torch.nn.functional as F
from utils.utils import get_confusion_matrix

import time
t = time.time()


def convert_name(name):
    new = name.replace('/','_')
    return new

def get_palette(n):
    palette = [0] * (n * 3)
    for j in range(0, n):
        lab = j
        palette[j * 3 + 0] = 0
        palette[j * 3 + 1] = 0
        palette[j * 3 + 2] = 0
        i = 0
        while lab:
            palette[j * 3 + 0] |= (((lab >> 0) & 1) << (7 - i))
            palette[j * 3 + 1] |= (((lab >> 1) & 1) << (7 - i))
            palette[j * 3 + 2] |= (((lab >> 2) & 1) << (7 - i))
            i += 1
            lab >>= 3
    return palette
    
# def save_pred(preds, sv_path, name):

#     preds = preds.cpu().numpy().copy()
#     preds = np.asarray(np.argmax(preds, axis=1), dtype=np.uint8)
#     for i in range(preds.shape[0]):
#         cv2.imwrite(os.path.join(sv_path, convert_name(name[i])) , preds[i])

        
def save_pred( preds, sv_path, name):
    palette = get_palette(256)
    preds = preds.cpu().numpy().copy()
    preds = np.asarray(np.argmax(preds, axis=1), dtype=np.uint8)
    for i in range(preds.shape[0]):
        pred = preds[i]
        save_img = Image.fromarray(pred)
        save_img.putpalette(palette)
        save_img.save(os.path.join(sv_path, convert_name(name[i]) ))
        

def testval_lesion(config, test_dataset, testloader, model,
            sv_dir='', sv_pred=True, device = None):
    model.eval()
    confusion_matrix = np.zeros(
        (config.DATASET.NUM_CLASSES, config.DATASET.NUM_CLASSES))
    with torch.no_grad():
        for index, batch in enumerate(testloader):
            image, label, _, name = batch
            size = label.size()
            if device is None:
                image = image.cuda()
                label = label.long().cuda()
            else:
                image = image.to(device)
                label = label.long().to(device)

            pred = model(image)
            if pred.size()[-2] != size[-2] or pred.size()[-1] != size[-1]:
                pred = F.upsample(pred, (size[-2], size[-1]),
                                  mode='bilinear')

            confusion_matrix += get_confusion_matrix(
                label,
                pred,
                size,
                config.DATASET.NUM_CLASSES,
                config.TRAIN.IGNORE_LABEL)

            if sv_pred:
                sv_path = os.path.join(sv_dir, 'test_val_results')
                if not os.path.exists(sv_path):
                    os.makedirs(sv_path)
                save_pred(pred, sv_path, name)

            if index % 100 == 0:
                logging.info('processing: %d batches' % index)
                pos = confusion_matrix.sum(1)
                res = confusion_matrix.sum(0)
                tp = np.diag(confusion_matrix)
                IoU_array = (tp / np.maximum(1.0, pos + res - tp))
                mean_IoU = IoU_array.mean()
#                 logging.info('mIoU: %.4f' % (mean_IoU))

    pos = confusion_matrix.sum(1)
    res = confusion_matrix.sum(0)
    tp = np.diag(confusion_matrix)
    pixel_acc = tp.sum() / pos.sum()
    mean_acc = (tp / np.maximum(1.0, pos)).mean()
    IoU_array = (tp / np.maximum(1.0, pos + res - tp))
    mean_IoU = IoU_array.mean()

    return mean_IoU, IoU_array, pixel_acc, mean_acc


def parse_args(l):
    parser = argparse.ArgumentParser(description='Test segmentation network')

    parser.add_argument('--cfg',
                        help='experiment configure file name',
                        required=True,
                        type=str)
    parser.add_argument('opts',
                        help="Modify config options using the command-line",
                        default=None,
                        nargs=argparse.REMAINDER)
    parser.add_argument('--bn_calib',
                        action='store_true')
    parser.add_argument('--mask_path',
                        help='the path of a mask.npy',
                        default=None,
                        type=str)
    args = parser.parse_args(l)
    update_config(cfg, args)

    return args



# experiment_name = 'Lesion_Q5_9Slices_scalenet_seg_test'
# mask_name = 'mask_1988'
# arglist = ['--cfg', '../experiments/lesion_Q5/%s.yaml'%experiment_name ,  
#            '--mask_path', '../evo_files/masks/%s.npy'%mask_name,  
#            'TEST.MODEL_FILE', '../output/Lesion/superscalenet_seg/Lesion_Q5_9Slices_superscalenet/data_patch_train/best.pth',
#            'DATASET.ROOT','',
#            'TRAIN.USE_FLIPPED',False]

experiment_name = 'Lesion_Q5_scalenet_seg_test'
mask_name = 'mask_1514'
arglist = ['--cfg', '../experiments/lesion_Q5/%s.yaml'%experiment_name ,  
           '--mask_path', '../evo_files/masks/%s.npy'%mask_name,  
           'TEST.MODEL_FILE', '../output/Lesion/superscalenet_seg/Lesion_Q5_superscalenet_base/data_patch_train/best.pth',
           'DATASET.ROOT','../abababab/',
           'TRAIN.USE_FLIPPED',False]

args = parse_args(arglist)

logger, final_output_dir, tb_log_dir = create_logger(
    cfg, args.cfg, 'valtest')

writer_dict = {
    'writer': SummaryWriter(tb_log_dir),
    'train_global_steps': 0,
    'valid_global_steps': 0,
}
# cudnn related setting
cudnn.benchmark = cfg.CUDNN.BENCHMARK
cudnn.deterministic = cfg.CUDNN.DETERMINISTIC
cudnn.enabled = cfg.CUDNN.ENABLED

# build model
model = eval('models.' + cfg.MODEL.NAME +
             '.get_seg_model')(cfg)


if cfg.TEST.MODEL_FILE:
    model_state_file = cfg.TEST.MODEL_FILE
else:
    raise NotImplementedError
    model_state_file = os.path.join(final_output_dir,
                                    'final_state.pth')
# logger.info('=> loading model from {}'.format(model_state_file))

pretrained_dict = torch.load(model_state_file)

D2= {}
for key in pretrained_dict.keys():
    if key[:6] == 'model.':
        new_key = key[6:]
        D2[new_key] = pretrained_dict[key]
    else:
        # print(key)
        D2[key] = pretrained_dict[key]

pretrained_dict = D2      
model_dict = model.state_dict()

model_keys = set(model_dict.keys())
pretrained_keys = set(pretrained_dict.keys())
missing_keys = model_keys - pretrained_keys
# logger.warn('Missing keys in pretrained_dict: {}'.format(missing_keys))

model_dict.update(pretrained_dict)
model.load_state_dict(model_dict, strict=False)

elapsed = time.time() - t
print('Current time cost is {} sec'.format(elapsed) )


test_size = (cfg.TEST.IMAGE_SIZE[1], cfg.TEST.IMAGE_SIZE[0])

# manully select from below.
# ('PDS_AMGEN_20020408_22Cat_test',)
# ('PDS_Q2_A&C_22Cat_train',)
# ('PDS_CUIMC_22Cat_test',)

test_roidb, test_ratio_list, test_ratio_index = combined_roidb_for_training(
        ('inference',) , cfg.VAL.PROPOSAL_FILES)

test_dataset = RoiDataLoader(
    test_roidb,
    cfg.MODEL.NUM_CLASSES,
    training=True)


testloader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=cfg.TEST.BATCH_SIZE_PER_GPU,
    shuffle=False,
    num_workers=cfg.WORKERS,
    pin_memory=True,
    sampler=None)



gpus = list(cfg.GPUS)
# logger.info('GPU list is {}'.format(gpus))

model = nn.DataParallel(model, device_ids=gpus).cuda()

if args.mask_path and os.path.exists(args.mask_path):
    masks = np.load(args.mask_path, allow_pickle=True)
    model.module.set_active_subnet(masks)
    # logger.info('=> setting mask from {}'.format(args.mask_path))
    # logger.info(masks)
else:
    masks=None
    logger.info('No model mask')


mean_IoU, IoU_array, pixel_acc, mean_acc = testval_lesion(cfg, 
                                                  test_dataset, 
                                                  testloader, 
                                                  model.cuda(),
                                                  sv_dir=mask_name, 
                                                  device=None)


elapsed = time.time() - t
print('Current time cost is {} sec'.format(elapsed) )

# %%
import _init_paths
from config import cfg
from config import update_config
from dataset.roidb import combined_roidb_for_training
experiment_name = 'Lesion_Q5_scalenet_seg_test'
mask_name = 'mask_1514'
test_roidb, test_ratio_list, test_ratio_index = combined_roidb_for_training(
        ('inference',) , cfg.VAL.PROPOSAL_FILES)
# Out:
# loading annotations into memory...
# Done (t=0.41s)
# creating index...
# index created!
# 1 33394
# 2 66788
# 4 66788

# %%
# coding: utf-8

# This notebook is to load predicted mask for hard-disk and calculate Segmentation evaluation metics.
# predicted mask is the output of ScaleNASv2 Test and save predicted mask.ipynb
# 
# cp -v /mnt/fast-data/mjc/AutoRECIST/Codes/ScaleNAS/ScaleNASv1/tools/utils_test.py .
# 
# gt box are loaded from /cache/*gt_roidb.pkl
# gt segmentation are loaded from Hao's Raw files
# 
# predictions are all_boxes and all_segms which both are loaded from mask_1988 png files.




# # This file is for segmetation metrics evaluation in 3D
# Edited by Jingchen around 06/20/2021
# This file is after ScaleNAS test which save predition into png images.
# This file load png images as predicted contours in 2D
# load cache pkl as gold-standard contours in 2D
# The stack 2D based on dicom-header to get 3D
# Evaluate 3D metics of dice, IoU, over-segmetation, and under-segmetation
# 
get_ipython().magic('reload_ext autoreload')
get_ipython().magic('autoreload 2')

import os
import logging
import numpy as np
import _init_paths

from config import cfg
from config import update_config
from utils_test import *
from utils_test import __get_annotation__
from utils_metrics_3d import *
import cv2
from PIL import Image

import sys
sys.path.append('/mnt/fast-disk1/mjc/utils_codes/read_weasis_raw_v0.96/')
import weasis_raw_data_api as wr


def convert_name(name):
    new = name.replace('/','_')
    return new

HEIGHT , WIDTH = 512, 512
def get_pred_vol(oneCT , site_list , D_z_index, union_mask = True):
    slice_no_list =list ( oneCT.keys() )

    V = D_z_index.values()
    shape_z = np.max(list(V)) + 1
    vol_shape = (shape_z , HEIGHT , WIDTH )
    height = vol_shape[1]
    width = vol_shape[2]

    if len(slice_no_list):
        slice_no_list.sort()
        vol_gt = np.zeros(vol_shape, dtype = bool)
        vol_pred = np.zeros(vol_shape, dtype = bool)

        for s in slice_no_list:
            aroidb , bboxes , segmentations = oneCT[s]

            ix = [a for a,b in enumerate(aroidb['gt_classes']) if int(b) in site_list]
            contours = [ aroidb['segms'][int(kk)] for kk in ix ]
            
            for c in contours:
                if len(c): #gt
                    new = polys_to_mask(c , height , width)
                    vol_gt[D_z_index[s]][new>0] = 1 


            for j in site_list:
                contours = segmentations[j]
                if union_mask:
                    #contour should be numpy.array here. list cause error of no attribute 'flatten'
                    cc = [ contour.flatten().tolist() for contour in contours if len(contour)!=0]
                    contours = union_ploys(cc , height, width)

                for c in contours:#union pred
                    if len(c)>=6:
                        new = polys_to_mask([c] , height , width) 
                        vol_pred[D_z_index[s]][new>0] = 1 
                    elif len(c):
                        print('len pred contour is %d'%len(c))
    return vol_pred

def seperate_vol(vol_pred , reduceFP = False):
    # vol_dict = seperate_vol(vol_pred)
    connectivity = 2
    from skimage import measure
    labels_pred=measure.label(vol_pred,connectivity=connectivity)
    l_pred,c_pred = np.unique(labels_pred , return_counts=True)


    ix2 = l_pred>0
    l_pred = l_pred[ix2] #background pixels are labeled as 0, so we exclude them
    c_pred = c_pred[ix2]

    if reduceFP:
        ix2 = l_pred>0
        for i, p in enumerate(l_pred):
            z = np.where(labels_pred == p)[0]
            if len( set(z) )<=1:
                ix2[i]=False

        l_pred = l_pred[ix2] #background pixels are labeled as 0, so we exclude them
        c_pred = c_pred[ix2]


    vol_dict = {}

    for p in l_pred:
        vp = labels_pred == p
        vol_dict[p] = vp

    return vol_dict



site_list_liver = [8]
site_list_liver_lung_LNs = [2,4,6,8,9,10,11,14,17] 
site_list_LNs = [2,4,6,10,11,14,17] 

site_list = site_list_liver
user_id = 'jm4669'

cache_path = './cache/'
name = 'inference'
# name = 'lesion_train'

cache_filepath = os.path.join(cache_path, name+'_gt_roidb.pkl')
# print('Loading cached gt_roidb from %s', cache_filepath)
with open(cache_filepath, 'rb') as fp:
    cached_roidb = pickle.load(fp)
    
roidb = cached_roidb



sv_dir = mask_name
sv_path = os.path.join(sv_dir, 'test_val_results')

all_boxes = [ [ np.zeros((0,5),dtype="float32") for _ in range(len(roidb)) ] for _ in range( cfg.DATASET.NUM_CLASSES) ]
all_segms = [ [ [] for _ in range(len(roidb)) ] for _ in range( cfg.DATASET.NUM_CLASSES) ]

for i in range(len(roidb)):

    one = roidb[i]
    onename = one['image']
    if not os.path.exists( os.path.join( sv_path, convert_name(onename) ) ):
        print(os.path.join(sv_path, convert_name(onename) ) , 'not exists!')
    pred_im = Image.open(os.path.join( sv_path, convert_name(onename) ))
    pred = np.array(pred_im)
    for j in range(cfg.DATASET.NUM_CLASSES):
        mask = np.asarray( pred==j , dtype=np.uint8)
        if np.sum(mask > 0) <= 3 :
            continue
        segmentation, bbox, area = __get_annotation__(mask , xywh = False , bbox_score=True)
        if segmentation and bbox:
            all_segms[j][i] = segmentation
            all_boxes[j][i] = bbox


D_CT = {}
for i , aroidb in enumerate(roidb):
    dicom_path , png_name = os.path.split(aroidb['image'])
    slice_no , _= os.path.splitext(png_name)
    slice_no = int(slice_no)
    if slice_no != aroidb['slice_no']:
        print('following slice numbers are not consistence.')
        print(dicom_path,slice_no,aroidb['slice_no'])

    segmentations = {}
    bboxes = {}
    for j in site_list:
        segmentations[j] = all_segms[j][i]
        bboxes[j] = all_boxes[j][i]

    if dicom_path not in D_CT:
        D_CT[dicom_path] = {}
        D_CT[dicom_path][slice_no] = [aroidb , bboxes , segmentations]
    else:
        D_CT[dicom_path][slice_no] = [aroidb , bboxes , segmentations]

# %%
pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], "X:" , "/mnt/X-drive")
pd_str_replace(df_all, ['Image File Path' , 'Contour File Path'], r"\\" , "/")
pd_str_replace(df_all, ['Image File Path'], "/mnt/X-drive/ClinicalTrials/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
pd_str_replace(df_all, ['Image File Path'], "/mnt/X-drive/ClinicalTrialDone/FNIH_VOLPACK", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")
pd_str_replace(df_all, ['Image File Path'], "/mnt/X-drive/ClinicalTrials", "/mnt/fast-disk1/mjc/AutoRecist/Inputs")

pd_str_replace(df_all, ['Contour File Path'], "/mnt/X-drive/ConvWeasisToRaw/PDS_AUTO_RECIST", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw/PDS_AUTO_RECIST_RAW")
pd_str_replace(df_all, ['Contour File Path'], "/mnt/X-drive/ConvWeasisToRaw", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")
pd_str_replace(df_all, ['Contour File Path'], "/mnt/X-drive/ConvWeasisToMatlab", "/mnt/fast-disk1/mjc/AutoRecist/Inputs/ConvWeasisToRaw")

# %%
def initialize_mask_vol( D_z_index , height , width):
    V = D_z_index.values()
    shape_z = np.max(list(V)) + 1
    mask_vol = np.zeros((shape_z , height , width ) , dtype=np.uint8 )
    return mask_vol

Metrics_vol = []
keys = list(D_CT.keys())
for k in keys:
#     if 'COU-AA-302' in k:
#         site_list = site_list_LNs
#     else:
#         site_list = site_list_liver_lung_LNs

    image_series_path = k.replace('/Pngs/' , '/Inputs/')    

    df_image = get_dicom_header_df( image_series_path )
    instanceNumber_list = df_image.index.to_list()
    D_z_index = instanceNumber2Matrix_z_index(instanceNumber_list)


    oneCT = remove_single_slice_segms(D_CT[k])
    vol_pred = get_pred_vol(oneCT , site_list , D_z_index, union_mask = False)
    



    image_series = wr.dicom_header(image_series_path)
    if len(image_series):
        height = image_series[0].Rows 
        width = image_series[0].Columns 
    else:
        print('ERROR image_series has no len' , image_series_path)
    assert(len(image_series) == vol_pred.shape[0])

    mask_vol = initialize_mask_vol( D_z_index, height , width)

    df_radiologist = df_all[(df_all['Image File Path'] == image_series_path) & (df_all['Location'].isin(['liver'])) ]
    for _ , row in df_radiologist.iterrows():
        radiologist_raw = wr.read(row['Contour File Path'])
        slice_list = radiologist_raw.get_instance_number_array()
        for j, one in enumerate(slice_list):
            mask = radiologist_raw.get_mask_image(j)
            mask_vol[D_z_index[one]] += mask


    vol2 = vol_pred + mask_vol
    vol2[vol2>1]=1
    vol_dict = seperate_vol(vol2)
    
    for tumor_index in vol_dict:
        mask_volume = vol_dict[tumor_index]
        weasis_raw_data = wr.create(image_series, mask_volume)

        file_folder = os.path.join(SAVE_PATH , 'RawToWeasis_Amgen')
        if not os.path.exists(file_folder):
            os.makedirs(file_folder)
        file_name = wr.unique(image_series, tumor_index, user_id)
        file_name = os.path.join(file_folder,file_name)
        wr.write(weasis_raw_data, file_name)

        Metrics_vol.append( [image_series_path , file_name , user_id ])



    df_metrics = pd.DataFrame(Metrics_vol, 
                              columns = ['Image File Path','Contour File Path','Uni']) 
    df_metrics.to_csv('RawToWeasisUnionAIRadiologist_Amgen20020408.csv' , index=False)
    print('finished ', k )
# Out:
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJC/D2004_02_27/E20040227/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJC/D2004_02_27/E20040227/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJD/D2004_02_07/E20040207/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJG/D2004_02_02/E20040202/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJG/D2004_02_02/E20040202/CT/S0013
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJH/D2004_02_02/E20040202/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJH/D2004_02_02/E20040202/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJI/D2004_03_01/E20040301/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJL/D2004_02_24/E20040224/CT/S3464
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJM/D2004_01_31/E20040131/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJN/D2004_02_03/E20040203/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJN/D2004_02_03/E20040203/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJO/D2004_02_19/E20040219/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJO/D2004_02_19/E20040219/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJP/D2004_02_26/E20040226/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJQ/D2004_04_27/E20040427/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJQ/D2004_04_27/E20040427/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJR/D2004_02_09/E20040209/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJR/D2004_02_11/E20040211/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJT/D2004_02_27/E20040227/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJV/D2004_04_25/E9999/CT/S0003_4584
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJV/D2004_04_25/E9999/CT/S0004_4585
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJV/D2004_04_25/E9999/CT/S0005_4586
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJW/D2004_02_25/E9999/CT/S0003_1568
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJW/D2004_02_25/E9999/CT/S0004_1569
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJY/D2004_02_26/E20040226/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIJZ/D2004_03_02/E20040302/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKB/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKD/D2004_02_03/E20040203/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKD/D2004_02_04/E20040204/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKG/D2004_04_19/E20040419/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKG/D2004_04_19/E20040419/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKH/D2004_01_30/E20040130/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKH/D2004_01_31/E20040131/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKI/D2004_02_23/E20040223/CT/S2050
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKI/D2004_02_23/E20040223/CT/S2051
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKJ/D2004_02_08/E20040208/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKK/D2004_02_29/E20040229/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKK/D2004_02_29/E20040229/CT/S0009
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKL/D2004_02_10/E9999/CT/S5141_1574
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKO/D2004_02_11/E20040211/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKO/D2004_02_11/E20040211/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKP/D2004_02_25/E20040225/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKQ/D2004_03_14/E20040314/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKS/D2004_02_21/E20040221/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKU/D2004_02_17/E20040217/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKV/D2004_02_24/E20040224/CT/S0001
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKX/D2004_04_28/E20040428/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKX/D2004_04_28/E20040428/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKZ/D2004_02_27/E20040227/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKZ/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIKZ/D2004_02_28/E20040228/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILA/D2004_02_26/E20040226/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILC/D2004_02_23/E20040223/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILC/D2004_02_23/E20040223/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILC/D2004_02_23/E20040223/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILD/D2004_02_24/E20040224/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILE/D2004_02_21/E20040221/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILE/D2004_02_21/E20040221/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILF/D2004_01_27/E20040127/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILF/D2004_01_27/E20040127/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILG/D2004_02_19/E20040219/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILG/D2004_02_20/E20040220/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILJ/D2004_02_29/E20040229/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILJ/D2004_02_29/E20040229/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILJ/D2004_02_29/E20040229/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILK/D2004_02_24/E20040224/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILL/D2004_02_23/E20040223/CT/S2965
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILM/D2004_02_05/E20040205/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILM/D2004_02_05/E20040205/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILN/D2004_02_28/E20040228/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILP/D2004_02_11/E20040211/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILQ/D2004_02_24/E20040224/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILQ/D2004_02_24/E20040224/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILR/D2004_05_20/E20040520/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILR/D2004_05_20/E20040520/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILS/D2004_02_28/E20040228/CT/S4883
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILS/D2004_02_28/E20040228/CT/S4884
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILU/D2004_02_25/E20040225/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILV/D2004_02_26/E20040226/CT/S2964
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILV/D2004_02_26/E20040226/CT/S2965
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILV/D2004_02_26/E20040226/CT/S2966
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAILY/D2004_02_03/E20040203/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMA/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMA/D2004_02_25/E20040225/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMC/D2004_02_28/E20040228/CT/S2607
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMC/D2004_02_28/E20040228/CT/S2608
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIME/D2004_02_24/E20040224/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMF/D2004_02_26/E20040226/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMG/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMG/D2004_02_26/E20040226/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMI/D2004_02_18/E20040218/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMI/D2004_02_18/E20040218/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIML/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIML/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMQ/D2004_03_02/E20040302/CT/S9708
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMS/D2004_02_29/E20040229/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMS/D2004_02_29/E20040229/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMU/D2004_03_02/E20040302/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMU/D2004_03_02/E20040302/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMV/D2004_01_27/E20040127/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMW/D2004_02_28/E20040228/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIMZ/D2004_03_01/E20040301/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINA/D2004_04_21/E20040421/CT/S7100
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINB/D2004_02_22/E20040222/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINB/D2004_02_22/E20040222/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINC/D2004_02_27/E20040227/CT/S3498
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIND/D2004_06_21/E20040621/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINF/D2004_01_31/E20040131/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAING/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINH/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINI/D2004_02_06/E20040206/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINJ/D2004_03_02/E20040302/CT/S0012
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINK/D2004_02_16/E20040216/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINL/D2004_03_30/E20040330/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINL/D2004_03_30/E20040330/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINN/D2004_04_27/E20040427/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINP/D2004_06_02/E20040602/CT/S4095
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINS/D2004_01_15/E20040115/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINS/D2004_01_15/E20040115/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINT/D2004_02_22/E20040222/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINU/D2004_12_29/E20041229/CT/S1549
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINV/D2004_02_04/E20040204/CT/S0122
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINV/D2004_02_04/E20040204/CT/S0123
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINX/D2004_01_30/E20040130/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINX/D2004_01_30/E20040130/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAINY/D2004_02_23/E20040223/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOB/D2004_02_19/E20040219/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOB/D2004_02_19/E20040219/CT/S0102
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOC/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOC/D2004_02_28/E20040228/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOE/D2004_03_08/E20040308/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOE/D2004_03_08/E20040308/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOG/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOI/D2004_02_13/E20040213/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOJ/D2004_02_15/E20040215/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOK/D2004_02_04/E20040204/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOK/D2004_02_04/E20040204/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOL/D2004_02_23/E20040223/CT/S2253
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOL/D2004_02_23/E20040223/CT/S2255
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOO/D2004_01_18/E20040118/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOR/D2004_02_27/E20040227/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOS/D2004_01_26/E20040126/CT/S7861
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOT/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOT/D2004_02_27/E20040227/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOU/D2004_02_23/E20040223/CT/S6065
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOW/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOX/D2004_04_24/E20040424/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOY/D2004_02_24/E20040224/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOY/D2004_02_24/E20040224/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIOZ/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPA/D2004_02_24/E20040224/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPB/D2004_02_28/E20040228/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPC/D2004_03_08/E20040308/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPC/D2004_03_08/E20040308/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPD/D2004_02_24/E20040224/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPF/D2004_02_25/E20040225/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPH/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPH/D2004_02_28/E20040228/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPI/D2004_02_12/E20040212/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPK/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPL/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPM/D2004_02_10/E20040210/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPN/D2004_02_25/E20040225/CT/S3815
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPO/D2004_02_05/E20040205/CT/S3337
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPP/D2004_04_27/E20040427/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPQ/D2004_02_25/E20040225/CT/S0461
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPR/D2004_02_11/E20040211/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPS/D2004_02_27/E20040227/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPS/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPU/D2004_02_28/E20040228/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPV/D2004_02_23/E20040223/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPW/D2004_02_06/E20040206/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPX/D2004_02_14/E20040214/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPY/D2004_02_20/E20040220/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPZ/D2004_03_02/E20040302/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIPZ/D2004_03_02/E20040302/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQA/D2004_03_02/E20040302/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQD/D2004_02_29/E20040229/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQE/D2004_02_24/E20040224/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQE/D2004_02_24/E20040224/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQF/D2004_02_11/E20040211/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQG/D2004_02_28/E20040228/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQG/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQH/D2004_02_21/E20040221/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQH/D2004_02_21/E20040221/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQI/D2004_02_23/E20040223/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQJ/D2004_02_18/E20040218/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQJ/D2004_02_19/E20040219/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQL/D2004_03_08/E20040308/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQM/D2004_02_18/E20040218/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQN/D2004_02_03/E20040203/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQO/D2004_02_23/E20040223/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQO/D2004_02_23/E20040223/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQP/D2004_02_25/E20040225/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQP/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQQ/D2004_02_28/E20040228/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQQ/D2004_02_28/E20040228/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQT/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQU/D2004_02_14/E20040214/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQV/D2004_02_20/E20040220/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQW/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQW/D2004_02_24/E20040224/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQX/D2004_02_15/E20040215/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQX/D2004_02_15/E20040215/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIQZ/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRB/D2004_01_29/E20040129/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRC/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRD/D2004_02_24/E20040224/CT/S0310
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRD/D2004_02_24/E20040224/CT/S0311
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRE/D2004_02_27/E20040227/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRF/D2004_03_02/E20040302/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRG/D2004_02_19/E20040219/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRJ/D2004_02_23/E20040223/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRJ/D2004_02_23/E20040223/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRK/D2004_02_28/E20040228/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRL/D2004_02_24/E20040224/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRL/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRM/D2004_02_11/E20040211/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRN/D2004_02_25/E20040225/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRO/D2004_02_24/E20040224/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRO/D2004_02_24/E20040224/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRP/D2004_02_13/E20040213/CT/S0502
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRP/D2004_02_13/E20040213/CT/S0503
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRS/D2004_02_25/E20040225/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRS/D2004_02_25/E20040225/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRU/D2004_02_29/E20040229/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRU/D2004_02_29/E20040229/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRW/D2004_02_28/E9999/CT/S5141_2841
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRX/D2004_02_17/E20040217/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIRX/D2004_02_17/E20040217/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISA/D2004_02_04/E20040204/CT/S3993
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISA/D2004_02_04/E20040204/CT/S3994
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISB/D2004_02_24/E20040224/CT/S2408
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISC/D2004_02_11/E20040211/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISD/D2004_03_02/E20040302/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISE/D2004_02_21/E20040221/CT/S2628
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISF/D2004_03_02/E20040302/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISH/D2004_04_22/E20040422/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISH/D2004_04_22/E20040422/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISI/D2004_02_01/E20040201/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISI/D2004_02_01/E20040201/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISJ/D2004_03_01/E20040301/CT/S1896
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISK/D2004_02_18/E20040218/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISK/D2004_02_18/E20040218/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISK/D2004_02_18/E20040218/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISM/D2004_02_15/E20040215/CT/S1231
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISM/D2004_02_15/E20040215/CT/S1232
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISN/D2004_02_25/E20040225/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISO/D2004_02_25/E20040225/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISP/D2004_02_25/E20040225/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISQ/D2004_01_27/E20040127/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISR/D2004_02_13/E20040213/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISR/D2004_02_13/E20040213/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISS/D2004_02_26/E20040226/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISS/D2004_02_26/E20040226/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIST/D2004_02_27/E20040227/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISU/D2004_02_06/E20040206/CT/S0103
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISV/D2004_02_29/E20040229/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISW/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISW/D2004_02_27/E20040227/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISX/D2004_02_24/E20040224/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAISY/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITB/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITB/D2004_02_29/E20040229/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITD/D2004_04_25/E20040425/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITD/D2004_04_25/E20040425/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITE/D2004_02_26/E20040226/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITE/D2004_02_26/E20040226/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITE/D2004_02_26/E20040226/CT/S0008
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITF/D2004_03_01/E20040301/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITG/D2004_02_25/E20040225/CT/S1358
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITG/D2004_02_25/E20040225/CT/S1359
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITG/D2004_02_25/E20040225/CT/S1360
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITH/D2004_03_02/E20040302/CT/S0009
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITH/D2004_03_02/E20040302/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITK/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITK/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITK/D2004_02_27/E20040227/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITL/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITL/D2004_02_26/E20040226/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITN/D2004_02_11/E20040211/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITO/D2004_02_05/E20040205/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITO/D2004_02_06/E20040206/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITP/D2004_02_04/E20040204/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITP/D2004_02_04/E20040204/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITQ/D2004_02_22/E20040222/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITR/D2004_02_06/E20040206/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITS/D2004_02_25/E20040225/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITU/D2004_02_26/E20040226/CT/S6470
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITV/D2004_02_21/E20040221/CT/S0773
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITV/D2004_02_21/E20040221/CT/S0774
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITW/D2004_02_12/E20040212/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITX/D2004_04_27/E20040427/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITX/D2004_04_27/E20040427/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAITZ/D2004_02_24/E20040224/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUA/D2004_02_03/E20040203/CT/S4602
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUA/D2004_02_03/E20040203/CT/S4603
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUD/D2004_02_26/E20040226/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUD/D2004_02_26/E20040226/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUE/D2004_02_27/E20040227/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUE/D2004_02_27/E20040227/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUE/D2004_03_01/E20040301/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUF/D2004_02_26/E20040226/CT/S8056
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUF/D2004_02_26/E20040226/CT/S8057
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUH/D2004_02_18/E20040218/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUI/D2004_02_20/E20040220/CT/S3620
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUI/D2004_02_20/E20040220/CT/S3621
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUJ/D2004_02_21/E20040221/CT/S4238
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUJ/D2004_02_21/E20040221/CT/S4239
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUK/D2004_02_19/E20040219/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUK/D2004_02_19/E20040219/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUL/D2004_02_25/E20040225/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUM/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUO/D2004_05_25/E20040525/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUO/D2004_05_25/E20040525/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUV/D2004_02_28/E20040228/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUV/D2004_02_28/E20040228/CT/S0011
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUW/D2004_02_24/E20040224/CT/S1438
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUW/D2004_02_24/E20040224/CT/S1439
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUX/D2004_02_28/E20040228/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUX/D2004_02_28/E20040228/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUY/D2004_02_29/E20040229/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIUY/D2004_02_29/E20040229/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVA/D2004_02_05/E20040205/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVB/D2004_02_28/E20040228/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVD/D2004_02_10/E20040210/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVD/D2004_02_11/E20040211/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVG/D2004_02_24/E20040224/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVG/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVH/D2004_02_24/E20040224/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVH/D2004_02_24/E20040224/CT/S0008
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVJ/D2004_03_01/E20040301/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVK/D2004_02_10/E20040210/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVK/D2004_02_10/E20040210/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVM/D2004_02_19/E20040219/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVP/D2004_03_01/E20040301/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVP/D2004_03_01/E20040301/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVR/D2004_03_16/E20040316/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVT/D2004_03_02/E20040302/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVU/D2004_02_13/E20040213/CT/S8370
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVW/D2004_02_20/E20040220/CT/S4504
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVX/D2004_03_01/E20040301/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVY/D2003_11_20/E20031120/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIVY/D2003_11_20/E20031120/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWA/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWC/D2004_01_24/E20040124/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWC/D2004_01_24/E20040124/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWD/D2004_02_27/E20040227/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWD/D2004_02_28/E20040228/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWE/D2004_04_27/E20040427/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWG/D2004_02_26/E20040226/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWH/D2004_03_01/E20040301/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWI/D2004_02_24/E20040224/CT/S0006
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWI/D2004_02_24/E20040224/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWJ/D2004_02_07/E20040207/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWL/D2004_02_27/E20040227/CT/S0004
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWL/D2004_02_27/E20040227/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWM/D2004_02_25/E20040225/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWO/D2004_03_02/E20040302/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWP/D2004_02_26/E20040226/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWQ/D2004_03_03/E20040303/CT/S0008
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWQ/D2004_03_03/E20040303/CT/S0009
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWR/D2004_02_26/E20040226/CT/S0003
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWU/D2004_02_11/E20040211/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWV/D2004_02_02/E20040202/CT/S0002
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWY/D2004_02_25/E20040225/CT/S0007
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWY/D2004_02_25/E20040225/CT/S0005
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIWZ/D2004_02_25/E20040225/CT/S3720
# finished  /mnt/fast-disk1/mjc/AutoRecist/Pngs/AMGEN/20020408/BAIXA/D2004_02_09/E20040209/CT/S0002

# %%
k

# %%
a= [1,2,3]
for x in a:
    x=10
print(a)
# Out:
# [1, 2, 3]
